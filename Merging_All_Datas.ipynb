# %%
! pip install flask_sqlalchemy
# Out:
# Requirement already satisfied: flask_sqlalchemy in c:\users\jasmi\anaconda3\lib\site-packages (2.4.0)
# Requirement already satisfied: SQLAlchemy>=0.8.0 in c:\users\jasmi\anaconda3\lib\site-packages (from flask_sqlalchemy) (1.2.15)
# Requirement already satisfied: Flask>=0.10 in c:\users\jasmi\anaconda3\lib\site-packages (from flask_sqlalchemy) (1.0.2)
# Requirement already satisfied: itsdangerous>=0.24 in c:\users\jasmi\anaconda3\lib\site-packages (from Flask>=0.10->flask_sqlalchemy) (1.1.0)
# Requirement already satisfied: click>=5.1 in c:\users\jasmi\anaconda3\lib\site-packages (from Flask>=0.10->flask_sqlalchemy) (7.0)
# Requirement already satisfied: Werkzeug>=0.14 in c:\users\jasmi\anaconda3\lib\site-packages (from Flask>=0.10->flask_sqlalchemy) (0.14.1)
# Requirement already satisfied: Jinja2>=2.10 in c:\users\jasmi\anaconda3\lib\site-packages (from Flask>=0.10->flask_sqlalchemy) (2.10)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\jasmi\anaconda3\lib\site-packages (from Jinja2>=2.10->Flask>=0.10->flask_sqlalchemy) (1.1.0)

# %%
! pip install folium
# Out:
# Collecting folium
#   Downloading https://files.pythonhosted.org/packages/4f/86/1ab30184cb60bc2b95deffe2bd86b8ddbab65a4fac9f7313c278c6e8d049/folium-0.9.1-py2.py3-none-any.whl (91kB)
# Collecting branca>=0.3.0 (from folium)
#   Downloading https://files.pythonhosted.org/packages/63/36/1c93318e9653f4e414a2e0c3b98fc898b4970e939afeedeee6075dd3b703/branca-0.3.1-py3-none-any.whl
# Requirement already satisfied: numpy in c:\users\jasmi\anaconda3\lib\site-packages (from folium) (1.15.4)
# Requirement already satisfied: jinja2>=2.9 in c:\users\jasmi\anaconda3\lib\site-packages (from folium) (2.10)
# Requirement already satisfied: requests in c:\users\jasmi\anaconda3\lib\site-packages (from folium) (2.21.0)
# Requirement already satisfied: six in c:\users\jasmi\appdata\roaming\python\python37\site-packages (from branca>=0.3.0->folium) (1.12.0)
# Requirement already satisfied: MarkupSafe>=0.23 in c:\users\jasmi\anaconda3\lib\site-packages (from jinja2>=2.9->folium) (1.1.0)
# Requirement already satisfied: idna<2.9,>=2.5 in c:\users\jasmi\anaconda3\lib\site-packages (from requests->folium) (2.8)
# Requirement already satisfied: chardet<3.1.0,>=3.0.2 in c:\users\jasmi\anaconda3\lib\site-packages (from requests->folium) (3.0.4)
# Requirement already satisfied: urllib3<1.25,>=1.21.1 in c:\users\jasmi\anaconda3\lib\site-packages (from requests->folium) (1.24.1)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\jasmi\anaconda3\lib\site-packages (from requests->folium) (2018.11.29)
# Installing collected packages: branca, folium
# Successfully installed branca-0.3.1 folium-0.9.1

# %%
import os

import pandas as pd
import numpy as np
import pymysql

import sqlalchemy
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session
from sqlalchemy import create_engine, inspect, func, distinct

from flask import Flask, jsonify, render_template
from flask_sqlalchemy import SQLAlchemy

pymysql.install_as_MySQLdb()

app = Flask(__name__)



# # reflect an existing database into a new model
# Base = automap_base()
# # reflect the tables
# Base.prepare(engine, reflect=True)
#
# # print table names
# print(engine.table_names())
# # Save reference to the table
# Hale = Base.classes.hale


app.config["SQLALCHEMY_DATABASE_URI"] = "mysql://rl91qzpzgty8oaf1:evamhxfd7l42mgso@y2w3wxldca8enczv.cbetxkdyhwsb.us-east-1.rds.amazonaws.com:3306/v21ogkg4wvsne316"
db = SQLAlchemy(app)

# reflect an existing database into a new model
Base = automap_base()
# reflect the tables
Base.prepare(db.engine, reflect=True)

# Save references to each table
Hale = Base.classes.hale
LexByCountry = Base.classes.lexbycountry
#
#
# Out:
# C:\Users\jasmi\Anaconda3\lib\site-packages\flask_sqlalchemy\__init__.py:835: FSADeprecationWarning: SQLALCHEMY_TRACK_MODIFICATIONS adds significant overhead and will be disabled by default in the future.  Set it to True or False to suppress this warning.
#   'SQLALCHEMY_TRACK_MODIFICATIONS adds significant overhead and '

# %%
stmt = db.session.query(LexByCountry).statement
df = pd.read_sql_query(stmt, db.session.bind)
df
# Out:
#                    Country                 Year  LEX at birth Both sexes  \
# 0              Afghanistan  0000-00-00 00:00:00                     62.7
# 1              Afghanistan  2000-01-01 00:00:00                     55.9
# 2              Afghanistan  2001-01-01 00:00:00                     56.5
# 3              Afghanistan  2002-01-01 00:00:00                     57.4
# 4              Afghanistan  2003-01-01 00:00:00                     58.0
# 5              Afghanistan  2004-01-01 00:00:00                     58.4
# 6              Afghanistan  2005-01-01 00:00:00                     58.9
# 7              Afghanistan  2006-01-01 00:00:00                     59.2
# 8              Afghanistan  2007-01-01 00:00:00                     59.6
# 9              Afghanistan  2008-01-01 00:00:00                     60.2
# 10             Afghanistan  2009-01-01 00:00:00                     60.7
# 11             Afghanistan  2010-01-01 00:00:00                     61.2
# 12             Afghanistan  2011-01-01 00:00:00                     61.7
# 13             Afghanistan  2012-01-01 00:00:00                     62.2
# 14             Afghanistan  2013-01-01 00:00:00                     62.7
# 15             Afghanistan  2014-01-01 00:00:00                     63.0
# 16             Afghanistan  2015-01-01 00:00:00                     63.2
# 17             Afghanistan  2016-01-01 00:00:00                     62.7
# 18                 Albania  0000-00-00 00:00:00                     76.4
# 19                 Albania  2000-01-01 00:00:00                     73.1
# 20                 Albania  2001-01-01 00:00:00                     74.0
# 21                 Albania  2002-01-01 00:00:00                     73.5
# 22                 Albania  2003-01-01 00:00:00                     72.9
# 23                 Albania  2004-01-01 00:00:00                     73.3
# 24                 Albania  2005-01-01 00:00:00                     73.5
# 25                 Albania  2006-01-01 00:00:00                     73.9
# 26                 Albania  2007-01-01 00:00:00                     74.1
# 27                 Albania  2008-01-01 00:00:00                     74.2
# 28                 Albania  2009-01-01 00:00:00                     74.4
# 29                 Albania  2010-01-01 00:00:00                     74.7
# ...                    ...                  ...                      ...
# 2524       Solomon Islands  2004-01-01 00:00:00                     67.9
# 2525       Solomon Islands  2005-01-01 00:00:00                     68.2
# 2526       Solomon Islands  2006-01-01 00:00:00                     68.5
# 2527       Solomon Islands  2007-01-01 00:00:00                     68.5
# 2528       Solomon Islands  2008-01-01 00:00:00                     69.1
# 2529       Solomon Islands  2009-01-01 00:00:00                     69.3
# 2530       Solomon Islands  2010-01-01 00:00:00                     69.7
# 2531       Solomon Islands  2011-01-01 00:00:00                     70.0
# 2532       Solomon Islands  2012-01-01 00:00:00                     70.2
# 2533       Solomon Islands  2013-01-01 00:00:00                     70.4
# 2534       Solomon Islands  2014-01-01 00:00:00                     70.5
# 2535       Solomon Islands  2015-01-01 00:00:00                     70.9
# 2536       Solomon Islands  2016-01-01 00:00:00                     71.1
# 2537               Somalia  2007-01-01 00:00:00                     51.7
# 2538               Somalia  2008-01-01 00:00:00                     52.2
# 2539               Somalia  2009-01-01 00:00:00                     52.7
# 2540               Somalia  2010-01-01 00:00:00                     53.0
# 2541               Somalia  2011-01-01 00:00:00                     53.7
# 2542               Somalia  2012-01-01 00:00:00                     53.9
# 2543               Somalia  2013-01-01 00:00:00                     54.8
# 2544               Somalia  2014-01-01 00:00:00                     55.1
# 2545               Somalia  2015-01-01 00:00:00                     55.6
# 2546               Somalia  2016-01-01 00:00:00                     55.4
# 2547                 Spain  0000-00-00 00:00:00                     83.1
# 2548             Sri Lanka  0000-00-00 00:00:00                     75.3
# 2549                 Sudan  0000-00-00 00:00:00                     65.1
# 2550              Suriname  0000-00-00 00:00:00                     71.8
# 2551                Sweden  0000-00-00 00:00:00                     82.4
# 2552           Switzerland  0000-00-00 00:00:00                     83.3
# 2553  Syrian Arab Republic  0000-00-00 00:00:00                     63.8
#
#       LEX at birth Male  LEX at birth Female  LEX at age 60 Both sexes  \
# 0                  61.0                 64.5                      16.3
# 1                  54.6                 57.3                      15.1
# 2                  55.3                 57.9                      15.2
# 3                  56.5                 58.5                      15.2
# 4                  56.9                 59.1                      15.4
# 5                  57.4                 59.6                      15.4
# 6                  57.8                 60.1                      15.5
# 7                  58.0                 60.5                      15.6
# 8                  58.4                 61.0                      15.7
# 9                  59.0                 61.6                      15.8
# 10                 59.5                 62.1                      15.9
# 11                 59.9                 62.5                      15.9
# 12                 60.5                 63.1                      16.0
# 13                 60.9                 63.6                      16.1
# 14                 61.5                 64.1                      16.2
# 15                 61.7                 64.4                      16.2
# 16                 61.8                 64.7                      16.3
# 17                 61.0                 64.5                      16.3
# 18                 74.3                 78.6                      20.8
# 19                 70.4                 76.0                      18.9
# 20                 71.6                 76.7                      19.6
# 21                 71.4                 75.9                      19.1
# 22                 70.8                 75.2                      18.4
# 23                 71.0                 75.8                      18.6
# 24                 71.6                 75.6                      18.9
# 25                 71.8                 76.2                      19.0
# 26                 71.9                 76.4                      19.2
# 27                 72.1                 76.5                      19.4
# 28                 72.3                 76.7                      19.6
# 29                 72.5                 77.0                      19.8
# ...                 ...                  ...                       ...
# 2524               66.6                 69.2                      16.5
# 2525               66.9                 69.5                      16.6
# 2526               67.3                 69.8                      16.7
# 2527               67.2                 69.9                      16.8
# 2528               67.9                 70.4                      16.9
# 2529               68.0                 70.7                      17.0
# 2530               68.4                 71.1                      17.1
# 2531               68.7                 71.4                      17.2
# 2532               68.9                 71.6                      17.3
# 2533               69.1                 71.9                      17.4
# 2534               69.1                 72.0                      17.5
# 2535               69.5                 72.4                      17.6
# 2536               69.7                 72.7                      17.7
# 2537               50.1                 53.3                      15.9
# 2538               50.7                 53.8                      16.0
# 2539               51.2                 54.3                      16.0
# 2540               51.4                 54.7                      16.1
# 2541               52.1                 55.3                      16.1
# 2542               52.2                 55.6                      16.1
# 2543               53.4                 56.3                      16.2
# 2544               53.6                 56.7                      16.2
# 2545               54.1                 57.1                      16.3
# 2546               53.7                 57.3                      16.3
# 2547               80.3                 85.7                      25.4
# 2548               72.1                 78.5                      20.8
# 2549               63.4                 66.9                      17.9
# 2550               68.7                 75.1                      19.2
# 2551               80.6                 84.1                      24.6
# 2552               81.2                 85.2                      25.5
# 2553               59.4                 68.9                      18.5
#
#        LEX at age 60 Male   LEX at age 60 Female  HALE at birth Both sexes  \
# 0                    15.5                   17.1                      53.0
# 1                    14.5                   15.9                      46.9
# 2                    14.5                   15.9                       0.0
# 3                    14.5                   16.0                       0.0
# 4                    14.7                   16.1                       0.0
# 5                    14.7                   16.2                       0.0
# 6                    14.8                   16.3                      49.6
# 7                    14.9                   16.4                       0.0
# 8                    15.0                   16.5                       0.0
# 9                    15.0                   16.6                       0.0
# 10                   15.1                   16.6                       0.0
# 11                   15.2                   16.7                      51.6
# 12                   15.3                   16.8                       0.0
# 13                   15.3                   16.8                       0.0
# 14                   15.4                   16.9                       0.0
# 15                   15.4                   17.0                       0.0
# 16                   15.5                   17.1                      53.2
# 17                   15.5                   17.1                      53.0
# 18                   19.4                   22.3                      68.1
# 19                   17.3                   20.8                      64.9
# 20                   18.1                   21.3                       0.0
# 21                   17.7                   20.5                       0.0
# 22                   17.1                   19.8                       0.0
# 23                   17.2                   20.1                       0.0
# 24                   17.7                   20.4                      65.4
# 25                   17.8                   20.3                       0.0
# 26                   17.9                   20.5                       0.0
# 27                   18.1                   20.7                       0.0
# 28                   18.4                   20.9                       0.0
# 29                   18.6                   21.2                      66.4
# ...                   ...                    ...                       ...
# 2524                 15.8                   17.4                       0.0
# 2525                 15.9                   17.5                      59.3
# 2526                 16.0                   17.6                       0.0
# 2527                 16.0                   17.6                       0.0
# 2528                 16.2                   17.8                       0.0
# 2529                 16.2                   17.9                       0.0
# 2530                 16.4                   18.0                      60.6
# 2531                 16.5                   18.2                       0.0
# 2532                 16.5                   18.3                       0.0
# 2533                 16.6                   18.4                       0.0
# 2534                 16.6                   18.4                       0.0
# 2535                 16.8                   18.6                      61.7
# 2536                 16.8                   18.7                      61.9
# 2537                 15.3                   16.5                       0.0
# 2538                 15.4                   16.5                       0.0
# 2539                 15.5                   16.6                       0.0
# 2540                 15.5                   16.6                      47.6
# 2541                 15.6                   16.6                       0.0
# 2542                 15.6                   16.7                       0.0
# 2543                 15.7                   16.7                       0.0
# 2544                 15.7                   16.8                       0.0
# 2545                 15.8                   16.8                      50.1
# 2546                 15.7                   16.8                      50.0
# 2547                 23.1                   27.5                      73.8
# 2548                 19.5                   21.9                      66.8
# 2549                 17.3                   18.5                      55.7
# 2550                 17.1                   21.2                      63.2
# 2551                 23.2                   25.8                      72.4
# 2552                 23.8                   26.9                      73.5
# 2553                 17.5                   19.4                      55.8
#
#       HALE at birth Male  HALE at birth Female  HALE at age 60 Both sexes  \
# 0                   52.1                  54.1                       11.3
# 1                   46.2                  47.7                       10.3
# 2                    0.0                   0.0                        0.0
# 3                    0.0                   0.0                        0.0
# 4                    0.0                   0.0                        0.0
# 5                    0.0                   0.0                        0.0
# 6                   49.1                  50.2                       10.7
# 7                    0.0                   0.0                        0.0
# 8                    0.0                   0.0                        0.0
# 9                    0.0                   0.0                        0.0
# 10                   0.0                   0.0                        0.0
# 11                  50.9                  52.3                       11.0
# 12                   0.0                   0.0                        0.0
# 13                   0.0                   0.0                        0.0
# 14                   0.0                   0.0                        0.0
# 15                   0.0                   0.0                        0.0
# 16                  52.6                  54.1                       11.2
# 17                  52.1                  54.1                       11.3
# 18                  66.7                  69.6                       16.3
# 19                  62.9                  67.2                       14.7
# 20                   0.0                   0.0                        0.0
# 21                   0.0                   0.0                        0.0
# 22                   0.0                   0.0                        0.0
# 23                   0.0                   0.0                        0.0
# 24                  64.0                  67.0                       14.7
# 25                   0.0                   0.0                        0.0
# 26                   0.0                   0.0                        0.0
# 27                   0.0                   0.0                        0.0
# 28                   0.0                   0.0                        0.0
# 29                  64.7                  68.2                       15.4
# ...                  ...                   ...                        ...
# 2524                 0.0                   0.0                        0.0
# 2525                59.0                  59.7                       12.1
# 2526                 0.0                   0.0                        0.0
# 2527                 0.0                   0.0                        0.0
# 2528                 0.0                   0.0                        0.0
# 2529                 0.0                   0.0                        0.0
# 2530                60.2                  61.1                       12.6
# 2531                 0.0                   0.0                        0.0
# 2532                 0.0                   0.0                        0.0
# 2533                 0.0                   0.0                        0.0
# 2534                 0.0                   0.0                        0.0
# 2535                61.2                  62.3                       13.0
# 2536                61.4                  62.5                       13.1
# 2537                 0.0                   0.0                        0.0
# 2538                 0.0                   0.0                        0.0
# 2539                 0.0                   0.0                        0.0
# 2540                46.5                  48.8                       12.3
# 2541                 0.0                   0.0                        0.0
# 2542                 0.0                   0.0                        0.0
# 2543                 0.0                   0.0                        0.0
# 2544                 0.0                   0.0                        0.0
# 2545                49.1                  51.1                       12.7
# 2546                48.8                  51.3                       12.7
# 2547                72.2                  75.4                       20.3
# 2548                64.4                  69.3                       16.1
# 2549                54.7                  56.8                       13.0
# 2550                61.0                  65.4                       14.7
# 2551                71.5                  73.4                       19.2
# 2552                72.4                  74.5                       20.1
# 2553                52.5                  59.5                       13.9
#
#       HALE at age 60 Male  HALE at age 60 Female
# 0                    10.9                   11.7
# 1                    10.1                   10.6
# 2                     0.0                    0.0
# 3                     0.0                    0.0
# 4                     0.0                    0.0
# 5                     0.0                    0.0
# 6                    10.4                   11.0
# 7                     0.0                    0.0
# 8                     0.0                    0.0
# 9                     0.0                    0.0
# 10                    0.0                    0.0
# 11                   10.6                   11.3
# 12                    0.0                    0.0
# 13                    0.0                    0.0
# 14                    0.0                    0.0
# 15                    0.0                    0.0
# 16                   10.8                   11.6
# 17                   10.9                   11.7
# 18                   15.3                   17.4
# 19                   13.5                   16.1
# 20                    0.0                    0.0
# 21                    0.0                    0.0
# 22                    0.0                    0.0
# 23                    0.0                    0.0
# 24                   13.8                   15.8
# 25                    0.0                    0.0
# 26                    0.0                    0.0
# 27                    0.0                    0.0
# 28                    0.0                    0.0
# 29                   14.5                   16.4
# ...                   ...                    ...
# 2524                  0.0                    0.0
# 2525                 11.8                   12.5
# 2526                  0.0                    0.0
# 2527                  0.0                    0.0
# 2528                  0.0                    0.0
# 2529                  0.0                    0.0
# 2530                 12.3                   13.0
# 2531                  0.0                    0.0
# 2532                  0.0                    0.0
# 2533                  0.0                    0.0
# 2534                  0.0                    0.0
# 2535                 12.6                   13.5
# 2536                 12.7                   13.6
# 2537                  0.0                    0.0
# 2538                  0.0                    0.0
# 2539                  0.0                    0.0
# 2540                 12.0                   12.5
# 2541                  0.0                    0.0
# 2542                  0.0                    0.0
# 2543                  0.0                    0.0
# 2544                  0.0                    0.0
# 2545                 12.5                   12.8
# 2546                 12.5                   12.9
# 2547                 18.7                   21.8
# 2548                 15.1                   16.9
# 2549                 12.7                   13.3
# 2550                 13.2                   16.0
# 2551                 18.2                   20.1
# 2552                 19.0                   21.2
# 2553                 13.3                   14.5
#
# [2554 rows x 14 columns]

# %%
file_one = "assets/data/hale.csv"

# %%
file_one_df = pd.read_csv(file_one, encoding="ISO-8859-1")
file_one_df.head()
# Out:
#                Country  At Birth Both sexes 2016 At Birth Both sexes 2015  \
# 0          Afghanistan                      53.0                     53.2
# 1              Albania                      68.1                     67.8
# 2              Algeria                      65.5                     65.3
# 3               Angola                      55.8                     55.3
# 4  Antigua and Barbuda                      67.0                     66.9
#
#    At Birth Both sexes 2010  At Birth Both sexes 2005  \
# 0                      51.6                      49.6
# 1                      66.4                      65.4
# 2                      64.5                      62.8
# 3                      51.8                      46.7
# 4                      66.5                      65.4
#
#   At Birth Both sexes 2000  At Birth Male 2016 At Birth Male 2015  \
# 0                     46.9                52.1               52.6
# 1                     64.9                66.7               66.5
# 2                     60.7                65.4               65.2
# 3                     41.9                53.8               53.3
# 4                     64.6                65.2               65.1
#
#    At Birth Male 2010  At Birth Male 2005              ...                \
# 0                50.9                49.1              ...
# 1                64.7                64.0              ...
# 2                64.4                62.7              ...
# 3                49.9                44.9              ...
# 4                64.8                64.0              ...
#
#   At age 60 (years) Male 2016  At age 60 (years) Male 2015  \
# 0                        10.9                         10.8
# 1                        15.3                         15.1
# 2                        15.7                         15.6
# 3                        12.9                         12.8
# 4                        14.0                           14
#
#   At age 60 (years) Male 2010  At age 60 (years) Male 2005  \
# 0                        10.6                         10.4
# 1                        14.5                         13.8
# 2                        15.1                         14.4
# 3                        12.1                         11.3
# 4                        14.6                         14.4
#
#    At age 60 (years) Male 2000 At age 60 (years) Female 2016  \
# 0                         10.1                          11.7
# 1                         13.5                          17.4
# 2                         13.2                          15.8
# 3                         10.5                          14.3
# 4                         13.1                          17.1
#
#    At age 60 (years) Female 2015 At age 60 (years) Female 2010  \
# 0                           11.6                          11.3
# 1                           16.9                          16.4
# 2                           15.7                          15.1
# 3                           14.2                          13.4
# 4                             17                          16.7
#
#    At age 60 (years) Female 2005  At age 60 (years) Female 2000
# 0                           11.0                           10.6
# 1                           15.8                           16.1
# 2                           14.5                           13.7
# 3                           12.6                           11.8
# 4                           15.9                             16
#
# [5 rows x 31 columns]

# %%
selected_file_one = file_one_df.loc[:, ["Country","At Birth Both sexes 2016", "At Birth Male 2016", "At Birth Female 2016"]]

# %%
renamed_one_df = selected_file_one.rename(columns={"At Birth Both sexes 2016":"Both sexes HALE", "At Birth Male 2016":"Male HALE","At Birth Female 2016":"Female HALE" })
renamed_one_df.head()
# Out:
#                Country  Both sexes HALE  Male HALE  Female HALE
# 0          Afghanistan             53.0       52.1         54.1
# 1              Albania             68.1       66.7         69.6
# 2              Algeria             65.5       65.4         65.6
# 3               Angola             55.8       53.8         57.7
# 4  Antigua and Barbuda             67.0       65.2         68.8

# %%
file_two = "assets/data/glucose.csv"
file_two_df = pd.read_csv(file_two, encoding="ISO-8859-1")

# %%
selected_file_two = file_two_df.loc[:, ["Country","Both_sexes_2014", "Male_2014", "Female_2014"]]

# %%
renamed_two_df = selected_file_two.rename(columns={"Both_sexes_2014":"Both sexes Glucose", "Male_2014":"Male Glucose","Female_2014":"Female Glucose" })

# %%
renamed_two_df["Both sexes Glucose"]= renamed_two_df["Both sexes Glucose"].str.split("[", n = 1, expand = True) 
renamed_two_df["Male Glucose"]= renamed_two_df["Male Glucose"].str.split("[", n = 1, expand = True)
renamed_two_df["Female Glucose"]= renamed_two_df["Female Glucose"].str.split("[", n = 1, expand = True)
renamed_two_df.head()
# Out:
#        Country Both sexes Glucose Male Glucose Female Glucose
# 0  Afghanistan              11.9         11.6           12.2
# 1      Albania               7.4          7.7            7.1
# 2      Algeria              12.4         12.3           12.6
# 3      Andorra               6.9          8.1            5.8
# 4       Angola               8.2          8.5            7.8

# %%
renamed_two_df.to_csv("assets/data/glucoselevel2014.csv", index=False, header=True)

# %%
file_three = "assets/data/lexbycountry.csv"
file_three_df = pd.read_csv(file_three, encoding="ISO-8859-1")

# %%
selected_file_three = file_three_df.loc[:, ["Country","Year", "LEX_at_birth_Both_sexes", "LEX_at_birth_Male", "LEX_at_birth_Female"]]

# %%
renamed_three_df = selected_file_three.rename(columns={"LEX_at_birth_Both_sexes":"Both sexes LEX", "LEX_at_birth_Male":"Male LEX","LEX_at_birth_Female":"Female LEX" })

# %%
renamed_three_df_filtered = renamed_three_df[renamed_three_df['Year'] >= 2016] 
renamed_three_df_filtered.head()
# Out:
#                 Country  Year Both sexes LEX Male LEX Female LEX
# 0           Afghanistan  2016           62.7       61       64.5
# 17              Albania  2016           76.4     74.3       78.6
# 34              Algeria  2016           76.4     75.4       77.4
# 51               Angola  2016           62.6     60.3       64.9
# 68  Antigua and Barbuda  2016             75     72.5       77.5

# %%
file_four = "assets/data/NCDdeaths.csv"
file_four_df= pd.read_csv(file_four, encoding="ISO-8859-1")

# %%
file_four_df.columns = file_four_df.iloc[0]
file_four_df_header = file_four_df[1:]

# %%
renamed_four_df = file_four_df_header.rename(columns={"Both sexes":"Both sexes NCD", "Male":"Male NCD","Female":"Female NCD" })
renamed_four_df.head()
# Out:
# 0      Country  Year                                 Causes Both sexes NCD  \
# 1  Afghanistan  2016                    Malignant neoplasms          19965
# 2  Afghanistan  2016                      Diabetes mellitus           7056
# 3  Afghanistan  2016                Cardiovascular diseases          51244
# 4  Afghanistan  2016  Chronic obstructive pulmonary disease           6715
# 5  Afghanistan  2015                    Malignant neoplasms          19290
#
# 0 Male NCD Female NCD
# 1    10702       9263
# 2     2437       4620
# 3    26828      24416
# 4     3560       3154
# 5    10319       8972

# %%
renamed_four_df.dtypes
# Out:
# 0
# Country           object
# Year              object
# Causes            object
# Both sexes NCD    object
# Male NCD          object
# Female NCD        object
# dtype: object

# %%
renamed_four_df["Year"] = pd.to_numeric(
    renamed_four_df["Year"])
renamed_four_df.dtypes
# Out:
# 0
# Country           object
# Year               int64
# Causes            object
# Both sexes NCD    object
# Male NCD          object
# Female NCD        object
# dtype: object

# %%
renamed_four_df_filtered = renamed_four_df[renamed_four_df['Year'] >= 2016] 
renamed_four_df_filtered.head()
# Out:
# 0       Country  Year                                 Causes Both sexes NCD  \
# 1   Afghanistan  2016                    Malignant neoplasms          19965
# 2   Afghanistan  2016                      Diabetes mellitus           7056
# 3   Afghanistan  2016                Cardiovascular diseases          51244
# 4   Afghanistan  2016  Chronic obstructive pulmonary disease           6715
# 21      Albania  2016                    Malignant neoplasms           5138
#
# 0  Male NCD Female NCD
# 1     10702       9263
# 2      2437       4620
# 3     26828      24416
# 4      3560       3154
# 21     2903       2235

# %%
renamed_four_df_filtered.to_csv("assets/data/NCD2016.csv", index=False, header=True)

# %%
file_four_NCD = "assets/data/NCD.csv"
file_four_NCD_df= pd.read_csv(file_four_NCD, encoding="ISO-8859-1")
file_four_NCD_df
# Out:
#                              Unnamed: 0 Unnamed: 1  \
# 0                               Country       Year
# 1                           Afghanistan       2016
# 2                           Afghanistan       2015
# 3                           Afghanistan       2010
# 4                           Afghanistan       2005
# 5                           Afghanistan       2000
# 6                               Albania       2016
# 7                               Albania       2015
# 8                               Albania       2010
# 9                               Albania       2005
# 10                              Albania       2000
# 11                              Algeria       2016
# 12                              Algeria       2015
# 13                              Algeria       2010
# 14                              Algeria       2005
# 15                              Algeria       2000
# 16                               Angola       2016
# 17                               Angola       2015
# 18                               Angola       2010
# 19                               Angola       2005
# 20                               Angola       2000
# 21                  Antigua and Barbuda       2016
# 22                  Antigua and Barbuda       2015
# 23                  Antigua and Barbuda       2010
# 24                  Antigua and Barbuda       2005
# 25                  Antigua and Barbuda       2000
# 26                            Argentina       2016
# 27                            Argentina       2015
# 28                            Argentina       2010
# 29                            Argentina       2005
# ..                                  ...        ...
# 886                             Vanuatu       2016
# 887                             Vanuatu       2015
# 888                             Vanuatu       2010
# 889                             Vanuatu       2005
# 890                             Vanuatu       2000
# 891  Venezuela (Bolivarian Republic of)       2016
# 892  Venezuela (Bolivarian Republic of)       2015
# 893  Venezuela (Bolivarian Republic of)       2010
# 894  Venezuela (Bolivarian Republic of)       2005
# 895  Venezuela (Bolivarian Republic of)       2000
# 896                            Viet Nam       2016
# 897                            Viet Nam       2015
# 898                            Viet Nam       2010
# 899                            Viet Nam       2005
# 900                            Viet Nam       2000
# 901                               Yemen       2016
# 902                               Yemen       2015
# 903                               Yemen       2010
# 904                               Yemen       2005
# 905                               Yemen       2000
# 906                              Zambia       2016
# 907                              Zambia       2015
# 908                              Zambia       2010
# 909                              Zambia       2005
# 910                              Zambia       2000
# 911                            Zimbabwe       2016
# 912                            Zimbabwe       2015
# 913                            Zimbabwe       2010
# 914                            Zimbabwe       2005
# 915                            Zimbabwe       2000
#
#     Probability (%) of dying between age 30 and exact age 70 from any of cardiovascular disease, cancer, diabetes, or chronic respiratory disease  \
# 0                                           Both sexes
# 1                                                 29.8
# 2                                                 29.8
# 3                                                 31.7
# 4                                                 34.1
# 5                                                 34.4
# 6                                                 17.0
# 7                                                 17.4
# 8                                                 18.6
# 9                                                 18.8
# 10                                                19.4
# 11                                                14.2
# 12                                                14.4
# 13                                                15.4
# 14                                                17.6
# 15                                                21.1
# 16                                                16.5
# 17                                                16.9
# 18                                                18.1
# 19                                                21.3
# 20                                                24.0
# 21                                                22.6
# 22                                                22.6
# 23                                                21.6
# 24                                                21.6
# 25                                                23.4
# 26                                                15.8
# 27                                                16.1
# 28                                                17.8
# 29                                                18.9
# ..                                                 ...
# 886                                               23.3
# 887                                               23.7
# 888                                               24.9
# 889                                               25.6
# 890                                               27.9
# 891                                               18.1
# 892                                               18.2
# 893                                               18.4
# 894                                               19.4
# 895                                               21.6
# 896                                               17.1
# 897                                               17.3
# 898                                               18.0
# 899                                               18.4
# 900                                               18.6
# 901                                               30.6
# 902                                               30.7
# 903                                               31.9
# 904                                               32.6
# 905                                               33.1
# 906                                               17.9
# 907                                               18.0
# 908                                               19.9
# 909                                               21.1
# 910                                               23.2
# 911                                               19.3
# 912                                               19.4
# 913                                               21.1
# 914                                               22.5
# 915                                               21.6
#
#     Probability (%) of dying between age 30 and exact age 70 from any of cardiovascular disease, cancer, diabetes, or chronic respiratory disease.1  \
# 0                                                 Male
# 1                                                 31.8
# 2                                                 31.9
# 3                                                 34.1
# 4                                                 36.5
# 5                                                 36.6
# 6                                                 20.7
# 7                                                 20.9
# 8                                                 22.3
# 9                                                 22.1
# 10                                                23.1
# 11                                                15.2
# 12                                                15.4
# 13                                                16.4
# 14                                                18.9
# 15                                                23.1
# 16                                                17.2
# 17                                                17.6
# 18                                                18.6
# 19                                                21.5
# 20                                                24.2
# 21                                                25.2
# 22                                                25.5
# 23                                                24.2
# 24                                                21.8
# 25                                                26.8
# 26                                                19.7
# 27                                                20.2
# 28                                                22.8
# 29                                                24.6
# ..                                                 ...
# 886                                               27.2
# 887                                               27.6
# 888                                               28.2
# 889                                               28.4
# 890                                               30.8
# 891                                               21.8
# 892                                               21.9
# 893                                               22.0
# 894                                               22.8
# 895                                               24.9
# 896                                               23.4
# 897                                               23.6
# 898                                               24.8
# 899                                               25.2
# 900                                               25.3
# 901                                               33.2
# 902                                               33.3
# 903                                               34.5
# 904                                               35.2
# 905                                               35.7
# 906                                               18.5
# 907                                               18.6
# 908                                               19.8
# 909                                               20.4
# 910                                               21.8
# 911                                               18.7
# 912                                               18.6
# 913                                               20.5
# 914                                               22.1
# 915                                               21.6
#
#     Probability (%) of dying between age 30 and exact age 70 from any of cardiovascular disease, cancer, diabetes, or chronic respiratory disease.2
# 0                                               Female
# 1                                                 27.7
# 2                                                 27.8
# 3                                                 29.4
# 4                                                 31.6
# 5                                                 32.1
# 6                                                 13.1
# 7                                                 13.7
# 8                                                 14.6
# 9                                                 15.0
# 10                                                14.9
# 11                                                13.2
# 12                                                13.3
# 13                                                14.4
# 14                                                16.2
# 15                                                19.1
# 16                                                16.0
# 17                                                16.3
# 18                                                17.8
# 19                                                21.2
# 20                                                23.8
# 21                                                20.0
# 22                                                19.7
# 23                                                19.3
# 24                                                21.3
# 25                                                20.8
# 26                                                12.2
# 27                                                12.4
# 28                                                13.2
# 29                                                13.6
# ..                                                 ...
# 886                                               19.2
# 887                                               19.6
# 888                                               21.1
# 889                                               22.3
# 890                                               24.4
# 891                                               14.5
# 892                                               14.6
# 893                                               14.9
# 894                                               16.2
# 895                                               18.3
# 896                                               11.5
# 897                                               11.6
# 898                                               12.1
# 899                                               12.4
# 900                                               12.7
# 901                                               28.2
# 902                                               28.2
# 903                                               29.4
# 904                                               30.1
# 905                                               30.5
# 906                                               17.4
# 907                                               17.6
# 908                                               20.0
# 909                                               21.7
# 910                                               24.4
# 911                                               19.8
# 912                                               19.9
# 913                                               21.5
# 914                                               22.9
# 915                                               21.7
#
# [916 rows x 5 columns]

# %%
file_four_NCD_df["Unnamed: 1"] = pd.to_numeric(
    file_four_NCD_df["Unnamed: 1"])
file_four_NCD_df.dtypes
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# pandas/_libs/src/inference.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "Year"
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-25-5e60c5187a1e> in <module>()
#       1 file_four_NCD_df["Unnamed: 1"] = pd.to_numeric(
# ----> 2     file_four_NCD_df["Unnamed: 1"])
#       3 file_four_NCD_df.dtypes
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/tools/numeric.py in to_numeric(arg, errors, downcast)
#     131             coerce_numeric = False if errors in ('ignore', 'raise') else True
#     132             values = lib.maybe_convert_numeric(values, set(),
# --> 133                                                coerce_numeric=coerce_numeric)
#     134
#     135     except Exception:
#
# pandas/_libs/src/inference.pyx in pandas._libs.lib.maybe_convert_numeric()
#
# ValueError: Unable to parse string "Year" at position 0

# %%
renamed_file_four_NCD_df_filtered = file_four_NCD_df[file_four_NCD_df['Unnamed: 1'] >= 2016] 
renamed_file_four_NCD_df_filtered.head()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-26-b225cd53e0d5> in <module>()
# ----> 1 renamed_file_four_NCD_df_filtered = file_four_NCD_df[file_four_NCD_df['Unnamed: 1'] >= 2016]
#       2 renamed_file_four_NCD_df_filtered.head()
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/ops.py in wrapper(self, other, axis)
#    1281
#    1282             with np.errstate(all='ignore'):
# -> 1283                 res = na_op(values, other)
#    1284             if is_scalar(res):
#    1285                 raise TypeError('Could not compare {typ} type with Series'
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/ops.py in na_op(x, y)
#    1141
#    1142         elif is_object_dtype(x.dtype):
# -> 1143             result = _comp_method_OBJECT_ARRAY(op, x, y)
#    1144
#    1145         elif is_datetimelike_v_numeric(x, y):
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/ops.py in _comp_method_OBJECT_ARRAY(op, x, y)
#    1120         result = libops.vec_compare(x, y, op)
#    1121     else:
# -> 1122         result = libops.scalar_compare(x, y, op)
#    1123     return result
#    1124
#
# pandas/_libs/ops.pyx in pandas._libs.ops.scalar_compare()
#
# TypeError: '>=' not supported between instances of 'str' and 'int'

# %%
file_five = "assets/data/obesity.csv"
file_five_df = pd.read_csv(file_five, encoding="ISO-8859-1")

# %%
selected_file_five = file_five_df.loc[:, ["Country","Both_sexes_2016", "Male_2016", "Female_2016"]]

# %%
renamed_five_df = selected_file_five.rename(columns={"Both_sexes_2016":"Both sexes Obesity", "Male_2016":"Male Obesity","Female_2016":"Female Obesity"})
renamed_five_df.head()
# Out:
#        Country                Both sexes Obesity                Male Obesity  \
# 0  Afghanistan                     5.5 [3.4-8.1]               3.2 [1.3-6.4]
# 1      Albania                  21.7 [17.0-26.7]            21.6 [14.8-29.0]
# 2      Algeria  27.4_[22.5-32.7]_Both_sexes_2016  19.9_[13.6-27.1]_Male_2016
# 3      Andorra                  25.6 [20.1-31.3]            25.9 [18.0-34.3]
# 4       Angola                    8.2 [5.1-12.2]               4.0 [1.6-7.9]
#
#                  Female Obesity
# 0                7.6 [4.3-12.4]
# 1              21.8 [15.3-28.9]
# 2  34.9_[27.6-42.7]_Female_2016
# 3              25.3 [17.7-33.7]
# 4               12.1 [6.8-19.0]

# %%
renamed_five_df["Both sexes Obesity"]= renamed_five_df["Both sexes Obesity"].str.split("[", n = 1, expand = True) 
renamed_five_df["Male Obesity"]= renamed_five_df["Male Obesity"].str.split("[", n = 1, expand = True)
renamed_five_df["Female Obesity"]= renamed_five_df["Female Obesity"].str.split("[", n = 1, expand = True)
renamed_five_df["Both sexes Obesity"]= renamed_five_df["Both sexes Obesity"].str.split("_", n = 1, expand = True) 
renamed_five_df["Male Obesity"]= renamed_five_df["Male Obesity"].str.split("_", n = 1, expand = True)
renamed_five_df["Female Obesity"]= renamed_five_df["Female Obesity"].str.split("_", n = 1, expand = True)
renamed_five_df.head()
# Out:
#        Country Both sexes Obesity Male Obesity Female Obesity
# 0  Afghanistan               5.5          3.2            7.6
# 1      Albania              21.7         21.6           21.8
# 2      Algeria               27.4         19.9           34.9
# 3      Andorra              25.6         25.9           25.3
# 4       Angola               8.2          4.0           12.1

# %%
renamed_five_df.to_csv("assets/data/obesity2016.csv", index=False, header=True)

# %%
file_six = "assets/data/daly.csv"
file_six_df = pd.read_csv(file_six, encoding="ISO-8859-1")
file_six_df
# Out:
#          Sex  GHE code Unnamed: 2  \
# 0        NaN       NaN        NaN
# 1        NaN       NaN        NaN
# 2    Persons       NaN        NaN
# 3    Persons       0.0        NaN
# 4    Persons      10.0         I.
# 5    Persons      20.0        NaN
# 6    Persons      30.0        NaN
# 7    Persons      40.0        NaN
# 8    Persons      50.0        NaN
# 9    Persons      60.0        NaN
# 10   Persons      70.0        NaN
# 11   Persons      80.0        NaN
# 12   Persons      85.0        NaN
# 13   Persons      90.0        NaN
# 14   Persons     100.0        NaN
# 15   Persons     110.0        NaN
# 16   Persons     120.0        NaN
# 17   Persons     130.0        NaN
# 18   Persons     140.0        NaN
# 19   Persons     150.0        NaN
# 20   Persons     160.0        NaN
# 21   Persons     170.0        NaN
# 22   Persons     180.0        NaN
# 23   Persons     185.0        NaN
# 24   Persons     186.0        NaN
# 25   Persons     190.0        NaN
# 26   Persons     200.0        NaN
# 27   Persons     205.0        NaN
# 28   Persons     210.0        NaN
# 29   Persons     220.0        NaN
# ..       ...       ...        ...
# 624  Females    1370.0        NaN
# 625  Females    1380.0        NaN
# 626  Females    1390.0        NaN
# 627  Females    1400.0        NaN
# 628  Females    1410.0        NaN
# 629  Females    1420.0        NaN
# 630  Females    1430.0        NaN
# 631  Females    1440.0        NaN
# 632  Females    1450.0        NaN
# 633  Females    1460.0        NaN
# 634  Females    1470.0        NaN
# 635  Females    1480.0        NaN
# 636  Females    1490.0        NaN
# 637  Females    1500.0        NaN
# 638  Females    1502.0        NaN
# 639  Females    1505.0        NaN
# 640  Females    1510.0       III.
# 641  Females    1520.0        NaN
# 642  Females    1530.0        NaN
# 643  Females    1540.0        NaN
# 644  Females    1550.0        NaN
# 645  Females    1560.0        NaN
# 646  Females    1570.0        NaN
# 647  Females    1575.0        NaN
# 648  Females    1580.0        NaN
# 649  Females    1590.0        NaN
# 650  Females    1600.0        NaN
# 651  Females    1610.0        NaN
# 652  Females    1620.0        NaN
# 653  Females    1630.0        NaN
#
#                                              GHE cause  \
# 0                                                  NaN
# 1                                                  NaN
# 2                               Population ('000) (2)
# 3                                           All Causes
# 4    Communicable, maternal, perinatal and nutritio...
# 5                                                   A.
# 6                                                  NaN
# 7                                                  NaN
# 8                                                  NaN
# 9                                                  NaN
# 10                                                 NaN
# 11                                                 NaN
# 12                                                 NaN
# 13                                                 NaN
# 14                                                 NaN
# 15                                                 NaN
# 16                                                 NaN
# 17                                                 NaN
# 18                                                 NaN
# 19                                                 NaN
# 20                                                 NaN
# 21                                                 NaN
# 22                                                 NaN
# 23                                                 NaN
# 24                                                 NaN
# 25                                                 NaN
# 26                                                 NaN
# 27                                                 NaN
# 28                                                 NaN
# 29                                                 NaN
# ..                                                 ...
# 624                                                NaN
# 625                                                NaN
# 626                                                NaN
# 627                                                 N.
# 628                                                NaN
# 629                                                NaN
# 630                                                NaN
# 631                                                NaN
# 632                                                NaN
# 633                                                NaN
# 634                                                 O.
# 635                                                NaN
# 636                                                NaN
# 637                                                NaN
# 638                                                NaN
# 639                                                 P.
# 640                                           Injuries
# 641                                                 A.
# 642                                                NaN
# 643                                                NaN
# 644                                                NaN
# 645                                                NaN
# 646                                                NaN
# 647                                                NaN
# 648                                                NaN
# 649                                                NaN
# 650                                                 B.
# 651                                                NaN
# 652                                                NaN
# 653                                                NaN
#
#                             Unnamed: 4  \
# 0                                  NaN
# 1                                  NaN
# 2                                  NaN
# 3                                  NaN
# 4                                  NaN
# 5    Infectious and parasitic diseases
# 6                                   1.
# 7                                   2.
# 8                                  NaN
# 9                                  NaN
# 10                                 NaN
# 11                                 NaN
# 12                                 NaN
# 13                                 NaN
# 14                                  3.
# 15                                  4.
# 16                                  5.
# 17                                 NaN
# 18                                 NaN
# 19                                 NaN
# 20                                 NaN
# 21                                  6.
# 22                                  7.
# 23                                  8.
# 24                                 NaN
# 25                                 NaN
# 26                                 NaN
# 27                                 NaN
# 28                                  9.
# 29                                 NaN
# ..                                 ...
# 624                                 3.
# 625                                 4.
# 626                                 5.
# 627               Congenital anomalies
# 628                                 1.
# 629                                 2.
# 630                                 3.
# 631                                 4.
# 632                                 5.
# 633                                 6.
# 634                    Oral conditions
# 635                                 1.
# 636                                 2.
# 637                                 3.
# 638                                 4.
# 639       Sudden infant death syndrome
# 640                                NaN
# 641             Unintentional injuries
# 642                                 1.
# 643                                 2.
# 644                                 3.
# 645                                 4.
# 646                                 5.
# 647                                 6.
# 648                                 7.
# 649                                 8.
# 650               Intentional injuries
# 651                                 1.
# 652                                 2.
# 653                                 3.
#
#                                      Unnamed: 5  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# 5                                           NaN
# 6                                  Tuberculosis
# 7                            STDs excluding HIV
# 8                                            a.
# 9                                            b.
# 10                                           c.
# 11                                           d.
# 12                                           e.
# 13                                           f.
# 14                                     HIV/AIDS
# 15                          Diarrhoeal diseases
# 16                   Childhood-cluster diseases
# 17                                           a.
# 18                                           b.
# 19                                           c.
# 20                                           d.
# 21                                   Meningitis
# 22                                 Encephalitis
# 23                                    Hepatitis
# 24                                           a.
# 25                                           b.
# 26                                           c.
# 27                                           d.
# 28                Parasitic and vector diseases
# 29                                           a.
# ..                                          ...
# 624                                        Gout
# 625                          Back and neck pain
# 626             Other musculoskeletal disorders
# 627                                         NaN
# 628                         Neural tube defects
# 629                  Cleft lip and cleft palate
# 630                               Down syndrome
# 631                  Congenital heart anomalies
# 632                 Other chromosomal anomalies
# 633                  Other congenital anomalies
# 634                                         NaN
# 635                               Dental caries
# 636                         Periodontal disease
# 637                                  Edentulism
# 638                        Other oral disorders
# 639                                         NaN
# 640                                         NaN
# 641                                         NaN
# 642                                 Road injury
# 643                                  Poisonings
# 644                                       Falls
# 645               Fire, heat and hot substances
# 646                                    Drowning
# 647               Exposure to mechanical forces
# 648                           Natural disasters
# 649                Other unintentional injuries
# 650                                         NaN
# 651                                   Self-harm
# 652                      Interpersonal violence
# 653  Collective violence and legal intervention
#
#     Member State\n(See Notes for explanation of colour codes) Afghanistan  \
# 0                                           ISO-3 Code                AFG
# 1                                                  NaN                  4
# 2                                                  NaN            34,656
# 3                                                  NaN            18144.4
# 4                                                  NaN             7896.1
# 5                                                  NaN             2336.7
# 6                                                  NaN              504.6
# 7                                                  NaN              232.7
# 8                                             Syphilis              198.3
# 9                                            Chlamydia                4.6
# 10                                          Gonorrhoea               22.7
# 11                                      Trichomoniasis                0.5
# 12                                      Genital herpes                0.6
# 13                                          Other STDs                6.1
# 14                                                 NaN               19.6
# 15                                                 NaN              709.7
# 16                                                 NaN              207.2
# 17                                      Whooping cough               19.1
# 18                                          Diphtheria                1.9
# 19                                             Measles               68.1
# 20                                             Tetanus              118.1
# 21                                                 NaN              255.0
# 22                                                 NaN               19.8
# 23                                                 NaN               17.8
# 24                                   Acute hepatitis A                1.7
# 25                                   Acute hepatitis B               10.9
# 26                                   Acute hepatitis C                0.2
# 27                                   Acute hepatitis E                5.1
# 28                                                 NaN              234.6
# 29                                             Malaria               19.5
# ..                                                 ...                ...
# 624                                                NaN                0.4
# 625                                                NaN               89.8
# 626                                                NaN               50.0
# 627                                                NaN              327.2
# 628                                                NaN               50.4
# 629                                                NaN                0.6
# 630                                                NaN                5.2
# 631                                                NaN              109.7
# 632                                                NaN               14.4
# 633                                                NaN              147.0
# 634                                                NaN               27.1
# 635                                                NaN                4.3
# 636                                                NaN                5.7
# 637                                                NaN                9.3
# 638                                                NaN                7.8
# 639                                                NaN               18.5
# 640                                                NaN             1191.3
# 641                                                NaN              460.5
# 642                                                NaN               80.6
# 643                                                NaN               23.1
# 644                                                NaN              171.0
# 645                                                NaN               21.3
# 646                                                NaN               37.1
# 647                                                NaN               33.4
# 648                                                NaN                0.9
# 649                                                NaN               93.1
# 650                                                NaN              730.8
# 651                                                NaN               15.7
# 652                                                NaN               13.6
# 653                                                NaN              701.4
#
#      Albania   Algeria     ...      United States of America  Uruguay  \
# 0        ALB       DZA     ...                           USA      URY
# 1          3         4     ...                             1        2
# 2     2,926    40,606      ...                      322,180    3,444
# 3      883.9   10833.0     ...                      100384.2   1048.7
# 4       51.4    2334.2     ...                        5214.5     79.1
# 5       10.0     460.0     ...                        1699.0     26.0
# 6        0.3      97.7     ...                          16.2      2.5
# 7        1.2      59.7     ...                          67.1      0.9
# 8        0.1       9.7     ...                          13.9      0.3
# 9        0.3       6.6     ...                          11.1      0.2
# 10       0.3      32.8     ...                           8.3      0.1
# 11       0.1       0.7     ...                          10.8      0.1
# 12       0.1       1.1     ...                          14.1      0.1
# 13       0.2       8.7     ...                           8.8      0.1
# 14       1.1      10.2     ...                         396.7     10.2
# 15       2.2     154.8     ...                         274.1      3.5
# 16       0.2      10.2     ...                           2.3      0.3
# 17       0.0       0.2     ...                           2.2      0.3
# 18       0.0       0.1     ...                           0.1      0.0
# 19       0.0       5.9     ...                           0.0      0.0
# 20       0.2       4.0     ...                           0.0      0.0
# 21       1.5      32.3     ...                          41.6      0.5
# 22       1.6      19.2     ...                         170.8      4.9
# 23       0.1      13.9     ...                          69.8      0.3
# 24       0.0       1.5     ...                          18.4      0.1
# 25       0.1       8.6     ...                          24.0      0.2
# 26       0.0       0.2     ...                           0.1      0.0
# 27       0.0       3.5     ...                          27.3      0.1
# 28       0.3      13.4     ...                           8.2      0.8
# 29         .       0.1     ...                           0.0        .
# ..       ...       ...     ...                           ...      ...
# 624      0.1       1.0     ...                          24.8      0.2
# 625     16.5     163.7     ...                        1596.4     17.5
# 626      1.6     106.9     ...                        1440.6     11.7
# 627      8.9     234.9     ...                         693.7      9.8
# 628      0.8      15.9     ...                          48.5      0.7
# 629      0.0       0.2     ...                           1.1      0.0
# 630      0.3      11.0     ...                          38.2      0.9
# 631      4.7      77.8     ...                         153.1      3.5
# 632      0.6      21.9     ...                         117.0      1.0
# 633      2.6     108.1     ...                         335.8      3.6
# 634      5.6      51.3     ...                         573.8      7.0
# 635      0.4       4.8     ...                          44.0      0.7
# 636      0.9      12.0     ...                          64.4      1.7
# 637      3.4      23.1     ...                         360.8      3.4
# 638      0.9      11.5     ...                         104.6      1.1
# 639      0.6      12.4     ...                          56.9      0.3
# 640     29.8     355.0     ...                        3511.8     34.0
# 641     23.7     305.2     ...                        2653.1     25.1
# 642      6.6     132.3     ...                         761.0      6.1
# 643      0.4       9.5     ...                          70.2      0.2
# 644      9.7      44.9     ...                        1054.5      5.5
# 645      0.8      23.5     ...                         102.8      1.4
# 646      0.7      12.0     ...                          54.8      0.7
# 647      2.2      16.4     ...                         149.2      1.7
# 648      0.0       0.3     ...                           4.2      0.0
# 649      3.5      66.2     ...                         456.4      9.4
# 650      6.1      49.8     ...                         858.8      8.9
# 651      3.6      17.8     ...                         551.4      6.2
# 652      2.2      27.2     ...                         303.8      2.7
# 653      0.3       4.7     ...                           3.5      0.0
#
#     Uzbekistan Vanuatu Venezuela (Bolivarian Republic of)  Viet Nam     Yemen  \
# 0          UZB     VUT                                VEN       VNM       YEM
# 1            1       4                                  2         4         4
# 2      31,447     270                             31,568    94,569    27,584
# 3       8579.3    76.9                             9033.5   25192.8   12374.6
# 4       1741.2    21.8                             1304.9    4238.7    4887.3
# 5        387.1     8.0                              478.0    1861.7    1284.1
# 6         86.5     0.9                               29.9     391.9      79.3
# 7         23.1     0.9                               14.6      66.2     328.8
# 8          4.9     0.8                                5.6      24.0     298.6
# 9          6.6     0.0                                3.3      22.0       4.2
# 10         6.1     0.0                                1.8       2.7      19.6
# 11         1.1     0.0                                1.3       1.3       0.4
# 12         0.7     0.0                                1.3       3.1       0.6
# 13         3.8     0.0                                1.2      13.0       5.4
# 14        32.0     0.0                              144.3     416.6      21.5
# 15        85.9     3.7                              120.6     313.1     435.8
# 16         2.3     0.3                                3.7      22.9      52.0
# 17         0.0     0.1                                3.2       4.3       9.3
# 18         0.1     0.0                                0.0       0.3       0.5
# 19         0.0     0.0                                0.0       3.4       6.1
# 20         2.1     0.2                                0.4      14.9      36.1
# 21        15.7     0.5                               21.6      68.7      77.4
# 22        41.2     0.1                               19.4     102.9      22.7
# 23        35.0     0.1                                6.4      25.4       9.8
# 24        14.9     0.0                                0.6       1.5       0.8
# 25        15.6     0.0                                2.5      21.0       7.2
# 26         0.1     0.0                                0.0       0.6       0.2
# 27         4.5     0.0                                3.2       2.2       1.6
# 28         5.8     0.3                               52.4      91.9     128.3
# 29         0.0     0.2                                7.7       1.2      73.3
# ..         ...     ...                                ...       ...       ...
# 624        0.8     0.0                                0.8       3.6       0.4
# 625      100.5     0.7                               77.8     310.0      79.1
# 626       24.2     0.6                               81.9     243.9      55.2
# 627      137.0     1.6                              120.3     393.1     225.1
# 628       20.5     0.1                               10.5      17.7      32.4
# 629        0.2     0.0                                0.3       0.8       0.3
# 630        3.2     0.1                                7.8       6.8       4.6
# 631       64.1     0.5                               45.2     209.3      70.7
# 632        5.9     0.1                                6.3      13.7      12.2
# 633       43.1     0.8                               50.2     144.8     105.0
# 634       44.7     0.2                               54.2      88.5      24.1
# 635        4.5     0.0                                5.9       9.8       3.5
# 636        6.3     0.0                               11.2      17.2       5.1
# 637       25.0     0.1                               27.7      31.9       8.8
# 638        9.0     0.1                                9.3      29.5       6.8
# 639        3.6     0.0                                0.7      11.9      24.4
# 640      274.1     2.0                              290.2     771.0     565.5
# 641      213.1     1.7                              212.9     656.4     373.9
# 642       41.6     0.8                              119.3     252.6     126.2
# 643        6.5     0.0                                2.1       3.4      28.8
# 644       52.4     0.1                               34.4     157.6      43.1
# 645       23.4     0.1                                6.0      17.9      43.2
# 646       22.0     0.2                                7.0      89.2      33.1
# 647       14.5     0.1                                6.3      24.5      25.2
# 648          .     0.0                                1.0       0.8       0.1
# 649       52.8     0.4                               36.9     110.4      74.2
# 650       61.0     0.3                               77.3     114.6     191.6
# 651       49.6     0.2                               10.2      76.1      46.9
# 652       11.2     0.2                               66.9      36.2      33.4
# 653        0.1     0.0                                0.2       2.3     111.3
#
#        Zambia  Zimbabwe Unnamed: 190
# 0         ZMB       ZWE          NaN
# 1           5         5          NaN
# 2     16,591    16,150           NaN
# 3      8883.4    8437.3          NaN
# 4      5671.0    4928.2          NaN
# 5      3211.4    2643.3          NaN
# 6       246.2      70.0          NaN
# 7        57.2      54.4          NaN
# 8        43.4      35.5          NaN
# 9         4.1       3.8          NaN
# 10        4.2       9.2          NaN
# 11        1.5       0.9          NaN
# 12        0.9       0.8          NaN
# 13        3.2       4.2          NaN
# 14     1441.0    1738.5          NaN
# 15      532.4     391.1          NaN
# 16       34.4      18.0          NaN
# 17        2.4       2.9          NaN
# 18        0.2       0.2          NaN
# 19       12.5       5.8          NaN
# 20       19.2       9.1          NaN
# 21      172.5     129.8          NaN
# 22        7.8      20.8          NaN
# 23       26.1       5.2          NaN
# 24        1.1       0.2          NaN
# 25       19.7       3.1          NaN
# 26        0.6       0.1          NaN
# 27        4.6       1.8          NaN
# 28      574.7     166.4          NaN
# 29      517.1     136.5          NaN
# ..        ...       ...          ...
# 624       0.3       0.3          NaN
# 625      24.6      28.2          NaN
# 626      17.2      17.6          NaN
# 627     125.1     125.1          NaN
# 628      17.9      12.6          NaN
# 629       1.3       2.2          NaN
# 630       2.1       6.6          NaN
# 631      31.3      30.4          NaN
# 632       9.5      10.4          NaN
# 633      63.0      62.9          NaN
# 634      11.8      14.5          NaN
# 635       1.8       1.5          NaN
# 636       3.2       0.7          NaN
# 637       2.8       8.4          NaN
# 638       4.0       4.0          NaN
# 639       6.4       1.7          NaN
# 640     301.3     315.0          NaN
# 641     253.5     252.6          NaN
# 642      84.0     132.6          NaN
# 643      13.8      14.1          NaN
# 644      30.0      13.0          NaN
# 645      26.5      24.2          NaN
# 646      23.4      11.4          NaN
# 647      12.5      13.6          NaN
# 648       0.0       0.0          NaN
# 649      63.4      43.7          NaN
# 650      47.9      62.4          NaN
# 651      14.2      20.2          NaN
# 652      33.5      42.1          NaN
# 653       0.2       0.1          NaN
#
# [654 rows x 191 columns]

# %%
modified_daly = "assets/data/Daly_cleaned.csv"
modified_daly_df = pd.read_csv(modified_daly, encoding="ISO-8859-1")
modified_daly_df
# Out:
#                                        Country  \
# 0                                  Afghanistan
# 1                                      Albania
# 2                                      Algeria
# 3                                       Angola
# 4                          Antigua and Barbuda
# 5                                    Argentina
# 6                                      Armenia
# 7                                    Australia
# 8                                      Austria
# 9                                   Azerbaijan
# 10                                     Bahamas
# 11                                     Bahrain
# 12                                  Bangladesh
# 13                                    Barbados
# 14                                     Belarus
# 15                                     Belgium
# 16                                      Belize
# 17                                       Benin
# 18                                      Bhutan
# 19            Bolivia (Plurinational State of)
# 20                      Bosnia and Herzegovina
# 21                                    Botswana
# 22                                      Brazil
# 23                           Brunei Darussalam
# 24                                    Bulgaria
# 25                                Burkina Faso
# 26                                     Burundi
# 27                                    Cambodia
# 28                                    Cameroon
# 29                                      Canada
# ..                                         ...
# 153                                      Sudan
# 154                                   Suriname
# 155                                  Swaziland
# 156                                     Sweden
# 157                                Switzerland
# 158                       Syrian Arab Republic
# 159                                 Tajikistan
# 160                                   Thailand
# 161  The former Yugoslav Republic of Macedonia
# 162                                Timor-Leste
# 163                                       Togo
# 164                                      Tonga
# 165                        Trinidad and Tobago
# 166                                    Tunisia
# 167                                     Turkey
# 168                               Turkmenistan
# 169                                     Uganda
# 170                                    Ukraine
# 171                       United Arab Emirates
# 172                             United Kingdom
# 173                United Republic of Tanzania
# 174                   United States of America
# 175                                    Uruguay
# 176                                 Uzbekistan
# 177                                    Vanuatu
# 178         Venezuela (Bolivarian Republic of)
# 179                                   Viet Nam
# 180                                      Yemen
# 181                                     Zambia
# 182                                   Zimbabwe
#
#      Infectious and parasitic diseases  Respiratory Infectious   \
# 0                               2336.7                   1424.9
# 1                                 10.0                     14.4
# 2                                460.0                    461.5
# 3                               5256.8                   1866.6
# 4                                  1.2                      0.8
# 5                                444.1                    613.6
# 6                                 18.3                     14.0
# 7                                 59.4                     81.3
# 8                                 21.5                     27.7
# 9                                117.8                     93.6
# 10                                14.8                      3.0
# 11                                 7.5                      3.9
# 12                              5486.9                   2211.2
# 13                                 4.3                      4.9
# 14                               104.0                     42.6
# 15                                44.5                     89.4
# 16                                12.0                      3.6
# 17                              1875.8                    760.0
# 18                                32.1                     12.4
# 19                               286.7                    265.2
# 20                                10.8                     10.9
# 21                               307.7                     45.3
# 22                              2949.4                   2382.1
# 23                                 1.9                      2.0
# 24                                28.2                     45.7
# 25                              3748.3                   1035.2
# 26                              1810.2                    688.7
# 27                               627.2                    359.2
# 28                              5114.4                   1527.5
# 29                               125.5                    142.0
# ..                                 ...                      ...
# 153                             2995.0                   1419.7
# 154                               13.7                      5.5
# 155                              316.1                     60.7
# 156                               28.2                     49.5
# 157                               20.5                     34.6
# 158                              288.4                    136.3
# 159                              224.6                    229.1
# 160                             1695.7                   1016.9
# 161                                5.2                      6.3
# 162                               94.4                     49.5
# 163                             1314.0                    422.4
# 164                                1.5                      1.2
# 165                               24.2                     10.6
# 166                               80.5                     87.4
# 167                              449.0                    357.0
# 168                              168.1                    132.1
# 169                             6396.6                   2002.1
# 170                              983.8                    272.0
# 171                               53.5                     23.2
# 172                              177.3                    555.6
# 173                             8233.1                   2388.0
# 174                             1699.0                   1673.7
# 175                               26.0                     24.7
# 176                              387.1                    350.7
# 177                                8.0                      4.1
# 178                              478.0                    263.3
# 179                             1861.7                    753.9
# 180                             1284.1                    926.3
# 181                             3211.4                    731.2
# 182                             2643.3                    666.8
#
#      Maternal conditions  Neonatal conditions  Nutritional deficiencies  \
# 0                  225.3               3675.8                     233.5
# 1                    0.6                 19.8                       6.6
# 2                   62.0               1169.5                     181.1
# 3                  214.4               2959.0                     746.3
# 4                    0.2                  0.6                       0.6
# 5                   29.1                372.0                      88.9
# 6                    0.6                 26.1                       8.2
# 7                    2.4                 75.3                      14.5
# 8                    0.4                 23.5                       7.3
# 9                    3.1                242.0                      44.7
# 10                   0.3                  3.2                       1.5
# 11                   0.3                  8.3                       6.5
# 12                 321.7               5069.7                    1056.5
# 13                   0.1                  2.7                       1.2
# 14                   1.0                 29.7                      11.9
# 15                   1.2                 30.4                      14.3
# 16                   0.2                  7.1                       2.2
# 17                  88.8               1136.1                     395.6
# 18                   1.4                 21.6                      10.4
# 19                  29.1                385.9                     113.9
# 20                   0.4                 16.7                      10.8
# 21                   5.1                107.2                      15.9
# 22                  96.7               2103.6                    1072.4
# 23                   0.1                  2.8                       0.8
# 24                   0.7                 30.5                      14.6
# 25                 157.4               1603.3                     647.8
# 26                 189.4                930.0                     400.3
# 27                  32.4                477.5                     147.5
# 28                 298.1               1766.1                     502.4
# 29                   2.1                139.3                      25.1
# ..                   ...                  ...                       ...
# 153                229.0               3330.0                     584.1
# 154                  1.1                 10.6                       2.7
# 155                  8.4                 79.2                      21.8
# 156                  0.6                 26.1                       8.8
# 157                  0.5                 33.5                      15.1
# 158                 19.7                272.0                      93.6
# 159                  4.5                414.9                      61.5
# 160                 12.5                458.8                     102.8
# 161                  0.2                 20.1                       6.1
# 162                  4.5                 76.2                       8.7
# 163                 57.1                567.4                     161.1
# 164                  0.1                  1.5                       0.9
# 165                  0.8                 19.8                       5.7
# 166                  8.5                154.1                      17.5
# 167                 16.7                693.1                     296.9
# 168                  2.1                269.8                      23.5
# 169                361.5               3045.6                     765.9
# 170                 10.2                244.7                      40.1
# 171                  0.9                 42.1                      36.8
# 172                  8.1                247.2                      72.0
# 173                636.3               3857.8                    1249.5
# 174                 47.7               1504.9                     289.3
# 175                  0.7                 19.9                       7.8
# 176                 16.5                713.7                     273.2
# 177                  0.3                  6.2                       3.1
# 178                 40.5                469.8                      53.3
# 179                 56.4               1364.3                     202.3
# 180                204.1               1850.0                     622.8
# 181                104.2               1213.2                     411.1
# 182                177.2               1032.2                     408.7
#
#      Malignant neoplasms  Other neoplasms  Diabetes mellitus  \
# 0                  898.1             48.6              338.0
# 1                  137.9              8.2               10.1
# 2                  871.8             22.7              407.8
# 3                  310.3             19.9              107.6
# 4                    3.4              0.1                1.7
# 5                 1658.8             80.0              350.6
# 6                  208.1              2.2               36.5
# 7                  998.8             27.2              156.6
# 8                  451.9             12.6               76.8
# 9                  346.2              1.2               70.9
# 10                  14.5              0.2                5.3
# 11                  15.4              0.3               22.3
# 12                3404.3             70.0             1070.0
# 13                  16.5              0.6                7.5
# 14                 499.0              2.2               40.8
# 15                 616.8             25.9               66.5
# 16                   9.1              0.3                5.6
# 17                 154.9              8.7               58.8
# 18                  15.0              0.3                8.3
# 19                 234.8              8.1              110.7
# 20                 179.6              3.3               70.1
# 21                  40.7              2.3               33.4
# 22                6636.6            138.7             2139.0
# 23                  12.6              0.1                6.6
# 24                 487.7              5.0               67.5
# 25                 300.8             17.4               85.8
# 26                 248.3              9.6               56.0
# 27                 446.6              6.6              102.8
# 28                 520.5             19.6              168.6
# 29                1711.6             33.4              312.1
# ..                   ...              ...                ...
# 153                631.9             48.0              283.2
# 154                 17.9              0.1                9.8
# 155                 28.0              1.9               26.0
# 156                465.5             17.8               86.7
# 157                383.8             11.0               44.4
# 158                442.3             20.9               93.9
# 159                176.7             28.2               35.7
# 160               2871.9             75.1              789.1
# 161                107.5              0.6               29.3
# 162                 27.5              0.2                5.4
# 163                125.1              5.1               38.5
# 164                  3.4              0.0                2.8
# 165                 50.8              3.2               61.0
# 166                248.2             13.0              142.3
# 167               3129.9              4.0              888.0
# 168                175.9              7.3               33.8
# 169                988.5             30.8              203.1
# 170               2654.3              7.3              222.2
# 171                 73.1              0.6               83.1
# 172               3452.8             74.3              312.4
# 173                957.3             31.1              257.3
# 174              14916.5            361.5             4054.7
# 175                196.1              7.0               28.0
# 176                507.2             36.0              238.8
# 177                  7.3              0.1                3.6
# 178                853.3             86.0              514.3
# 179               3275.6             37.4              736.4
# 180                455.9             28.2              179.8
# 181                295.9             14.8               72.6
# 182                337.0              4.4              134.4
#
#      Endocrine, blood, immune disorders          ...           \
# 0                                 180.2          ...
# 1                                   7.9          ...
# 2                                 118.4          ...
# 3                                 157.9          ...
# 4                                   0.7          ...
# 5                                 101.1          ...
# 6                                   4.9          ...
# 7                                  60.1          ...
# 8                                  37.8          ...
# 9                                  31.9          ...
# 10                                  1.5          ...
# 11                                  5.9          ...
# 12                                401.8          ...
# 13                                  1.9          ...
# 14                                 14.6          ...
# 15                                 38.7          ...
# 16                                  1.0          ...
# 17                                193.1          ...
# 18                                  2.8          ...
# 19                                 26.3          ...
# 20                                  7.4          ...
# 21                                  7.1          ...
# 22                                671.5          ...
# 23                                  1.0          ...
# 24                                 16.3          ...
# 25                                374.4          ...
# 26                                 56.9          ...
# 27                                 44.6          ...
# 28                                322.5          ...
# 29                                 97.4          ...
# ..                                  ...          ...
# 153                               232.2          ...
# 154                                 1.7          ...
# 155                                10.0          ...
# 156                                22.8          ...
# 157                                21.0          ...
# 158                                51.2          ...
# 159                                19.4          ...
# 160                               141.6          ...
# 161                                 3.4          ...
# 162                                 2.9          ...
# 163                                80.4          ...
# 164                                 0.3          ...
# 165                                 7.9          ...
# 166                                32.3          ...
# 167                               281.7          ...
# 168                                18.6          ...
# 169                               205.7          ...
# 170                                69.8          ...
# 171                                17.1          ...
# 172                               153.6          ...
# 173                               237.7          ...
# 174                              1421.9          ...
# 175                                10.4          ...
# 176                                49.3          ...
# 177                                 0.5          ...
# 178                                49.2          ...
# 179                               198.2          ...
# 180                               155.5          ...
# 181                                74.1          ...
# 182                                49.6          ...
#
#      Respiratory diseases  Digestive diseases  Genitourinary diseases  \
# 0                   315.0               267.7                   308.2
# 1                    21.7                18.9                    20.9
# 2                   279.3               219.7                   348.1
# 3                   215.1               395.4                   145.4
# 4                     1.0                 0.7                     0.8
# 5                   733.7               451.1                   401.8
# 6                    26.8                36.4                    28.6
# 7                   312.4               138.3                   105.5
# 8                    98.6                80.5                    61.9
# 9                    67.1               107.7                    75.3
# 10                    2.4                 3.0                     3.6
# 11                    6.8                 4.8                     9.0
# 12                 2315.1              1521.6                  1094.5
# 13                    2.9                 2.8                     3.8
# 14                   75.0               144.6                    64.1
# 15                  175.6               114.2                    80.6
# 16                    3.0                 3.3                     3.7
# 17                  104.3               206.9                   126.7
# 18                   15.0                13.8                    10.4
# 19                  107.2               200.5                   145.9
# 20                   36.3                38.9                    29.5
# 21                   24.4                13.6                    14.5
# 22                 2200.9              2521.9                  1510.9
# 23                    3.8                 1.9                     3.4
# 24                  110.7               120.9                    71.4
# 25                  133.1               295.2                   142.3
# 26                  106.6               189.4                    64.8
# 27                  160.8               385.7                   102.3
# 28                  229.2               525.4                   306.0
# 29                  429.9               258.2                   187.6
# ..                    ...                 ...                     ...
# 153                 420.3               368.8                   423.6
# 154                   4.6                 7.3                     7.9
# 155                  17.6                12.1                    10.3
# 156                 132.5                65.1                    46.4
# 157                  92.0                56.3                    50.3
# 158                 131.5                84.4                   130.4
# 159                  58.0                78.6                    52.0
# 160                1075.1               909.2                   977.8
# 161                  23.3                15.1                    16.8
# 162                  12.1                 9.1                     5.2
# 163                  72.6               124.7                    65.7
# 164                   1.5                 1.0                     1.2
# 165                  14.4                14.0                    13.8
# 166                 100.6                76.5                   131.9
# 167                 899.5               442.0                   815.2
# 168                  26.0               112.9                    59.3
# 169                 309.8               572.8                   219.1
# 170                 409.8               874.6                   285.6
# 171                  65.0                28.1                    61.6
# 172                1106.8               716.8                   328.1
# 173                 415.5               607.5                   290.4
# 174                6220.9              3572.2                  2927.0
# 175                  56.9                32.0                    30.0
# 176                 173.2               404.1                   275.6
# 177                   3.7                 1.5                     2.2
# 178                 235.2               246.8                   183.6
# 179                1050.2               909.5                   571.4
# 180                 284.3               210.3                   259.6
# 181                 107.0               218.0                    87.1
# 182                 139.5               157.6                   111.7
#
#      Skin diseases  Musculoskeletal diseases  Congenital anomalies  \
# 0             89.8                     298.2                 666.4
# 1              6.9                      45.6                  18.3
# 2            111.4                     611.1                 483.8
# 3            125.4                     170.8                 709.8
# 4              0.4                       1.4                   0.7
# 5            150.6                     845.2                 299.6
# 6              7.2                      42.3                  19.7
# 7             70.7                     527.9                  69.8
# 8             22.5                     164.8                  31.5
# 9             22.4                     113.7                  88.1
# 10             1.5                       6.1                   1.3
# 11             3.6                      21.1                   8.8
# 12           508.6                    2239.0                1463.4
# 13             1.0                       5.5                   1.7
# 14            22.5                     158.6                  39.4
# 15            33.6                     224.6                  35.9
# 16             1.3                       4.0                   3.1
# 17            43.5                      87.5                 241.4
# 18             2.5                      10.1                   7.4
# 19            35.6                     119.1                 149.5
# 20             8.7                      65.1                  12.7
# 21             8.2                      21.2                  27.1
# 22           797.0                    3289.1                1445.0
# 23             1.2                       5.8                   2.9
# 24            17.2                     129.9                  25.5
# 25            87.9                     131.2                 335.6
# 26            51.1                      73.3                 199.4
# 27            61.2                     171.7                 130.2
# 28            93.5                     186.5                 563.6
# 29           114.3                     783.7                 106.8
# ..             ...                       ...                   ...
# 153          111.1                     475.4                 729.2
# 154            2.3                       7.3                   4.0
# 155            5.2                      10.5                  27.0
# 156           30.4                     208.9                  31.4
# 157           23.3                     180.6                  30.6
# 158           46.8                     206.9                 175.4
# 159           20.3                      67.6                 118.8
# 160          323.8                    1268.0                 329.8
# 161            4.7                      31.4                   7.2
# 162            4.2                       9.3                  18.1
# 163           27.2                      57.6                 141.4
# 164            0.5                       1.2                   1.1
# 165            4.8                      23.4                  10.0
# 166           32.7                     198.1                  98.9
# 167          208.0                    1437.6                 742.4
# 168           13.3                      51.8                  94.0
# 169          180.2                     233.3                 745.4
# 170          106.0                     823.6                 211.5
# 171           22.8                     141.2                  40.6
# 172          211.6                    1395.8                 223.5
# 173          250.7                     343.6                1006.0
# 174         1066.2                    6881.0                1464.2
# 175           11.4                      72.4                  20.8
# 176           70.5                     303.4                 305.4
# 177            1.0                       2.8                   3.5
# 178           82.1                     350.7                 257.5
# 179          324.3                    1208.3                 870.8
# 180           79.6                     282.3                 479.2
# 181           80.6                     103.5                 281.5
# 182           58.8                     112.7                 298.4
#
#      Oral conditions  Sudden infant death syndrome  Unintentional injuries  \
# 0               55.2                          38.2                  1329.8
# 1               10.5                           1.2                    71.1
# 2              102.5                          24.4                  1023.3
# 3               37.5                          51.5                  1277.6
# 4                0.3                           0.0                     2.3
# 5              129.0                          21.5                   910.2
# 6               12.2                           0.3                    70.9
# 7               97.4                           5.5                   342.0
# 8               46.4                           0.7                   157.8
# 9               31.7                           3.5                   213.6
# 10               1.4                           0.1                     6.4
# 11               3.4                           0.1                    18.3
# 12             295.3                         127.6                  3660.7
# 13               1.3                           0.1                     4.7
# 14              36.8                           1.5                   376.0
# 15              58.5                           2.0                   224.4
# 16               0.9                           0.1                     8.3
# 17              19.0                          17.5                   580.0
# 18               1.6                           0.5                    26.3
# 19              29.9                           2.1                   414.0
# 20              17.6                           0.1                    91.0
# 21               4.9                           0.7                    59.1
# 22             744.6                          18.5                  5092.9
# 23               1.0                           0.1                     8.1
# 24              33.6                           0.3                   193.6
# 25              27.1                          24.9                   962.9
# 26              15.3                          18.1                   686.2
# 27              22.6                           4.9                   504.5
# 28              39.5                          36.3                  1389.9
# 29             143.1                           5.8                   603.1
# ..               ...                           ...                     ...
# 153             76.2                          31.7                  1910.9
# 154              1.7                           0.4                    14.6
# 155              2.3                           1.6                    60.0
# 156             40.5                           1.8                   153.7
# 157             43.4                           0.7                   130.5
# 158             38.9                           4.3                   330.1
# 159             19.1                           7.8                   256.2
# 160            180.6                          13.7                  2290.0
# 161              7.8                           0.5                    41.9
# 162              1.7                           1.7                    39.9
# 163             12.7                           6.4                   363.1
# 164              0.1                           0.0                     1.7
# 165              5.1                           0.3                    30.7
# 166             34.4                           3.8                   236.4
# 167            281.9                          12.6                  1408.0
# 168             14.3                           5.0                   171.4
# 169             48.7                          49.3                  1956.3
# 170            192.0                           6.2                  1468.8
# 171             21.2                           1.5                   176.2
# 172            312.0                          10.5                   901.7
# 173             54.2                          63.3                  2617.5
# 174           1071.5                         131.6                  6760.5
# 175             12.4                           0.8                    79.6
# 176             80.9                           8.0                   675.6
# 177              0.3                           0.1                     5.4
# 178             95.6                           1.5                  1156.9
# 179            154.9                          26.5                  2724.4
# 180             47.3                          56.1                  1221.7
# 181             21.8                          16.5                   713.7
# 182             24.3                           3.9                   768.6
#
#      Intentional injuries
# 0                  2372.6
# 1                    17.3
# 2                   195.5
# 3                   287.8
# 4                     0.1
# 5                   391.4
# 6                    12.9
# 7                   168.4
# 8                    56.8
# 9                    40.0
# 10                    6.7
# 11                    6.1
# 12                  897.7
# 13                    1.5
# 14                  136.0
# 15                  101.3
# 16                    7.1
# 17                  103.0
# 18                    6.1
# 19                  174.3
# 20                   26.3
# 21                   27.5
# 22                 4598.0
# 23                    1.6
# 24                   37.2
# 25                  205.0
# 26                  138.1
# 27                  100.6
# 28                  346.8
# 29                  249.4
# ..                    ...
# 153                 658.3
# 154                   9.6
# 155                  28.6
# 156                  66.7
# 157                  52.4
# 158                4454.6
# 159                  26.7
# 160                 713.8
# 161                   9.0
# 162                  12.7
# 163                  82.5
# 164                   0.5
# 165                  44.2
# 166                  35.3
# 167                 536.6
# 168                  37.6
# 169                 636.1
# 170                 583.9
# 171                  37.9
# 172                 320.6
# 173                 453.8
# 174                3772.7
# 175                  43.7
# 176                 180.8
# 177                   1.2
# 178                1038.9
# 179                 594.6
# 180                 608.5
# 181                 172.7
# 182                 250.0
#
# [183 rows x 24 columns]

# %%
modified_daly_df.columns
# Out:
# Index(['Country', 'Infectious and parasitic diseases',
#        'Respiratory Infectious ', 'Maternal conditions', 'Neonatal conditions',
#        'Nutritional deficiencies', 'Malignant neoplasms', 'Other neoplasms',
#        'Diabetes mellitus', 'Endocrine, blood, immune disorders',
#        'Mental and substance use disorders', 'Neurological conditions',
#        'Sense organ diseases', 'Cardiovascular diseases',
#        'Respiratory diseases', 'Digestive diseases', 'Genitourinary diseases',
#        'Skin diseases', 'Musculoskeletal diseases', 'Congenital anomalies',
#        'Oral conditions', 'Sudden infant death syndrome',
#        'Unintentional injuries', 'Intentional injuries'],
#       dtype='object')

# %%
modified_daly_df.dtypes
# Out:
# Country                                object
# Infectious and parasitic diseases     float64
# Respiratory Infectious                float64
# Maternal conditions                   float64
# Neonatal conditions                   float64
# Nutritional deficiencies              float64
# Malignant neoplasms                   float64
# Other neoplasms                       float64
# Diabetes mellitus                     float64
# Endocrine, blood, immune disorders    float64
# Mental and substance use disorders    float64
# Neurological conditions               float64
# Sense organ diseases                  float64
# Cardiovascular diseases               float64
# Respiratory diseases                  float64
# Digestive diseases                    float64
# Genitourinary diseases                float64
# Skin diseases                         float64
# Musculoskeletal diseases              float64
# Congenital anomalies                  float64
# Oral conditions                       float64
# Sudden infant death syndrome          float64
# Unintentional injuries                float64
# Intentional injuries                  float64
# dtype: object

# %%
#################################################
# Database Setup
#################################################

engine = create_engine(
    "mysql://rl91qzpzgty8oaf1:evamhxfd7l42mgso@y2w3wxldca8enczv.cbetxkdyhwsb.us-east-1.rds.amazonaws.com:3306/v21ogkg4wvsne316")
conn = engine.connect()

# %%
from sqlalchemy.ext.declarative import declarative_base
Base = declarative_base()

# %%
from sqlalchemy import Column, Integer, String, Float
class User(Base):
    __tablename__ = "DALY"
    Country = Column(String(255), primary_key=True)
    Infectious_and_parasitic_diseases = Column ("Infectious and parasitic diseases", Float)
    Respiratory_Infectious = Column ("Respiratory Infectious", Float)
    Maternal_conditions = Column ("Maternal conditions", Float)
    Neonatal_conditions = Column ("Neonatal conditions", Float)
    Nutritional_deficiencies = Column ("Nutritional deficiencies", Float)
    Malignant_neoplasms = Column ("Malignant neoplasms", Float)
    Other_neoplasms = Column ("Other neoplasms", Float)
    Diabetes_mellitus = Column ("Diabetes mellitus", Float)
    Endocrine_blood_immune_disorders = Column ("Endocrine, blood, immune disorders", Float)
    Mental_and_substance_use_disorders = Column ("Mental and substance use disorders", Float)
    Neurological_conditions = Column ("Neurological conditions", Float)
    Sense_organ_diseases = Column ("Sense organ diseases", Float)
    Cardiovascular_diseases = Column ("Cardiovascular diseases", Float)
    Respiratory_diseases = Column ("Respiratory diseases", Float)
    Digestive_diseases = Column ("Digestive diseases", Float)
    Genitourinary_diseases = Column ("Genitourinary diseases", Float)
    Skin_diseases = Column ("Skin diseases", Float)
    Musculoskeletal_diseases = Column ("Musculoskeletal diseases", Float)
    Congenital_anomalies = Column ("Congenital anomalies", Float)
    Oral_conditions = Column ("Oral conditions", Float)
    Sudden_infant_death_syndrome = Column ("Sudden infant death syndrome", Float)
    Unintentional_injuries = Column ("Unintentional injuries", Float)
    Intentional_injuries = Column ("Intentional injuries", Float)

# %%
Base.metadata.create_all(conn)

# %%
modified_daly_df.to_sql(User.__tablename__, conn, index=False, if_exists="append")
# Out:
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1169                         parameters,
# -> 1170                         context)
#    1171             elif not parameters and context.no_parameters:
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py in do_executemany(self, cursor, statement, parameters, context)
#     104     def do_executemany(self, cursor, statement, parameters, context=None):
# --> 105         rowcount = cursor.executemany(statement, parameters)
#     106         if context is not None:
#
# /anaconda3/lib/python3.7/site-packages/pymysql/cursors.py in executemany(self, query, args)
#     196                                          self.max_stmt_length,
# --> 197                                          self._get_db().encoding)
#     198
#
# /anaconda3/lib/python3.7/site-packages/pymysql/cursors.py in _do_execute_many(self, prefix, values, postfix, args, max_stmt_length, encoding)
#     233             sql += v
# --> 234         rows += self.execute(sql + postfix)
#     235         self.rowcount = rows
#
# /anaconda3/lib/python3.7/site-packages/pymysql/cursors.py in execute(self, query, args)
#     169
# --> 170         result = self._query(query)
#     171         self._executed = query
#
# /anaconda3/lib/python3.7/site-packages/pymysql/cursors.py in _query(self, q)
#     327         self._clear_result()
# --> 328         conn.query(q)
#     329         self._do_get_result()
#
# /anaconda3/lib/python3.7/site-packages/pymysql/connections.py in query(self, sql, unbuffered)
#     516         self._execute_command(COMMAND.COM_QUERY, sql)
# --> 517         self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     518         return self._affected_rows
#
# /anaconda3/lib/python3.7/site-packages/pymysql/connections.py in _read_query_result(self, unbuffered)
#     731             result = MySQLResult(self)
# --> 732             result.read()
#     733         self._result = result
#
# /anaconda3/lib/python3.7/site-packages/pymysql/connections.py in read(self)
#    1074         try:
# -> 1075             first_packet = self.connection._read_packet()
#    1076
#
# /anaconda3/lib/python3.7/site-packages/pymysql/connections.py in _read_packet(self, packet_type)
#     683         packet = packet_type(buff, self.encoding)
# --> 684         packet.check_error()
#     685         return packet
#
# /anaconda3/lib/python3.7/site-packages/pymysql/protocol.py in check_error(self)
#     219             if DEBUG: print("errno =", errno)
# --> 220             err.raise_mysql_exception(self._data)
#     221
#
# /anaconda3/lib/python3.7/site-packages/pymysql/err.py in raise_mysql_exception(data)
#     108     errorclass = error_map.get(errno, InternalError)
# --> 109     raise errorclass(errno, errval)
#
# InternalError: (1054, "Unknown column 'Respiratory Infectious ' in 'field list'")
#
# The above exception was the direct cause of the following exception:
#
# InternalError                             Traceback (most recent call last)
# <ipython-input-12-2e9ac935f90b> in <module>()
# ----> 1 modified_daly_df.to_sql(User.__tablename__, conn, index=False, if_exists="append")
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype)
#    2128         sql.to_sql(self, name, con, schema=schema, if_exists=if_exists,
#    2129                    index=index, index_label=index_label, chunksize=chunksize,
# -> 2130                    dtype=dtype)
#    2131
#    2132     def to_pickle(self, path, compression='infer',
#
# /anaconda3/lib/python3.7/site-packages/pandas/io/sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype)
#     448     pandas_sql.to_sql(frame, name, if_exists=if_exists, index=index,
#     449                       index_label=index_label, schema=schema,
# --> 450                       chunksize=chunksize, dtype=dtype)
#     451
#     452
#
# /anaconda3/lib/python3.7/site-packages/pandas/io/sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype)
#    1125                          schema=schema, dtype=dtype)
#    1126         table.create()
# -> 1127         table.insert(chunksize)
#    1128         if (not name.isdigit() and not name.islower()):
#    1129             # check for potentially case sensitivity issues (GH7815)
#
# /anaconda3/lib/python3.7/site-packages/pandas/io/sql.py in insert(self, chunksize)
#     639
#     640                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 641                 self._execute_insert(conn, keys, chunk_iter)
#     642
#     643     def _query_iterator(self, result, chunksize, columns, coerce_float=True,
#
# /anaconda3/lib/python3.7/site-packages/pandas/io/sql.py in _execute_insert(self, conn, keys, data_iter)
#     614     def _execute_insert(self, conn, keys, data_iter):
#     615         data = [{k: v for k, v in zip(keys, row)} for row in data_iter]
# --> 616         conn.execute(self.insert_statement(), data)
#     617
#     618     def insert(self, chunksize=None):
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in execute(self, object, *multiparams, **params)
#     946             raise exc.ObjectNotExecutableError(object)
#     947         else:
# --> 948             return meth(self, multiparams, params)
#     949
#     950     def _execute_function(self, func, multiparams, params):
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/sql/elements.py in _execute_on_connection(self, connection, multiparams, params)
#     267     def _execute_on_connection(self, connection, multiparams, params):
#     268         if self.supports_execution:
# --> 269             return connection._execute_clauseelement(self, multiparams, params)
#     270         else:
#     271             raise exc.ObjectNotExecutableError(self)
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_clauseelement(self, elem, multiparams, params)
#    1058             compiled_sql,
#    1059             distilled_params,
# -> 1060             compiled_sql, distilled_params
#    1061         )
#    1062         if self._has_events or self.engine._has_events:
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1198                 parameters,
#    1199                 cursor,
# -> 1200                 context)
#    1201
#    1202         if self._has_events or self.engine._has_events:
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1411                 util.raise_from_cause(
#    1412                     sqlalchemy_exception,
# -> 1413                     exc_info
#    1414                 )
#    1415             else:
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/util/compat.py in raise_from_cause(exception, exc_info)
#     263     exc_type, exc_value, exc_tb = exc_info
#     264     cause = exc_value if exc_value is not exception else None
# --> 265     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     266
#     267 if py3k:
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/util/compat.py in reraise(tp, value, tb, cause)
#     246             value.__cause__ = cause
#     247         if value.__traceback__ is not tb:
# --> 248             raise value.with_traceback(tb)
#     249         raise value
#     250
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1168                         statement,
#    1169                         parameters,
# -> 1170                         context)
#    1171             elif not parameters and context.no_parameters:
#    1172                 if self.dialect._has_events:
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py in do_executemany(self, cursor, statement, parameters, context)
#     103
#     104     def do_executemany(self, cursor, statement, parameters, context=None):
# --> 105         rowcount = cursor.executemany(statement, parameters)
#     106         if context is not None:
#     107             context._rowcount = rowcount
#
# /anaconda3/lib/python3.7/site-packages/pymysql/cursors.py in executemany(self, query, args)
#     195             return self._do_execute_many(q_prefix, q_values, q_postfix, args,
#     196                                          self.max_stmt_length,
# --> 197                                          self._get_db().encoding)
#     198
#     199         self.rowcount = sum(self.execute(query, arg) for arg in args)
#
# /anaconda3/lib/python3.7/site-packages/pymysql/cursors.py in _do_execute_many(self, prefix, values, postfix, args, max_stmt_length, encoding)
#     232                 sql += b','
#     233             sql += v
# --> 234         rows += self.execute(sql + postfix)
#     235         self.rowcount = rows
#     236         return rows
#
# /anaconda3/lib/python3.7/site-packages/pymysql/cursors.py in execute(self, query, args)
#     168         query = self.mogrify(query, args)
#     169
# --> 170         result = self._query(query)
#     171         self._executed = query
#     172         return result
#
# /anaconda3/lib/python3.7/site-packages/pymysql/cursors.py in _query(self, q)
#     326         self._last_executed = q
#     327         self._clear_result()
# --> 328         conn.query(q)
#     329         self._do_get_result()
#     330         return self.rowcount
#
# /anaconda3/lib/python3.7/site-packages/pymysql/connections.py in query(self, sql, unbuffered)
#     515                 sql = sql.encode(self.encoding, 'surrogateescape')
#     516         self._execute_command(COMMAND.COM_QUERY, sql)
# --> 517         self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     518         return self._affected_rows
#     519
#
# /anaconda3/lib/python3.7/site-packages/pymysql/connections.py in _read_query_result(self, unbuffered)
#     730         else:
#     731             result = MySQLResult(self)
# --> 732             result.read()
#     733         self._result = result
#     734         if result.server_status is not None:
#
# /anaconda3/lib/python3.7/site-packages/pymysql/connections.py in read(self)
#    1073     def read(self):
#    1074         try:
# -> 1075             first_packet = self.connection._read_packet()
#    1076
#    1077             if first_packet.is_ok_packet():
#
# /anaconda3/lib/python3.7/site-packages/pymysql/connections.py in _read_packet(self, packet_type)
#     682
#     683         packet = packet_type(buff, self.encoding)
# --> 684         packet.check_error()
#     685         return packet
#     686
#
# /anaconda3/lib/python3.7/site-packages/pymysql/protocol.py in check_error(self)
#     218             errno = self.read_uint16()
#     219             if DEBUG: print("errno =", errno)
# --> 220             err.raise_mysql_exception(self._data)
#     221
#     222     def dump(self):
#
# /anaconda3/lib/python3.7/site-packages/pymysql/err.py in raise_mysql_exception(data)
#     107         errval = data[3:].decode('utf-8', 'replace')
#     108     errorclass = error_map.get(errno, InternalError)
# --> 109     raise errorclass(errno, errval)
#
# InternalError: (pymysql.err.InternalError) (1054, "Unknown column 'Respiratory Infectious ' in 'field list'") [SQL: 'INSERT INTO `DALY` (`Country`, `Infectious and parasitic diseases`, `Respiratory Infectious `, `Maternal conditions`, `Neonatal conditions`, `Nutritional deficiencies`, `Malignant neoplasms`, `Other neoplasms`, `Diabetes mellitus`, `Endocrine, blood, immune disorders`, `Mental and substance use disorders`, `Neurological conditions`, `Sense organ diseases`, `Cardiovascular diseases`, `Respiratory diseases`, `Digestive diseases`, `Genitourinary diseases`, `Skin diseases`, `Musculoskeletal diseases`, `Congenital anomalies`, `Oral conditions`, `Sudden infant death syndrome`, `Unintentional injuries`, `Intentional injuries`) VALUES (%(Country)s, %(Infectious and parasitic diseases)s, %(Respiratory Infectious )s, %(Maternal conditions)s, %(Neonatal conditions)s, %(Nutritional deficiencies)s, %(Malignant neoplasms)s, %(Other neoplasms)s, %(Diabetes mellitus)s, %(Endocrine, blood, immune disorders)s, %(Mental and substance use disorders)s, %(Neurological conditions)s, %(Sense organ diseases)s, %(Cardiovascular diseases)s, %(Respiratory diseases)s, %(Digestive diseases)s, %(Genitourinary diseases)s, %(Skin diseases)s, %(Musculoskeletal diseases)s, %(Congenital anomalies)s, %(Oral conditions)s, %(Sudden infant death syndrome)s, %(Unintentional injuries)s, %(Intentional injuries)s)'] [parameters: ({'Country': 'Afghanistan', 'Infectious and parasitic diseases': 2336.7, 'Respiratory Infectious ': 1424.9, 'Maternal conditions': 225.3, 'Neonatal conditions': 3675.8, 'Nutritional deficiencies': 233.5, 'Malignant neoplasms': 898.1, 'Other neoplasms': 48.6, 'Diabetes mellitus': 338.0, 'Endocrine, blood, immune disorders': 180.2, 'Mental and substance use disorders': 759.7, 'Neurological conditions': 338.7, 'Sense organ diseases': 373.2, 'Cardiovascular diseases': 1570.7, 'Respiratory diseases': 315.0, 'Digestive diseases': 267.7, 'Genitourinary diseases': 308.2, 'Skin diseases': 89.8, 'Musculoskeletal diseases': 298.2, 'Congenital anomalies': 666.4, 'Oral conditions': 55.2, 'Sudden infant death syndrome': 38.2, 'Unintentional injuries': 1329.8, 'Intentional injuries': 2372.6}, {'Country': 'Albania', 'Infectious and parasitic diseases': 10.0, 'Respiratory Infectious ': 14.4, 'Maternal conditions': 0.6, 'Neonatal conditions': 19.8, 'Nutritional deficiencies': 6.6, 'Malignant neoplasms': 137.9, 'Other neoplasms': 8.2, 'Diabetes mellitus': 10.1, 'Endocrine, blood, immune disorders': 7.9, 'Mental and substance use disorders': 55.2, 'Neurological conditions': 48.8, 'Sense organ diseases': 47.4, 'Cardiovascular diseases': 284.6, 'Respiratory diseases': 21.7, 'Digestive diseases': 18.9, 'Genitourinary diseases': 20.9, 'Skin diseases': 6.9, 'Musculoskeletal diseases': 45.6, 'Congenital anomalies': 18.3, 'Oral conditions': 10.5, 'Sudden infant death syndrome': 1.2, 'Unintentional injuries': 71.1, 'Intentional injuries': 17.3}, {'Country': 'Algeria', 'Infectious and parasitic diseases': 460.0, 'Respiratory Infectious ': 461.5, 'Maternal conditions': 62.0, 'Neonatal conditions': 1169.5, 'Nutritional deficiencies': 181.1, 'Malignant neoplasms': 871.8, 'Other neoplasms': 22.7, 'Diabetes mellitus': 407.8, 'Endocrine, blood, immune disorders': 118.4, 'Mental and substance use disorders': 927.8, 'Neurological conditions': 581.4, 'Sense organ diseases': 593.2, 'Cardiovascular diseases': 1576.5, 'Respiratory diseases': 279.3, 'Digestive diseases': 219.7, 'Genitourinary diseases': 348.1, 'Skin diseases': 111.4, 'Musculoskeletal diseases': 611.1, 'Congenital anomalies': 483.8, 'Oral conditions': 102.5, 'Sudden infant death syndrome': 24.4, 'Unintentional injuries': 1023.3, 'Intentional injuries': 195.5}, {'Country': 'Angola', 'Infectious and parasitic diseases': 5256.8, 'Respiratory Infectious ': 1866.6, 'Maternal conditions': 214.4, 'Neonatal conditions': 2959.0, 'Nutritional deficiencies': 746.3, 'Malignant neoplasms': 310.3, 'Other neoplasms': 19. ...

# %%
import pymysql, os
pymysql.install_as_MySQLdb()

PASSWD = os.getenv("evamhxfd7l42mgso")
USER = "rl91qzpzgty8oaf1"
PORT = "3306"
DOMAIN = "y2w3wxldca8enczv.cbetxkdyhwsb.us-east-1.rds.amazonaws.com"
DB = "v21ogkg4wvsne316"
engine = create_engine(f"mysql://{USER}:{PASSWD}@{DOMAIN}:{PORT}/{DB}")
conn = engine.connect()
# Out:
# ---------------------------------------------------------------------------
# OperationalError                          Traceback (most recent call last)
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    2157         try:
# -> 2158             return fn()
#    2159         except dialect.dbapi.Error as e:
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/pool.py in unique_connection(self)
#     344         """
# --> 345         return _ConnectionFairy._checkout(self)
#     346
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/pool.py in _checkout(cls, pool, threadconns, fairy)
#     790         if not fairy:
# --> 791             fairy = _ConnectionRecord.checkout(pool)
#     792
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/pool.py in checkout(cls, pool)
#     531     def checkout(cls, pool):
# --> 532         rec = pool._do_get()
#     533         try:
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/pool.py in _do_get(self)
#    1195                 with util.safe_reraise():
# -> 1196                     self._dec_overflow()
#    1197         else:
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/util/langhelpers.py in __exit__(self, type_, value, traceback)
#      65             if not self.warn_only:
# ---> 66                 compat.reraise(exc_type, exc_value, exc_tb)
#      67         else:
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/util/compat.py in reraise(tp, value, tb, cause)
#     248             raise value.with_traceback(tb)
# --> 249         raise value
#     250
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/pool.py in _do_get(self)
#    1192             try:
# -> 1193                 return self._create_connection()
#    1194             except:
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/pool.py in _create_connection(self)
#     349
# --> 350         return _ConnectionRecord(self)
#     351
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/pool.py in __init__(self, pool, connect)
#     476         if connect:
# --> 477             self.__connect(first_connect_check=True)
#     478         self.finalize_callback = deque()
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/pool.py in __connect(self, first_connect_check)
#     673             self.starttime = time.time()
# --> 674             connection = pool._invoke_creator(self)
#     675             pool.logger.debug("Created new connection %r", connection)
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/strategies.py in connect(connection_record)
#     105                             return connection
# --> 106                 return dialect.connect(*cargs, **cparams)
#     107
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/default.py in connect(self, *cargs, **cparams)
#     411     def connect(self, *cargs, **cparams):
# --> 412         return self.dbapi.connect(*cargs, **cparams)
#     413
#
# /anaconda3/lib/python3.7/site-packages/pymysql/__init__.py in Connect(*args, **kwargs)
#      93     from .connections import Connection
# ---> 94     return Connection(*args, **kwargs)
#      95
#
# /anaconda3/lib/python3.7/site-packages/pymysql/connections.py in __init__(self, host, user, password, database, port, unix_socket, charset, sql_mode, read_default_file, conv, use_unicode, client_flag, cursorclass, init_command, connect_timeout, ssl, read_default_group, compress, named_pipe, autocommit, db, passwd, local_infile, max_allowed_packet, defer_connect, auth_plugin_map, read_timeout, write_timeout, bind_address, binary_prefix, program_name, server_public_key)
#     324         else:
# --> 325             self.connect()
#     326
#
# /anaconda3/lib/python3.7/site-packages/pymysql/connections.py in connect(self, sock)
#     598             self._get_server_information()
# --> 599             self._request_authentication()
#     600
#
# /anaconda3/lib/python3.7/site-packages/pymysql/connections.py in _request_authentication(self)
#     860         self.write_packet(data)
# --> 861         auth_packet = self._read_packet()
#     862
#
# /anaconda3/lib/python3.7/site-packages/pymysql/connections.py in _read_packet(self, packet_type)
#     683         packet = packet_type(buff, self.encoding)
# --> 684         packet.check_error()
#     685         return packet
#
# /anaconda3/lib/python3.7/site-packages/pymysql/protocol.py in check_error(self)
#     219             if DEBUG: print("errno =", errno)
# --> 220             err.raise_mysql_exception(self._data)
#     221
#
# /anaconda3/lib/python3.7/site-packages/pymysql/err.py in raise_mysql_exception(data)
#     108     errorclass = error_map.get(errno, InternalError)
# --> 109     raise errorclass(errno, errval)
#
# OperationalError: (1045, "Access denied for user 'rl91qzpzgty8oaf1'@'136.49.116.130' (using password: YES)")
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-13-de3647ec07d5> in <module>()
#       8 DB = "v21ogkg4wvsne316"
#       9 engine = create_engine(f"mysql://{USER}:{PASSWD}@{DOMAIN}:{PORT}/{DB}")
# ---> 10 conn = engine.connect()
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in connect(self, **kwargs)
#    2100         """
#    2101
# -> 2102         return self._connection_cls(self, **kwargs)
#    2103
#    2104     def contextual_connect(self, close_with_result=False, **kwargs):
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in __init__(self, engine, connection, close_with_result, _branch_from, _execution_options, _dispatch, _has_events)
#      88         else:
#      89             self.__connection = connection \
# ---> 90                 if connection is not None else engine.raw_connection()
#      91             self.__transaction = None
#      92             self.__savepoint_seq = 0
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in raw_connection(self, _connection)
#    2186         """
#    2187         return self._wrap_pool_connect(
# -> 2188             self.pool.unique_connection, _connection)
#    2189
#    2190
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    2160             if connection is None:
#    2161                 Connection._handle_dbapi_exception_noconnection(
# -> 2162                     e, dialect, self)
#    2163             else:
#    2164                 util.reraise(*sys.exc_info())
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    1474             util.raise_from_cause(
#    1475                 sqlalchemy_exception,
# -> 1476                 exc_info
#    1477             )
#    1478         else:
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/util/compat.py in raise_from_cause(exception, exc_info)
#     263     exc_type, exc_value, exc_tb = exc_info
#     264     cause = exc_value if exc_value is not exception else None
# --> 265     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     266
#     267 if py3k:
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/util/compat.py in reraise(tp, value, tb, cause)
#     246             value.__cause__ = cause
#     247         if value.__traceback__ is not tb:
# --> 248             raise value.with_traceback(tb)
#     249         raise value
#     250
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    2156         dialect = self.dialect
#    2157         try:
# -> 2158             return fn()
#    2159         except dialect.dbapi.Error as e:
#    2160             if connection is None:
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/pool.py in unique_connection(self)
#     343
#     344         """
# --> 345         return _ConnectionFairy._checkout(self)
#     346
#     347     def _create_connection(self):
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/pool.py in _checkout(cls, pool, threadconns, fairy)
#     789     def _checkout(cls, pool, threadconns=None, fairy=None):
#     790         if not fairy:
# --> 791             fairy = _ConnectionRecord.checkout(pool)
#     792
#     793             fairy._pool = pool
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/pool.py in checkout(cls, pool)
#     530     @classmethod
#     531     def checkout(cls, pool):
# --> 532         rec = pool._do_get()
#     533         try:
#     534             dbapi_connection = rec.get_connection()
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/pool.py in _do_get(self)
#    1194             except:
#    1195                 with util.safe_reraise():
# -> 1196                     self._dec_overflow()
#    1197         else:
#    1198             return self._do_get()
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/util/langhelpers.py in __exit__(self, type_, value, traceback)
#      64             self._exc_info = None   # remove potential circular references
#      65             if not self.warn_only:
# ---> 66                 compat.reraise(exc_type, exc_value, exc_tb)
#      67         else:
#      68             if not compat.py3k and self._exc_info and self._exc_info[1]:
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/util/compat.py in reraise(tp, value, tb, cause)
#     247         if value.__traceback__ is not tb:
#     248             raise value.with_traceback(tb)
# --> 249         raise value
#     250
#     251 else:
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/pool.py in _do_get(self)
#    1191         if self._inc_overflow():
#    1192             try:
# -> 1193                 return self._create_connection()
#    1194             except:
#    1195                 with util.safe_reraise():
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/pool.py in _create_connection(self)
#     348         """Called by subclasses to create a new ConnectionRecord."""
#     349
# --> 350         return _ConnectionRecord(self)
#     351
#     352     def _invalidate(self, connection, exception=None, _checkin=True):
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/pool.py in __init__(self, pool, connect)
#     475         self.__pool = pool
#     476         if connect:
# --> 477             self.__connect(first_connect_check=True)
#     478         self.finalize_callback = deque()
#     479
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/pool.py in __connect(self, first_connect_check)
#     672         try:
#     673             self.starttime = time.time()
# --> 674             connection = pool._invoke_creator(self)
#     675             pool.logger.debug("Created new connection %r", connection)
#     676             self.connection = connection
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/strategies.py in connect(connection_record)
#     104                         if connection is not None:
#     105                             return connection
# --> 106                 return dialect.connect(*cargs, **cparams)
#     107
#     108             creator = pop_kwarg('creator', connect)
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/default.py in connect(self, *cargs, **cparams)
#     410
#     411     def connect(self, *cargs, **cparams):
# --> 412         return self.dbapi.connect(*cargs, **cparams)
#     413
#     414     def create_connect_args(self, url):
#
# /anaconda3/lib/python3.7/site-packages/pymysql/__init__.py in Connect(*args, **kwargs)
#      92     """
#      93     from .connections import Connection
# ---> 94     return Connection(*args, **kwargs)
#      95
#      96 from . import connections as _orig_conn
#
# /anaconda3/lib/python3.7/site-packages/pymysql/connections.py in __init__(self, host, user, password, database, port, unix_socket, charset, sql_mode, read_default_file, conv, use_unicode, client_flag, cursorclass, init_command, connect_timeout, ssl, read_default_group, compress, named_pipe, autocommit, db, passwd, local_infile, max_allowed_packet, defer_connect, auth_plugin_map, read_timeout, write_timeout, bind_address, binary_prefix, program_name, server_public_key)
#     323             self._sock = None
#     324         else:
# --> 325             self.connect()
#     326
#     327     def _create_ssl_ctx(self, sslp):
#
# /anaconda3/lib/python3.7/site-packages/pymysql/connections.py in connect(self, sock)
#     597
#     598             self._get_server_information()
# --> 599             self._request_authentication()
#     600
#     601             if self.sql_mode is not None:
#
# /anaconda3/lib/python3.7/site-packages/pymysql/connections.py in _request_authentication(self)
#     859
#     860         self.write_packet(data)
# --> 861         auth_packet = self._read_packet()
#     862
#     863         # if authentication method isn't accepted the first byte
#
# /anaconda3/lib/python3.7/site-packages/pymysql/connections.py in _read_packet(self, packet_type)
#     682
#     683         packet = packet_type(buff, self.encoding)
# --> 684         packet.check_error()
#     685         return packet
#     686
#
# /anaconda3/lib/python3.7/site-packages/pymysql/protocol.py in check_error(self)
#     218             errno = self.read_uint16()
#     219             if DEBUG: print("errno =", errno)
# --> 220             err.raise_mysql_exception(self._data)
#     221
#     222     def dump(self):
#
# /anaconda3/lib/python3.7/site-packages/pymysql/err.py in raise_mysql_exception(data)
#     107         errval = data[3:].decode('utf-8', 'replace')
#     108     errorclass = error_map.get(errno, InternalError)
# --> 109     raise errorclass(errno, errval)
#
# OperationalError: (pymysql.err.OperationalError) (1045, "Access denied for user 'rl91qzpzgty8oaf1'@'136.49.116.130' (using password: YES)") (Background on this error at: http://sqlalche.me/e/e3q8)

# %%
Base.metadata.drop_all(conn)
Base.metadata.create_all(conn)

# %%
modified_daly_df.to_sql(User.__tablename__, conn, index=False, if_exists="append")
# Out:
# ---------------------------------------------------------------------------
# InternalError                             Traceback (most recent call last)
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1169                         parameters,
# -> 1170                         context)
#    1171             elif not parameters and context.no_parameters:
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py in do_executemany(self, cursor, statement, parameters, context)
#     104     def do_executemany(self, cursor, statement, parameters, context=None):
# --> 105         rowcount = cursor.executemany(statement, parameters)
#     106         if context is not None:
#
# /anaconda3/lib/python3.7/site-packages/pymysql/cursors.py in executemany(self, query, args)
#     196                                          self.max_stmt_length,
# --> 197                                          self._get_db().encoding)
#     198
#
# /anaconda3/lib/python3.7/site-packages/pymysql/cursors.py in _do_execute_many(self, prefix, values, postfix, args, max_stmt_length, encoding)
#     233             sql += v
# --> 234         rows += self.execute(sql + postfix)
#     235         self.rowcount = rows
#
# /anaconda3/lib/python3.7/site-packages/pymysql/cursors.py in execute(self, query, args)
#     169
# --> 170         result = self._query(query)
#     171         self._executed = query
#
# /anaconda3/lib/python3.7/site-packages/pymysql/cursors.py in _query(self, q)
#     327         self._clear_result()
# --> 328         conn.query(q)
#     329         self._do_get_result()
#
# /anaconda3/lib/python3.7/site-packages/pymysql/connections.py in query(self, sql, unbuffered)
#     516         self._execute_command(COMMAND.COM_QUERY, sql)
# --> 517         self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     518         return self._affected_rows
#
# /anaconda3/lib/python3.7/site-packages/pymysql/connections.py in _read_query_result(self, unbuffered)
#     731             result = MySQLResult(self)
# --> 732             result.read()
#     733         self._result = result
#
# /anaconda3/lib/python3.7/site-packages/pymysql/connections.py in read(self)
#    1074         try:
# -> 1075             first_packet = self.connection._read_packet()
#    1076
#
# /anaconda3/lib/python3.7/site-packages/pymysql/connections.py in _read_packet(self, packet_type)
#     683         packet = packet_type(buff, self.encoding)
# --> 684         packet.check_error()
#     685         return packet
#
# /anaconda3/lib/python3.7/site-packages/pymysql/protocol.py in check_error(self)
#     219             if DEBUG: print("errno =", errno)
# --> 220             err.raise_mysql_exception(self._data)
#     221
#
# /anaconda3/lib/python3.7/site-packages/pymysql/err.py in raise_mysql_exception(data)
#     108     errorclass = error_map.get(errno, InternalError)
# --> 109     raise errorclass(errno, errval)
#
# InternalError: (1054, "Unknown column 'Respiratory Infectious ' in 'field list'")
#
# The above exception was the direct cause of the following exception:
#
# InternalError                             Traceback (most recent call last)
# <ipython-input-15-2e9ac935f90b> in <module>()
# ----> 1 modified_daly_df.to_sql(User.__tablename__, conn, index=False, if_exists="append")
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in to_sql(self, name, con, schema, if_exists, index, index_label, chunksize, dtype)
#    2128         sql.to_sql(self, name, con, schema=schema, if_exists=if_exists,
#    2129                    index=index, index_label=index_label, chunksize=chunksize,
# -> 2130                    dtype=dtype)
#    2131
#    2132     def to_pickle(self, path, compression='infer',
#
# /anaconda3/lib/python3.7/site-packages/pandas/io/sql.py in to_sql(frame, name, con, schema, if_exists, index, index_label, chunksize, dtype)
#     448     pandas_sql.to_sql(frame, name, if_exists=if_exists, index=index,
#     449                       index_label=index_label, schema=schema,
# --> 450                       chunksize=chunksize, dtype=dtype)
#     451
#     452
#
# /anaconda3/lib/python3.7/site-packages/pandas/io/sql.py in to_sql(self, frame, name, if_exists, index, index_label, schema, chunksize, dtype)
#    1125                          schema=schema, dtype=dtype)
#    1126         table.create()
# -> 1127         table.insert(chunksize)
#    1128         if (not name.isdigit() and not name.islower()):
#    1129             # check for potentially case sensitivity issues (GH7815)
#
# /anaconda3/lib/python3.7/site-packages/pandas/io/sql.py in insert(self, chunksize)
#     639
#     640                 chunk_iter = zip(*[arr[start_i:end_i] for arr in data_list])
# --> 641                 self._execute_insert(conn, keys, chunk_iter)
#     642
#     643     def _query_iterator(self, result, chunksize, columns, coerce_float=True,
#
# /anaconda3/lib/python3.7/site-packages/pandas/io/sql.py in _execute_insert(self, conn, keys, data_iter)
#     614     def _execute_insert(self, conn, keys, data_iter):
#     615         data = [{k: v for k, v in zip(keys, row)} for row in data_iter]
# --> 616         conn.execute(self.insert_statement(), data)
#     617
#     618     def insert(self, chunksize=None):
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in execute(self, object, *multiparams, **params)
#     946             raise exc.ObjectNotExecutableError(object)
#     947         else:
# --> 948             return meth(self, multiparams, params)
#     949
#     950     def _execute_function(self, func, multiparams, params):
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/sql/elements.py in _execute_on_connection(self, connection, multiparams, params)
#     267     def _execute_on_connection(self, connection, multiparams, params):
#     268         if self.supports_execution:
# --> 269             return connection._execute_clauseelement(self, multiparams, params)
#     270         else:
#     271             raise exc.ObjectNotExecutableError(self)
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_clauseelement(self, elem, multiparams, params)
#    1058             compiled_sql,
#    1059             distilled_params,
# -> 1060             compiled_sql, distilled_params
#    1061         )
#    1062         if self._has_events or self.engine._has_events:
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1198                 parameters,
#    1199                 cursor,
# -> 1200                 context)
#    1201
#    1202         if self._has_events or self.engine._has_events:
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception(self, e, statement, parameters, cursor, context)
#    1411                 util.raise_from_cause(
#    1412                     sqlalchemy_exception,
# -> 1413                     exc_info
#    1414                 )
#    1415             else:
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/util/compat.py in raise_from_cause(exception, exc_info)
#     263     exc_type, exc_value, exc_tb = exc_info
#     264     cause = exc_value if exc_value is not exception else None
# --> 265     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     266
#     267 if py3k:
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/util/compat.py in reraise(tp, value, tb, cause)
#     246             value.__cause__ = cause
#     247         if value.__traceback__ is not tb:
# --> 248             raise value.with_traceback(tb)
#     249         raise value
#     250
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _execute_context(self, dialect, constructor, statement, parameters, *args)
#    1168                         statement,
#    1169                         parameters,
# -> 1170                         context)
#    1171             elif not parameters and context.no_parameters:
#    1172                 if self.dialect._has_events:
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/dialects/mysql/mysqldb.py in do_executemany(self, cursor, statement, parameters, context)
#     103
#     104     def do_executemany(self, cursor, statement, parameters, context=None):
# --> 105         rowcount = cursor.executemany(statement, parameters)
#     106         if context is not None:
#     107             context._rowcount = rowcount
#
# /anaconda3/lib/python3.7/site-packages/pymysql/cursors.py in executemany(self, query, args)
#     195             return self._do_execute_many(q_prefix, q_values, q_postfix, args,
#     196                                          self.max_stmt_length,
# --> 197                                          self._get_db().encoding)
#     198
#     199         self.rowcount = sum(self.execute(query, arg) for arg in args)
#
# /anaconda3/lib/python3.7/site-packages/pymysql/cursors.py in _do_execute_many(self, prefix, values, postfix, args, max_stmt_length, encoding)
#     232                 sql += b','
#     233             sql += v
# --> 234         rows += self.execute(sql + postfix)
#     235         self.rowcount = rows
#     236         return rows
#
# /anaconda3/lib/python3.7/site-packages/pymysql/cursors.py in execute(self, query, args)
#     168         query = self.mogrify(query, args)
#     169
# --> 170         result = self._query(query)
#     171         self._executed = query
#     172         return result
#
# /anaconda3/lib/python3.7/site-packages/pymysql/cursors.py in _query(self, q)
#     326         self._last_executed = q
#     327         self._clear_result()
# --> 328         conn.query(q)
#     329         self._do_get_result()
#     330         return self.rowcount
#
# /anaconda3/lib/python3.7/site-packages/pymysql/connections.py in query(self, sql, unbuffered)
#     515                 sql = sql.encode(self.encoding, 'surrogateescape')
#     516         self._execute_command(COMMAND.COM_QUERY, sql)
# --> 517         self._affected_rows = self._read_query_result(unbuffered=unbuffered)
#     518         return self._affected_rows
#     519
#
# /anaconda3/lib/python3.7/site-packages/pymysql/connections.py in _read_query_result(self, unbuffered)
#     730         else:
#     731             result = MySQLResult(self)
# --> 732             result.read()
#     733         self._result = result
#     734         if result.server_status is not None:
#
# /anaconda3/lib/python3.7/site-packages/pymysql/connections.py in read(self)
#    1073     def read(self):
#    1074         try:
# -> 1075             first_packet = self.connection._read_packet()
#    1076
#    1077             if first_packet.is_ok_packet():
#
# /anaconda3/lib/python3.7/site-packages/pymysql/connections.py in _read_packet(self, packet_type)
#     682
#     683         packet = packet_type(buff, self.encoding)
# --> 684         packet.check_error()
#     685         return packet
#     686
#
# /anaconda3/lib/python3.7/site-packages/pymysql/protocol.py in check_error(self)
#     218             errno = self.read_uint16()
#     219             if DEBUG: print("errno =", errno)
# --> 220             err.raise_mysql_exception(self._data)
#     221
#     222     def dump(self):
#
# /anaconda3/lib/python3.7/site-packages/pymysql/err.py in raise_mysql_exception(data)
#     107         errval = data[3:].decode('utf-8', 'replace')
#     108     errorclass = error_map.get(errno, InternalError)
# --> 109     raise errorclass(errno, errval)
#
# InternalError: (pymysql.err.InternalError) (1054, "Unknown column 'Respiratory Infectious ' in 'field list'") [SQL: 'INSERT INTO `DALY` (`Country`, `Infectious and parasitic diseases`, `Respiratory Infectious `, `Maternal conditions`, `Neonatal conditions`, `Nutritional deficiencies`, `Malignant neoplasms`, `Other neoplasms`, `Diabetes mellitus`, `Endocrine, blood, immune disorders`, `Mental and substance use disorders`, `Neurological conditions`, `Sense organ diseases`, `Cardiovascular diseases`, `Respiratory diseases`, `Digestive diseases`, `Genitourinary diseases`, `Skin diseases`, `Musculoskeletal diseases`, `Congenital anomalies`, `Oral conditions`, `Sudden infant death syndrome`, `Unintentional injuries`, `Intentional injuries`) VALUES (%(Country)s, %(Infectious and parasitic diseases)s, %(Respiratory Infectious )s, %(Maternal conditions)s, %(Neonatal conditions)s, %(Nutritional deficiencies)s, %(Malignant neoplasms)s, %(Other neoplasms)s, %(Diabetes mellitus)s, %(Endocrine, blood, immune disorders)s, %(Mental and substance use disorders)s, %(Neurological conditions)s, %(Sense organ diseases)s, %(Cardiovascular diseases)s, %(Respiratory diseases)s, %(Digestive diseases)s, %(Genitourinary diseases)s, %(Skin diseases)s, %(Musculoskeletal diseases)s, %(Congenital anomalies)s, %(Oral conditions)s, %(Sudden infant death syndrome)s, %(Unintentional injuries)s, %(Intentional injuries)s)'] [parameters: ({'Country': 'Afghanistan', 'Infectious and parasitic diseases': 2336.7, 'Respiratory Infectious ': 1424.9, 'Maternal conditions': 225.3, 'Neonatal conditions': 3675.8, 'Nutritional deficiencies': 233.5, 'Malignant neoplasms': 898.1, 'Other neoplasms': 48.6, 'Diabetes mellitus': 338.0, 'Endocrine, blood, immune disorders': 180.2, 'Mental and substance use disorders': 759.7, 'Neurological conditions': 338.7, 'Sense organ diseases': 373.2, 'Cardiovascular diseases': 1570.7, 'Respiratory diseases': 315.0, 'Digestive diseases': 267.7, 'Genitourinary diseases': 308.2, 'Skin diseases': 89.8, 'Musculoskeletal diseases': 298.2, 'Congenital anomalies': 666.4, 'Oral conditions': 55.2, 'Sudden infant death syndrome': 38.2, 'Unintentional injuries': 1329.8, 'Intentional injuries': 2372.6}, {'Country': 'Albania', 'Infectious and parasitic diseases': 10.0, 'Respiratory Infectious ': 14.4, 'Maternal conditions': 0.6, 'Neonatal conditions': 19.8, 'Nutritional deficiencies': 6.6, 'Malignant neoplasms': 137.9, 'Other neoplasms': 8.2, 'Diabetes mellitus': 10.1, 'Endocrine, blood, immune disorders': 7.9, 'Mental and substance use disorders': 55.2, 'Neurological conditions': 48.8, 'Sense organ diseases': 47.4, 'Cardiovascular diseases': 284.6, 'Respiratory diseases': 21.7, 'Digestive diseases': 18.9, 'Genitourinary diseases': 20.9, 'Skin diseases': 6.9, 'Musculoskeletal diseases': 45.6, 'Congenital anomalies': 18.3, 'Oral conditions': 10.5, 'Sudden infant death syndrome': 1.2, 'Unintentional injuries': 71.1, 'Intentional injuries': 17.3}, {'Country': 'Algeria', 'Infectious and parasitic diseases': 460.0, 'Respiratory Infectious ': 461.5, 'Maternal conditions': 62.0, 'Neonatal conditions': 1169.5, 'Nutritional deficiencies': 181.1, 'Malignant neoplasms': 871.8, 'Other neoplasms': 22.7, 'Diabetes mellitus': 407.8, 'Endocrine, blood, immune disorders': 118.4, 'Mental and substance use disorders': 927.8, 'Neurological conditions': 581.4, 'Sense organ diseases': 593.2, 'Cardiovascular diseases': 1576.5, 'Respiratory diseases': 279.3, 'Digestive diseases': 219.7, 'Genitourinary diseases': 348.1, 'Skin diseases': 111.4, 'Musculoskeletal diseases': 611.1, 'Congenital anomalies': 483.8, 'Oral conditions': 102.5, 'Sudden infant death syndrome': 24.4, 'Unintentional injuries': 1023.3, 'Intentional injuries': 195.5}, {'Country': 'Angola', 'Infectious and parasitic diseases': 5256.8, 'Respiratory Infectious ': 1866.6, 'Maternal conditions': 214.4, 'Neonatal conditions': 2959.0, 'Nutritional deficiencies': 746.3, 'Malignant neoplasms': 310.3, 'Other neoplasms': 19. ...

# %%
LEX_HALE_MERGED = pd.merge(renamed_one_df, renamed_three_df_filtered, on ="Country", how="inner")
LEX_HALE_MERGED.head()
# Out:
#                Country  Both sexes HALE  Male HALE  Female HALE  Year  \
# 0          Afghanistan             53.0       52.1         54.1  2016
# 1              Albania             68.1       66.7         69.6  2016
# 2              Algeria             65.5       65.4         65.6  2016
# 3               Angola             55.8       53.8         57.7  2016
# 4  Antigua and Barbuda             67.0       65.2         68.8  2016
#
#   Both sexes LEX Male LEX Female LEX
# 0           62.7       61       64.5
# 1           76.4     74.3       78.6
# 2           76.4     75.4       77.4
# 3           62.6     60.3       64.9
# 4             75     72.5       77.5

# %%
LEX_HALE_MERGED["Both sexes LEX"] = pd.to_numeric(
    LEX_HALE_MERGED["Both sexes LEX"])

# %%
LEX_HALE_MERGED["Male LEX"] = pd.to_numeric(
    LEX_HALE_MERGED["Male LEX"])

# %%
LEX_HALE_MERGED["Female LEX"] = pd.to_numeric(
    LEX_HALE_MERGED["Female LEX"])

# %%
LEX_HALE_MERGED["Dark_Years_Both"] = (LEX_HALE_MERGED["Both sexes LEX"] - LEX_HALE_MERGED["Both sexes HALE"])/LEX_HALE_MERGED["Both sexes LEX"]

# %%
LEX_HALE_MERGED["Dark_Years_Male"] = LEX_HALE_MERGED["Male LEX"] - LEX_HALE_MERGED["Male HALE"]

# %%
LEX_HALE_MERGED["Dark_Years_Female"] = LEX_HALE_MERGED["Female LEX"] - LEX_HALE_MERGED["Female HALE"]

# %%
dark_years_df = LEX_HALE_MERGED.loc[:, ["Country","Dark_Years_Both", "Dark_Years_Male", "Dark_Years_Female"]]
dark_years_df.head()
# Out:
#                Country  Dark_Years_Both  Dark_Years_Male  Dark_Years_Female
# 0          Afghanistan         0.154705              8.9               10.4
# 1              Albania         0.108639              7.6                9.0
# 2              Algeria         0.142670             10.0               11.8
# 3               Angola         0.108626              6.5                7.2
# 4  Antigua and Barbuda         0.106667              7.3                8.7

# %%
dark_years_df.to_csv("assets/data/darkyears2.csv", index=False, header=True)

# %%
merge_glusose_dark_years_df = pd.merge(renamed_two_df, dark_years_df, on ="Country", how="inner")

# %%
merge_glusose_dark_years__obesity_df = pd.merge(renamed_five_df, merge_glusose_dark_years_df, on ="Country", how="inner")

# %%
merge_glusose_dark_years__obesity_NCD_df = pd.merge(renamed_four_df_filtered, merge_glusose_dark_years__obesity_df, on ="Country", how="outer")

merge_glusose_dark_years__obesity_NCD_df.head()
# Out:
#        Country  Year                                 Causes Both sexes NCD  \
# 0  Afghanistan  2016                    Malignant neoplasms          19965
# 1  Afghanistan  2016                      Diabetes mellitus           7056
# 2  Afghanistan  2016                Cardiovascular diseases          51244
# 3  Afghanistan  2016  Chronic obstructive pulmonary disease           6715
# 4      Albania  2016                    Malignant neoplasms           5138
#
#   Male NCD Female NCD Both sexes Obesity Male Obesity Female Obesity  \
# 0    10702       9263               5.5          3.2            7.6
# 1     2437       4620               5.5          3.2            7.6
# 2    26828      24416               5.5          3.2            7.6
# 3     3560       3154               5.5          3.2            7.6
# 4     2903       2235              21.7         21.6           21.8
#
#   Both sexes Glucose Male Glucose Female Glucose  Dark_Years_Both  \
# 0              11.9         11.6           12.2          0.154705
# 1              11.9         11.6           12.2          0.154705
# 2              11.9         11.6           12.2          0.154705
# 3              11.9         11.6           12.2          0.154705
# 4               7.4          7.7            7.1          0.108639
#
#    Dark_Years_Male  Dark_Years_Female
# 0              8.9               10.4
# 1              8.9               10.4
# 2              8.9               10.4
# 3              8.9               10.4
# 4              7.6                9.0

# %%
#################################################
# Database Setup
#################################################

engine = create_engine(
    "mysql://rl91qzpzgty8oaf1:evamhxfd7l42mgso@y2w3wxldca8enczv.cbetxkdyhwsb.us-east-1.rds.amazonaws.com:3306/v21ogkg4wvsne316")
conn = engine.connect()
# Out:
# ---------------------------------------------------------------------------
# timeout                                   Traceback (most recent call last)
# /anaconda3/lib/python3.7/site-packages/pymysql/connections.py in connect(self, sock)
#     582                                 (self.host, self.port), self.connect_timeout,
# --> 583                                 **kwargs)
#     584                             break
#
# /anaconda3/lib/python3.7/socket.py in create_connection(address, timeout, source_address)
#     726     if err is not None:
# --> 727         raise err
#     728     else:
#
# /anaconda3/lib/python3.7/socket.py in create_connection(address, timeout, source_address)
#     715                 sock.bind(source_address)
# --> 716             sock.connect(sa)
#     717             # Break explicitly a reference cycle
#
# timeout: timed out
#
# During handling of the above exception, another exception occurred:
#
# OperationalError                          Traceback (most recent call last)
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    2157         try:
# -> 2158             return fn()
#    2159         except dialect.dbapi.Error as e:
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/pool.py in unique_connection(self)
#     344         """
# --> 345         return _ConnectionFairy._checkout(self)
#     346
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/pool.py in _checkout(cls, pool, threadconns, fairy)
#     790         if not fairy:
# --> 791             fairy = _ConnectionRecord.checkout(pool)
#     792
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/pool.py in checkout(cls, pool)
#     531     def checkout(cls, pool):
# --> 532         rec = pool._do_get()
#     533         try:
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/pool.py in _do_get(self)
#    1195                 with util.safe_reraise():
# -> 1196                     self._dec_overflow()
#    1197         else:
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/util/langhelpers.py in __exit__(self, type_, value, traceback)
#      65             if not self.warn_only:
# ---> 66                 compat.reraise(exc_type, exc_value, exc_tb)
#      67         else:
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/util/compat.py in reraise(tp, value, tb, cause)
#     248             raise value.with_traceback(tb)
# --> 249         raise value
#     250
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/pool.py in _do_get(self)
#    1192             try:
# -> 1193                 return self._create_connection()
#    1194             except:
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/pool.py in _create_connection(self)
#     349
# --> 350         return _ConnectionRecord(self)
#     351
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/pool.py in __init__(self, pool, connect)
#     476         if connect:
# --> 477             self.__connect(first_connect_check=True)
#     478         self.finalize_callback = deque()
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/pool.py in __connect(self, first_connect_check)
#     673             self.starttime = time.time()
# --> 674             connection = pool._invoke_creator(self)
#     675             pool.logger.debug("Created new connection %r", connection)
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/strategies.py in connect(connection_record)
#     105                             return connection
# --> 106                 return dialect.connect(*cargs, **cparams)
#     107
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/default.py in connect(self, *cargs, **cparams)
#     411     def connect(self, *cargs, **cparams):
# --> 412         return self.dbapi.connect(*cargs, **cparams)
#     413
#
# /anaconda3/lib/python3.7/site-packages/pymysql/__init__.py in Connect(*args, **kwargs)
#      93     from .connections import Connection
# ---> 94     return Connection(*args, **kwargs)
#      95
#
# /anaconda3/lib/python3.7/site-packages/pymysql/connections.py in __init__(self, host, user, password, database, port, unix_socket, charset, sql_mode, read_default_file, conv, use_unicode, client_flag, cursorclass, init_command, connect_timeout, ssl, read_default_group, compress, named_pipe, autocommit, db, passwd, local_infile, max_allowed_packet, defer_connect, auth_plugin_map, read_timeout, write_timeout, bind_address, binary_prefix, program_name, server_public_key)
#     324         else:
# --> 325             self.connect()
#     326
#
# /anaconda3/lib/python3.7/site-packages/pymysql/connections.py in connect(self, sock)
#     629                 if DEBUG: print(exc.traceback)
# --> 630                 raise exc
#     631
#
# OperationalError: (2003, "Can't connect to MySQL server on 'y2w3wxldca8enczv.cbetxkdyhwsb.us-east-1.rds.amazonaws.com' (timed out)")
#
# The above exception was the direct cause of the following exception:
#
# OperationalError                          Traceback (most recent call last)
# <ipython-input-46-fe05ae0bef7c> in <module>()
#       5 engine = create_engine(
#       6     "mysql://rl91qzpzgty8oaf1:evamhxfd7l42mgso@y2w3wxldca8enczv.cbetxkdyhwsb.us-east-1.rds.amazonaws.com:3306/v21ogkg4wvsne316")
# ----> 7 conn = engine.connect()
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in connect(self, **kwargs)
#    2100         """
#    2101
# -> 2102         return self._connection_cls(self, **kwargs)
#    2103
#    2104     def contextual_connect(self, close_with_result=False, **kwargs):
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in __init__(self, engine, connection, close_with_result, _branch_from, _execution_options, _dispatch, _has_events)
#      88         else:
#      89             self.__connection = connection \
# ---> 90                 if connection is not None else engine.raw_connection()
#      91             self.__transaction = None
#      92             self.__savepoint_seq = 0
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in raw_connection(self, _connection)
#    2186         """
#    2187         return self._wrap_pool_connect(
# -> 2188             self.pool.unique_connection, _connection)
#    2189
#    2190
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    2160             if connection is None:
#    2161                 Connection._handle_dbapi_exception_noconnection(
# -> 2162                     e, dialect, self)
#    2163             else:
#    2164                 util.reraise(*sys.exc_info())
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _handle_dbapi_exception_noconnection(cls, e, dialect, engine)
#    1474             util.raise_from_cause(
#    1475                 sqlalchemy_exception,
# -> 1476                 exc_info
#    1477             )
#    1478         else:
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/util/compat.py in raise_from_cause(exception, exc_info)
#     263     exc_type, exc_value, exc_tb = exc_info
#     264     cause = exc_value if exc_value is not exception else None
# --> 265     reraise(type(exception), exception, tb=exc_tb, cause=cause)
#     266
#     267 if py3k:
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/util/compat.py in reraise(tp, value, tb, cause)
#     246             value.__cause__ = cause
#     247         if value.__traceback__ is not tb:
# --> 248             raise value.with_traceback(tb)
#     249         raise value
#     250
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/base.py in _wrap_pool_connect(self, fn, connection)
#    2156         dialect = self.dialect
#    2157         try:
# -> 2158             return fn()
#    2159         except dialect.dbapi.Error as e:
#    2160             if connection is None:
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/pool.py in unique_connection(self)
#     343
#     344         """
# --> 345         return _ConnectionFairy._checkout(self)
#     346
#     347     def _create_connection(self):
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/pool.py in _checkout(cls, pool, threadconns, fairy)
#     789     def _checkout(cls, pool, threadconns=None, fairy=None):
#     790         if not fairy:
# --> 791             fairy = _ConnectionRecord.checkout(pool)
#     792
#     793             fairy._pool = pool
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/pool.py in checkout(cls, pool)
#     530     @classmethod
#     531     def checkout(cls, pool):
# --> 532         rec = pool._do_get()
#     533         try:
#     534             dbapi_connection = rec.get_connection()
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/pool.py in _do_get(self)
#    1194             except:
#    1195                 with util.safe_reraise():
# -> 1196                     self._dec_overflow()
#    1197         else:
#    1198             return self._do_get()
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/util/langhelpers.py in __exit__(self, type_, value, traceback)
#      64             self._exc_info = None   # remove potential circular references
#      65             if not self.warn_only:
# ---> 66                 compat.reraise(exc_type, exc_value, exc_tb)
#      67         else:
#      68             if not compat.py3k and self._exc_info and self._exc_info[1]:
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/util/compat.py in reraise(tp, value, tb, cause)
#     247         if value.__traceback__ is not tb:
#     248             raise value.with_traceback(tb)
# --> 249         raise value
#     250
#     251 else:
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/pool.py in _do_get(self)
#    1191         if self._inc_overflow():
#    1192             try:
# -> 1193                 return self._create_connection()
#    1194             except:
#    1195                 with util.safe_reraise():
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/pool.py in _create_connection(self)
#     348         """Called by subclasses to create a new ConnectionRecord."""
#     349
# --> 350         return _ConnectionRecord(self)
#     351
#     352     def _invalidate(self, connection, exception=None, _checkin=True):
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/pool.py in __init__(self, pool, connect)
#     475         self.__pool = pool
#     476         if connect:
# --> 477             self.__connect(first_connect_check=True)
#     478         self.finalize_callback = deque()
#     479
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/pool.py in __connect(self, first_connect_check)
#     672         try:
#     673             self.starttime = time.time()
# --> 674             connection = pool._invoke_creator(self)
#     675             pool.logger.debug("Created new connection %r", connection)
#     676             self.connection = connection
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/strategies.py in connect(connection_record)
#     104                         if connection is not None:
#     105                             return connection
# --> 106                 return dialect.connect(*cargs, **cparams)
#     107
#     108             creator = pop_kwarg('creator', connect)
#
# /anaconda3/lib/python3.7/site-packages/sqlalchemy/engine/default.py in connect(self, *cargs, **cparams)
#     410
#     411     def connect(self, *cargs, **cparams):
# --> 412         return self.dbapi.connect(*cargs, **cparams)
#     413
#     414     def create_connect_args(self, url):
#
# /anaconda3/lib/python3.7/site-packages/pymysql/__init__.py in Connect(*args, **kwargs)
#      92     """
#      93     from .connections import Connection
# ---> 94     return Connection(*args, **kwargs)
#      95
#      96 from . import connections as _orig_conn
#
# /anaconda3/lib/python3.7/site-packages/pymysql/connections.py in __init__(self, host, user, password, database, port, unix_socket, charset, sql_mode, read_default_file, conv, use_unicode, client_flag, cursorclass, init_command, connect_timeout, ssl, read_default_group, compress, named_pipe, autocommit, db, passwd, local_infile, max_allowed_packet, defer_connect, auth_plugin_map, read_timeout, write_timeout, bind_address, binary_prefix, program_name, server_public_key)
#     323             self._sock = None
#     324         else:
# --> 325             self.connect()
#     326
#     327     def _create_ssl_ctx(self, sslp):
#
# /anaconda3/lib/python3.7/site-packages/pymysql/connections.py in connect(self, sock)
#     628                 exc.traceback = traceback.format_exc()
#     629                 if DEBUG: print(exc.traceback)
# --> 630                 raise exc
#     631
#     632             # If e is neither DatabaseError or IOError, It's a bug.
#
# OperationalError: (pymysql.err.OperationalError) (2003, "Can't connect to MySQL server on 'y2w3wxldca8enczv.cbetxkdyhwsb.us-east-1.rds.amazonaws.com' (timed out)") (Background on this error at: http://sqlalche.me/e/e3q8)

# %%
from sqlalchemy.ext.declarative import declarative_base
Base = declarative_base()

# %%
from sqlalchemy import Column, Integer, String, Float
class User(Base):
    __tablename__ = "darkdark"
    Country = Column(String(255), primary_key=True)
    Year = Column(String(255))
    Causes = Column(String(255))
    Both_sexes_NCD = Column("Both sexes NCD", String(255))
    Male_NCD = Column("Male NCD", String(255))
    Female_NCD = Column("Female NCD", String(255))
    Both_sexes_Obesity = Column("Both sexes Obesity", String(255))
    Male_Obesity = Column("Male Obesity", String(255))
    Female_Obesity = Column("Female Obesity", String(255))
    Both_sexes_Glucose = Column("Both sexes Glucose", String(255))
    Male_Glucose = Column("Male Glucose", String(255))
    Female_Glucose = Column("Female Glucose", String(255))
    Dark_Years_Both = Column("Dark_Years_Both", String(255))
    Dark_Years_Male = Column("Dark_Years_Male", String(255))
    Dark_Years_Female = Column("Dark_Years_Female", String(255))

# %%
Base.metadata.create_all(conn)

# %%
merge_glusose_dark_years__obesity_NCD_df.to_sql(User.__tablename__, conn, index=False, if_exists="append")

# %%
import pymysql, os
pymysql.install_as_MySQLdb()

PASSWD = os.getenv("evamhxfd7l42mgso")
USER = "rl91qzpzgty8oaf1"
PORT = "3306"
DOMAIN = "y2w3wxldca8enczv.cbetxkdyhwsb.us-east-1.rds.amazonaws.com"
DB = "v21ogkg4wvsne316"
engine = create_engine(f"mysql://{USER}:{PASSWD}@{DOMAIN}:{PORT}/{DB}")
conn = engine.connect()

# %%
#default_schmea: v21ogkg4wvsne316

# %%
Base.metadata.drop_all(conn)
Base.metadata.create_all(conn)

# %%
merge_glusose_dark_years__obesity_NCD_df.to_sql(User.__tablename__, conn, index=False, if_exists="append")

# %%
modified_daly2 = "assets/data/daly_columned.csv"
modified_daly2_df = pd.read_csv(modified_daly2, encoding="ISO-8859-1")
modified_daly2_df

# %%
country_geo = 'assets/data/world-countries.json'

# %%
data = pd.read_csv('assets/data/newDaly.csv', encoding="ISO-8859-1")
data.shape

data.head()
# Out:
#                Country  Infectious_and_parasitic_diseases  \
# 0          Afghanistan                             2336.7
# 1              Albania                               10.0
# 2              Algeria                              460.0
# 3               Angola                             5256.8
# 4  Antigua and Barbuda                                1.2
#
#    Respiratory_Infectious  Maternal_conditions  Neonatal_conditions  \
# 0                  1424.9                225.3               3675.8
# 1                    14.4                  0.6                 19.8
# 2                   461.5                 62.0               1169.5
# 3                  1866.6                214.4               2959.0
# 4                     0.8                  0.2                  0.6
#
#    Nutritional_deficiencies  Malignant_neoplasms  Other_neoplasms  \
# 0                     233.5                898.1             48.6
# 1                       6.6                137.9              8.2
# 2                     181.1                871.8             22.7
# 3                     746.3                310.3             19.9
# 4                       0.6                  3.4              0.1
#
#    Diabetes_mellitus  Endocrine_blood_immune_disorders          ...           \
# 0              338.0                             180.2          ...
# 1               10.1                               7.9          ...
# 2              407.8                             118.4          ...
# 3              107.6                             157.9          ...
# 4                1.7                               0.7          ...
#
#    Respiratory_diseases  Digestive_diseases  Genitourinary_diseases  \
# 0                 315.0               267.7                   308.2
# 1                  21.7                18.9                    20.9
# 2                 279.3               219.7                   348.1
# 3                 215.1               395.4                   145.4
# 4                   1.0                 0.7                     0.8
#
#    Skin_diseases  Musculoskeletal_diseases  Congenital_anomalies  \
# 0           89.8                     298.2                 666.4
# 1            6.9                      45.6                  18.3
# 2          111.4                     611.1                 483.8
# 3          125.4                     170.8                 709.8
# 4            0.4                       1.4                   0.7
#
#    Oral_conditions  Sudden_infant_death_syndrome  Unintentional_injuries  \
# 0             55.2                          38.2                  1329.8
# 1             10.5                           1.2                    71.1
# 2            102.5                          24.4                  1023.3
# 3             37.5                          51.5                  1277.6
# 4              0.3                           0.0                     2.3
#
#    Intentional_injuries
# 0                2372.6
# 1                  17.3
# 2                 195.5
# 3                 287.8
# 4                   0.1
#
# [5 rows x 24 columns]

# %%
# mydf = data[['Country', 'Infectious and parasitic diseases', 'Maternal conditions', 'Diabetes mellitus']]

# %%
# new_column_names = [column.replace(" ", "_") for column in data.columns]
# new_column_names
# new_column_names[2] = 'Respiratory_Infectious'
# new_column_names[9] = 'Endocrine_blood_immune_disorders'
# new_column_names

# %%
# data.columns = new_column_names
# data.to_csv("assets/data/newDaly.csv", index=False)

# %%
# mydf.head()

# %%
# import folium

# %%
# map = folium.Map(location=[100, 0], zoom_start=1.5)

# %%
# map.choropleth(geo_data=country_geo, data=mydf,
#              columns=['Country', 'Maternal conditions'],
#              key_on='feature.properties.name',
#              fill_color='PuRd', fill_opacity=0.7, line_opacity=0.2)

# %%
# map.choropleth(geo_data=country_geo, data=mydf,
#              columns=['Country', 'Diabetes mellitus'],
#              key_on='feature.properties.name',
#              fill_color='YlGnBu', fill_opacity=0.7, line_opacity=0.2)

# %%
# map.save('plot_data.html')

# %%
# mydf.replace('Russian Federation', 'Russia', inplace=True)

# %%
# mydf.replace('The former Yugoslav Republic of Macedonia', 'Macedonia', inplace=True)

# %%
# mydf.loc[mydf['Country'] == 'Russia']

# %%
data.head()
# Out:
#                Country  Infectious_and_parasitic_diseases  \
# 0          Afghanistan                             2336.7
# 1              Albania                               10.0
# 2              Algeria                              460.0
# 3               Angola                             5256.8
# 4  Antigua and Barbuda                                1.2
#
#    Respiratory_Infectious  Maternal_conditions  Neonatal_conditions  \
# 0                  1424.9                225.3               3675.8
# 1                    14.4                  0.6                 19.8
# 2                   461.5                 62.0               1169.5
# 3                  1866.6                214.4               2959.0
# 4                     0.8                  0.2                  0.6
#
#    Nutritional_deficiencies  Malignant_neoplasms  Other_neoplasms  \
# 0                     233.5                898.1             48.6
# 1                       6.6                137.9              8.2
# 2                     181.1                871.8             22.7
# 3                     746.3                310.3             19.9
# 4                       0.6                  3.4              0.1
#
#    Diabetes_mellitus  Endocrine_blood_immune_disorders          ...           \
# 0              338.0                             180.2          ...
# 1               10.1                               7.9          ...
# 2              407.8                             118.4          ...
# 3              107.6                             157.9          ...
# 4                1.7                               0.7          ...
#
#    Respiratory_diseases  Digestive_diseases  Genitourinary_diseases  \
# 0                 315.0               267.7                   308.2
# 1                  21.7                18.9                    20.9
# 2                 279.3               219.7                   348.1
# 3                 215.1               395.4                   145.4
# 4                   1.0                 0.7                     0.8
#
#    Skin_diseases  Musculoskeletal_diseases  Congenital_anomalies  \
# 0           89.8                     298.2                 666.4
# 1            6.9                      45.6                  18.3
# 2          111.4                     611.1                 483.8
# 3          125.4                     170.8                 709.8
# 4            0.4                       1.4                   0.7
#
#    Oral_conditions  Sudden_infant_death_syndrome  Unintentional_injuries  \
# 0             55.2                          38.2                  1329.8
# 1             10.5                           1.2                    71.1
# 2            102.5                          24.4                  1023.3
# 3             37.5                          51.5                  1277.6
# 4              0.3                           0.0                     2.3
#
#    Intentional_injuries
# 0                2372.6
# 1                  17.3
# 2                 195.5
# 3                 287.8
# 4                   0.1
#
# [5 rows x 24 columns]

# %%
data['Cardiovascular_diseases'].max()
# Out:
# 97208.2

# %%
keys = data.columns.values
print(keys)
# Out:
# ['Country' 'Infectious_and_parasitic_diseases' 'Respiratory_Infectious'
#  'Maternal_conditions' 'Neonatal_conditions' 'Nutritional_deficiencies'
#  'Malignant_neoplasms' 'Other_neoplasms' 'Diabetes_mellitus'
#  'Endocrine_blood_immune_disorders' 'Mental_and_substance_use_disorders'
#  'Neurological_conditions' 'Sense_organ_diseases'
#  'Cardiovascular_diseases' 'Respiratory_diseases' 'Digestive_diseases'
#  'Genitourinary_diseases' 'Skin_diseases' 'Musculoskeletal_diseases'
#  'Congenital_anomalies' 'Oral_conditions' 'Sudden_infant_death_syndrome'
#  'Unintentional_injuries' 'Intentional_injuries']

# %%
def return_values(country):
    mydict = {}
    if ((data['Country'] == country).any()):
        myrow = data.loc[data['Country'] == country]
        for key in keys:
            mydict[key] = myrow.iloc[0,][key]
    else:
        for key in keys:
            mydict[key] = 0
    return(mydict)

# %%
return_values("blah")
# Out:
# {'Country': 0,
#  'Infectious_and_parasitic_diseases': 0,
#  'Respiratory_Infectious': 0,
#  'Maternal_conditions': 0,
#  'Neonatal_conditions': 0,
#  'Nutritional_deficiencies': 0,
#  'Malignant_neoplasms': 0,
#  'Other_neoplasms': 0,
#  'Diabetes_mellitus': 0,
#  'Endocrine_blood_immune_disorders': 0,
#  'Mental_and_substance_use_disorders': 0,
#  'Neurological_conditions': 0,
#  'Sense_organ_diseases': 0,
#  'Cardiovascular_diseases': 0,
#  'Respiratory_diseases': 0,
#  'Digestive_diseases': 0,
#  'Genitourinary_diseases': 0,
#  'Skin_diseases': 0,
#  'Musculoskeletal_diseases': 0,
#  'Congenital_anomalies': 0,
#  'Oral_conditions': 0,
#  'Sudden_infant_death_syndrome': 0,
#  'Unintentional_injuries': 0,
#  'Intentional_injuries': 0}

# %%
# data.head()

# %%
import json

with open('assets/data/world-countries.json') as f:
    worldData = json.load(f)

# append health data to geojson object for each country
for feature in worldData['features']:
    country = feature['properties']['name']
    country_dict = return_values(country)
    for key in country_dict.keys():
        feature['properties'][key] = country_dict[key]
# Out:
# dict

# %%
# with open('Daly.geo.json', 'w') as fp:
#     json.dump(worldData, fp)

# %%
# jsonDf['features']

# %%
countryData = pd.read_csv('assets/data/population_and_codes.csv', encoding="ISO-8859-1")

# %%
countryData.head()
# Out:
#   Unnamed: 0  Population ('000) (2)
# 0        AFG                  34,656
# 1        ALB                   2,926
# 2        DZA                  40,606
# 3        AGO                  28,813
# 4        ATG                     101

# %%
countryData.shape
# Out:
# (183, 2)

# %%
data.shape
# Out:
# (183, 24)

# %%
# countryData.head()

# %%
newCountryData = data.join(countryData)

# %%
newCountryData.loc[data['Country'] == 'Serbia', ['Unnamed: 0']]
# Out:
#     Unnamed: 0
# 141        SRB

# %%
newCountryData.columns
# Out:
# Index(['Country', 'Infectious_and_parasitic_diseases',
#        'Respiratory_Infectious', 'Maternal_conditions', 'Neonatal_conditions',
#        'Nutritional_deficiencies', 'Malignant_neoplasms', 'Other_neoplasms',
#        'Diabetes_mellitus', 'Endocrine_blood_immune_disorders',
#        'Mental_and_substance_use_disorders', 'Neurological_conditions',
#        'Sense_organ_diseases', 'Cardiovascular_diseases',
#        'Respiratory_diseases', 'Digestive_diseases', 'Genitourinary_diseases',
#        'Skin_diseases', 'Musculoskeletal_diseases', 'Congenital_anomalies',
#        'Oral_conditions', 'Sudden_infant_death_syndrome',
#        'Unintentional_injuries', 'Intentional_injuries', 'Unnamed: 0',
#        ' Population ('000) (2) '],
#       dtype='object')

# %%
newCountryData.rename(index=str, columns={"Unnamed: 0": "id", " Population ('000) (2) ": "Population"}, inplace=True)

# %%
newCountryData.to_csv("assets/data/newDaly.csv", index=False)

# %%
newCountryData.head()
# Out:
#                Country  Infectious_and_parasitic_diseases  \
# 0          Afghanistan                             2336.7
# 1              Albania                               10.0
# 2              Algeria                              460.0
# 3               Angola                             5256.8
# 4  Antigua and Barbuda                                1.2
#
#    Respiratory_Infectious  Maternal_conditions  Neonatal_conditions  \
# 0                  1424.9                225.3               3675.8
# 1                    14.4                  0.6                 19.8
# 2                   461.5                 62.0               1169.5
# 3                  1866.6                214.4               2959.0
# 4                     0.8                  0.2                  0.6
#
#    Nutritional_deficiencies  Malignant_neoplasms  Other_neoplasms  \
# 0                     233.5                898.1             48.6
# 1                       6.6                137.9              8.2
# 2                     181.1                871.8             22.7
# 3                     746.3                310.3             19.9
# 4                       0.6                  3.4              0.1
#
#    Diabetes_mellitus  Endocrine_blood_immune_disorders     ...      \
# 0              338.0                             180.2     ...
# 1               10.1                               7.9     ...
# 2              407.8                             118.4     ...
# 3              107.6                             157.9     ...
# 4                1.7                               0.7     ...
#
#    Genitourinary_diseases  Skin_diseases  Musculoskeletal_diseases  \
# 0                   308.2           89.8                     298.2
# 1                    20.9            6.9                      45.6
# 2                   348.1          111.4                     611.1
# 3                   145.4          125.4                     170.8
# 4                     0.8            0.4                       1.4
#
#    Congenital_anomalies  Oral_conditions  Sudden_infant_death_syndrome  \
# 0                 666.4             55.2                          38.2
# 1                  18.3             10.5                           1.2
# 2                 483.8            102.5                          24.4
# 3                 709.8             37.5                          51.5
# 4                   0.7              0.3                           0.0
#
#    Unintentional_injuries  Intentional_injuries   id  Population
# 0                  1329.8                2372.6  AFG      34,656
# 1                    71.1                  17.3  ALB       2,926
# 2                  1023.3                 195.5  DZA      40,606
# 3                  1277.6                 287.8  AGO      28,813
# 4                     2.3                   0.1  ATG         101
#
# [5 rows x 26 columns]

# %%
json
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-261-577411980790> in <module>
# ----> 1 int('34,656')
#
# ValueError: invalid literal for int() with base 10: '34,656'

# %%
import requests 
response = requests.get("https://dark-health-app.herokuapp.com/daly")
todos = json.loads(response.text)

# %%
todos
# Out:
# {'features': [{'geometry': {'coordinates': [[[61.210817, 35.650072],
#       [62.230651, 35.270664],
#       [62.984662, 35.404041],
#       [63.193538, 35.857166],
#       [63.982896, 36.007957],
#       [64.546479, 36.312073],
#       [64.746105, 37.111818],
#       [65.588948, 37.305217],
#       [65.745631, 37.661164],
#       [66.217385, 37.39379],
#       [66.518607, 37.362784],
#       [67.075782, 37.356144],
#       [67.83, 37.144994],
#       [68.135562, 37.023115],
#       [68.859446, 37.344336],
#       [69.196273, 37.151144],
#       [69.518785, 37.608997],
#       [70.116578, 37.588223],
#       [70.270574, 37.735165],
#       [70.376304, 38.138396],
#       [70.806821, 38.486282],
#       [71.348131, 38.258905],
#       [71.239404, 37.953265],
#       [71.541918, 37.905774],
#       [71.448693, 37.065645],
#       [71.844638, 36.738171],
#       [72.193041, 36.948288],
#       [72.63689, 37.047558],
#       [73.260056, 37.495257],
#       [73.948696, 37.421566],
#       [74.980002, 37.41999],
#       [75.158028, 37.133031],
#       [74.575893, 37.020841],
#       [74.067552, 36.836176],
#       [72.920025, 36.720007],
#       [71.846292, 36.509942],
#       [71.262348, 36.074388],
#       [71.498768, 35.650563],
#       [71.613076, 35.153203],
#       [71.115019, 34.733126],
#       [71.156773, 34.348911],
#       [70.881803, 33.988856],
#       [69.930543, 34.02012],
#       [70.323594, 33.358533],
#       [69.687147, 33.105499],
#       [69.262522, 32.501944],
#       [69.317764, 31.901412],
#       [68.926677, 31.620189],
#       [68.556932, 31.71331],
#       [67.792689, 31.58293],
#       [67.683394, 31.303154],
#       [66.938891, 31.304911],
#       [66.381458, 30.738899],
#       [66.346473, 29.887943],
#       [65.046862, 29.472181],
#       [64.350419, 29.560031],
#       [64.148002, 29.340819],
#       [63.550261, 29.468331],
#       [62.549857, 29.318572],
#       [60.874248, 29.829239],
#       [61.781222, 30.73585],
#       [61.699314, 31.379506],
#       [60.941945, 31.548075],
#       [60.863655, 32.18292],
#       [60.536078, 32.981269],
#       [60.9637, 33.528832],
#       [60.52843, 33.676446],
#       [60.803193, 34.404102],
#       [61.210817, 35.650072]]],
#     'type': 'Polygon'},
#    'id': 'AFG',
#    'properties': {'Cardiovascular_diseases': 4.532259926131117,
#     'Congenital_anomalies': 1.9228993536472763,
#     'Country': 'Afghanistan',
#     'Diabetes_mellitus': 0.9753000923361035,
#     'Digestive_diseases': 0.7724492151431209,
#     'Endocrine_blood_immune_disorders': 0.5199676823638042,
#     'Genitourinary_diseases': 0.8893120960295476,
#     'Infectious_and_parasitic_diseases': 6.74255540166205,
#     'Intentional_injuries': 6.846144967682363,
#     'Malignant_neoplasms': 2.5914704524469068,
#     'Maternal_conditions': 0.6501038781163435,
#     'Mental_and_substance_use_disorders': 2.192116805170822,
#     'Musculoskeletal_diseases': 0.8604570637119113,
#     'Neonatal_conditions': 10.606532779316712,
#     'Neurological_conditions': 0.9773199445983378,
#     'Nutritional_deficiencies': 0.6737650046168051,
#     'Oral_conditions': 0.1592797783933518,
#     'Other_neoplasms': 0.1402354570637119,
#     'Population': '34,656',
#     'Respiratory_Infectious': 4.111553554939982,
#     'Respiratory_diseases': 0.9089335180055401,
#     'Sense_organ_diseases': 1.0768698060941828,
#     'Skin_diseases': 0.25911819021237303,
#     'Sudden_infant_death_syndrome': 0.11022622345337027,
#     'Unintentional_injuries': 3.837142197599261,
#     'id': 'AFG',
#     'name': 'Afghanistan'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [[[[16.326528, -5.87747],
#        [16.57318, -6.622645],
#        [16.860191, -7.222298],
#        [17.089996, -7.545689],
#        [17.47297, -8.068551],
#        [18.134222, -7.987678],
#        [18.464176, -7.847014],
#        [19.016752, -7.988246],
#        [19.166613, -7.738184],
#        [19.417502, -7.155429],
#        [20.037723, -7.116361],
#        [20.091622, -6.94309],
#        [20.601823, -6.939318],
#        [20.514748, -7.299606],
#        [21.728111, -7.290872],
#        [21.746456, -7.920085],
#        [21.949131, -8.305901],
#        [21.801801, -8.908707],
#        [21.875182, -9.523708],
#        [22.208753, -9.894796],
#        [22.155268, -11.084801],
#        [22.402798, -10.993075],
#        [22.837345, -11.017622],
#        [23.456791, -10.867863],
#        [23.912215, -10.926826],
#        [24.017894, -11.237298],
#        [23.904154, -11.722282],
#        [24.079905, -12.191297],
#        [23.930922, -12.565848],
#        [24.016137, -12.911046],
#        [21.933886, -12.898437],
#        [21.887843, -16.08031],
#        [22.562478, -16.898451],
#        [23.215048, -17.523116],
#        [21.377176, -17.930636],
#        [18.956187, -17.789095],
#        [18.263309, -17.309951],
#        [14.209707, -17.353101],
#        [14.058501, -17.423381],
#        [13.462362, -16.971212],
#        [12.814081, -16.941343],
#        [12.215461, -17.111668],
#        [11.734199, -17.301889],
#        [11.640096, -16.673142],
#        [11.778537, -15.793816],
#        [12.123581, -14.878316],
#        [12.175619, -14.449144],
#        [12.500095, -13.5477],
#        [12.738479, -13.137906],
#        [13.312914, -12.48363],
#        [13.633721, -12.038645],
#        [13.738728, -11.297863],
#        [13.686379, -10.731076],
#        [13.387328, -10.373578],
#        [13.120988, -9.766897],
#        [12.87537, -9.166934],
#        [12.929061, -8.959091],
#        [13.236433, -8.562629],
#        [12.93304, -7.596539],
#        [12.728298, -6.927122],
#        [12.227347, -6.294448],
#        [12.322432, -6.100092],
#        [12.735171, -5.965682],
#        [13.024869, -5.984389],
#        [13.375597, -5.864241],
#        [16.326528, -5.87747]]],
#      [[[12.436688, -5.684304],
#        [12.182337, -5.789931],
#        [11.914963, -5.037987],
#        [12.318608, -4.60623],
#        [12.62076, -4.438023],
#        [12.995517, -4.781103],
#        [12.631612, -4.991271],
#        [12.468004, -5.248362],
#        [12.436688, -5.684304]]]],
#     'type': 'MultiPolygon'},
#    'id': 'AGO',
#    'properties': {'Cardiovascular_diseases': 2.3301981744351505,
#     'Congenital_anomalies': 2.4634713497379654,
#     'Country': 'Angola',
#     'Diabetes_mellitus': 0.3734425432964287,
#     'Digestive_diseases': 1.3722972269461702,
#     'Endocrine_blood_immune_disorders': 0.5480165203206886,
#     'Genitourinary_diseases': 0.5046333252351369,
#     'Infectious_and_parasitic_diseases': 18.24454239405824,
#     'Intentional_injuries': 0.9988546836497414,
#     'Malignant_neoplasms': 1.0769444348037345,
#     'Maternal_conditions': 0.7441085621073821,
#     'Mental_and_substance_use_disorders': 1.6683441502099747,
#     'Musculoskeletal_diseases': 0.592787977648978,
#     'Neonatal_conditions': 10.26966994065179,
#     'Neurological_conditions': 0.8051921007878389,
#     'Nutritional_deficiencies': 2.5901502793877764,
#     'Oral_conditions': 0.130149585256655,
#     'Other_neoplasms': 0.06906604657619825,
#     'Population': '28,813',
#     'Respiratory_Infectious': 6.478325755735257,
#     'Respiratory_diseases': 0.7465380210321729,
#     'Sense_organ_diseases': 0.9749071599625169,
#     'Skin_diseases': 0.43522021309825426,
#     'Sudden_infant_death_syndrome': 0.17873876375247283,
#     'Unintentional_injuries': 4.434109603304064,
#     'id': 'AGO',
#     'name': 'Angola'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [[[20.590247, 41.855404],
#       [20.463175, 41.515089],
#       [20.605182, 41.086226],
#       [21.02004, 40.842727],
#       [20.99999, 40.580004],
#       [20.674997, 40.435],
#       [20.615, 40.110007],
#       [20.150016, 39.624998],
#       [19.98, 39.694993],
#       [19.960002, 39.915006],
#       [19.406082, 40.250773],
#       [19.319059, 40.72723],
#       [19.40355, 41.409566],
#       [19.540027, 41.719986],
#       [19.371769, 41.877548],
#       [19.304486, 42.195745],
#       [19.738051, 42.688247],
#       [19.801613, 42.500093],
#       [20.0707, 42.58863],
#       [20.283755, 42.32026],
#       [20.52295, 42.21787],
#       [20.590247, 41.855404]]],
#     'type': 'Polygon'},
#    'id': 'ALB',
#    'properties': {'Cardiovascular_diseases': 9.726589200273411,
#     'Congenital_anomalies': 0.6254272043745729,
#     'Country': 'Albania',
#     'Diabetes_mellitus': 0.34518113465481887,
#     'Digestive_diseases': 0.6459330143540669,
#     'Endocrine_blood_immune_disorders': 0.26999316473000684,
#     'Genitourinary_diseases': 0.7142857142857143,
#     'Infectious_and_parasitic_diseases': 0.3417634996582365,
#     'Intentional_injuries': 0.5912508544087491,
#     'Malignant_neoplasms': 4.712918660287081,
#     'Maternal_conditions': 0.020505809979494187,
#     'Mental_and_substance_use_disorders': 1.8865345181134654,
#     'Musculoskeletal_diseases': 1.5584415584415585,
#     'Neonatal_conditions': 0.6766917293233082,
#     'Neurological_conditions': 1.667805878332194,
#     'Nutritional_deficiencies': 0.22556390977443605,
#     'Oral_conditions': 0.3588516746411483,
#     'Other_neoplasms': 0.2802460697197539,
#     'Population': '2,926',
#     'Respiratory_Infectious': 0.4921394395078606,
#     'Respiratory_diseases': 0.7416267942583732,
#     'Sense_organ_diseases': 1.619958988380041,
#     'Skin_diseases': 0.23581681476418317,
#     'Sudden_infant_death_syndrome': 0.041011619958988374,
#     'Unintentional_injuries': 2.429938482570061,
#     'id': 'ALB',
#     'name': 'Albania'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [[[51.579519, 24.245497],
#       [51.757441, 24.294073],
#       [51.794389, 24.019826],
#       [52.577081, 24.177439],
#       [53.404007, 24.151317],
#       [54.008001, 24.121758],
#       [54.693024, 24.797892],
#       [55.439025, 25.439145],
#       [56.070821, 26.055464],
#       [56.261042, 25.714606],
#       [56.396847, 24.924732],
#       [55.886233, 24.920831],
#       [55.804119, 24.269604],
#       [55.981214, 24.130543],
#       [55.528632, 23.933604],
#       [55.525841, 23.524869],
#       [55.234489, 23.110993],
#       [55.208341, 22.70833],
#       [55.006803, 22.496948],
#       [52.000733, 23.001154],
#       [51.617708, 24.014219],
#       [51.579519, 24.245497]]],
#     'type': 'Polygon'},
#    'id': 'ARE',
#    'properties': {'Cardiovascular_diseases': 2.43042071197411,
#     'Congenital_anomalies': 0.4379719525350594,
#     'Country': 'United Arab Emirates',
#     'Diabetes_mellitus': 0.8964401294498381,
#     'Digestive_diseases': 0.30312837108953616,
#     'Endocrine_blood_immune_disorders': 0.18446601941747573,
#     'Genitourinary_diseases': 0.6645091693635383,
#     'Infectious_and_parasitic_diseases': 0.5771305285868392,
#     'Intentional_injuries': 0.40884573894282633,
#     'Malignant_neoplasms': 0.7885652642934196,
#     'Maternal_conditions': 0.00970873786407767,
#     'Mental_and_substance_use_disorders': 2.669902912621359,
#     'Musculoskeletal_diseases': 1.5231930960086297,
#     'Neonatal_conditions': 0.45415318230852214,
#     'Neurological_conditions': 1.0248112189859764,
#     'Nutritional_deficiencies': 0.39697950377562025,
#     'Oral_conditions': 0.2286947141316073,
#     'Other_neoplasms': 0.006472491909385113,
#     'Population': '9,270',
#     'Respiratory_Infectious': 0.25026968716289105,
#     'Respiratory_diseases': 0.7011866235167207,
#     'Sense_organ_diseases': 0.889967637540453,
#     'Skin_diseases': 0.24595469255663432,
#     'Sudden_infant_death_syndrome': 0.016181229773462782,
#     'Unintentional_injuries': 1.9007551240560947,
#     'id': 'ARE',
#     'name': 'United Arab Emirates'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [[[[-65.5, -55.2],
#        [-66.45, -55.25],
#        [-66.95992, -54.89681],
#        [-67.56244, -54.87001],
#        [-68.63335, -54.8695],
#        [-68.63401, -52.63637],
#        [-68.25, -53.1],
#        [-67.75, -53.85],
#        [-66.45, -54.45],
#        [-65.05, -54.7],
#        [-65.5, -55.2]]],
#      [[[-64.964892, -22.075862],
#        [-64.377021, -22.798091],
#        [-63.986838, -21.993644],
#        [-62.846468, -22.034985],
#        [-62.685057, -22.249029],
#        [-60.846565, -23.880713],
#        [-60.028966, -24.032796],
#        [-58.807128, -24.771459],
#        [-57.777217, -25.16234],
#        [-57.63366, -25.603657],
#        [-58.618174, -27.123719],
#        [-57.60976, -27.395899],
#        [-56.486702, -27.548499],
#        [-55.695846, -27.387837],
#        [-54.788795, -26.621786],
#        [-54.625291, -25.739255],
#        [-54.13005, -25.547639],
#        [-53.628349, -26.124865],
#        [-53.648735, -26.923473],
#        [-54.490725, -27.474757],
#        [-55.162286, -27.881915],
#        [-56.2909, -28.852761],
#        [-57.625133, -30.216295],
#        [-57.874937, -31.016556],
#        [-58.14244, -32.044504],
#        [-58.132648, -33.040567],
#        [-58.349611, -33.263189],
#        [-58.427074, -33.909454],
#        [-58.495442, -34.43149],
#        [-57.22583, -35.288027],
#        [-57.362359, -35.97739],
#        [-56.737487, -36.413126],
#        [-56.788285, -36.901572],
#        [-57.749157, -38.183871],
#        [-59.231857, -38.72022],
#        [-61.237445, -38.928425],
#        [-62.335957, -38.827707],
#        [-62.125763, -39.424105],
#        [-62.330531, -40.172586],
#        [-62.145994, -40.676897],
#        [-62.745803, -41.028761],
#        [-63.770495, -41.166789],
#        [-64.73209, -40.802677],
#        [-65.118035, -41.064315],
#        [-64.978561, -42.058001],
#        [-64.303408, -42.359016],
#        [-63.755948, -42.043687],
#        [-63.458059, -42.563138],
#        [-64.378804, -42.873558],
#        [-65.181804, -43.495381],
#        [-65.328823, -44.501366],
#        [-65.565269, -45.036786],
#        [-66.509966, -45.039628],
#        [-67.293794, -45.551896],
#        [-67.580546, -46.301773],
#        [-66.597066, -47.033925],
#        [-65.641027, -47.236135],
#        [-65.985088, -48.133289],
#        [-67.166179, -48.697337],
#        [-67.816088, -49.869669],
#        [-68.728745, -50.264218],
#        [-69.138539, -50.73251],
#        [-68.815561, -51.771104],
#        [-68.149995, -52.349983],
#        [-68.571545, -52.299444],
#        [-69.498362, -52.142761],
#        [-71.914804, -52.009022],
#        [-72.329404, -51.425956],
#        [-72.309974, -50.67701],
#        [-72.975747, -50.74145],
#        [-73.328051, -50.378785],
#        [-73.415436, -49.318436],
#        [-72.648247, -48.878618],
#        [-72.331161, -48.244238],
#        [-72.447355, -47.738533],
#        [-71.917258, -46.884838],
#        [-71.552009, -45.560733],
#        [-71.659316, -44.973689],
#        [-71.222779, -44.784243],
#        [-71.329801, -44.407522],
#        [-71.793623, -44.207172],
#        [-71.464056, -43.787611],
#        [-71.915424, -43.408565],
#        [-72.148898, -42.254888],
#        [-71.746804, -42.051386],
#        [-71.915734, -40.832339],
#        [-71.680761, -39.808164],
#        [-71.413517, -38.916022],
#        [-70.814664, -38.552995],
#        [-71.118625, -37.576827],
#        [-71.121881, -36.658124],
#        [-70.364769, -36.005089],
#        [-70.388049, -35.169688],
#        [-69.817309, -34.193571],
#        [-69.814777, -33.273886],
#        [-70.074399, -33.09121],
#        [-70.535069, -31.36501],
#        [-69.919008, -30.336339],
#        [-70.01355, -29.367923],
#        [-69.65613, -28.459141],
#        [-69.001235, -27.521214],
#        [-68.295542, -26.89934],
#        [-68.5948, -26.506909],
#        [-68.386001, -26.185016],
#        [-68.417653, -24.518555],
#        [-67.328443, -24.025303],
#        [-66.985234, -22.986349],
#        [-67.106674, -22.735925],
#        [-66.273339, -21.83231],
#        [-64.964892, -22.075862]]]],
#     'type': 'MultiPolygon'},
#    'id': 'ARG',
#    'properties': {'Cardiovascular_diseases': 4.178393048555203,
#     'Congenital_anomalies': 0.6832850594111343,
#     'Country': 'Argentina',
#     'Diabetes_mellitus': 0.7995986042374621,
#     'Digestive_diseases': 1.0288047072775788,
#     'Endocrine_blood_immune_disorders': 0.23057449768513238,
#     'Genitourinary_diseases': 0.9163682806121285,
#     'Infectious_and_parasitic_diseases': 1.01284010308573,
#     'Intentional_injuries': 0.8926494400985243,
#     'Malignant_neoplasms': 3.7831550619198575,
#     'Maternal_conditions': 0.0663671402832577,
#     'Mental_and_substance_use_disorders': 2.5372317376331335,
#     'Musculoskeletal_diseases': 1.9276119232786735,
#     'Neonatal_conditions': 0.848404679909686,
#     'Neurological_conditions': 1.1029260838825918,
#     'Nutritional_deficiencies': 0.2027504732364814,
#     'Oral_conditions': 0.29420484867835883,
#     'Other_neoplasms': 0.18245261933541634,
#     'Population': '43,847',
#     'Respiratory_Infectious': 1.3994115903026434,
#     'Respiratory_diseases': 1.6733185850799372,
#     'Sense_organ_diseases': 1.1866262230027138,
#     'Skin_diseases': 0.34346705589892124,
#     'Sudden_infant_death_syndrome': 0.04903414144639314,
#     'Unintentional_injuries': 2.0758546764886994,
#     'id': 'ARG',
#     'name': 'Argentina'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [[[43.582746, 41.092143],
#       [44.97248, 41.248129],
#       [45.179496, 40.985354],
#       [45.560351, 40.81229],
#       [45.359175, 40.561504],
#       [45.891907, 40.218476],
#       [45.610012, 39.899994],
#       [46.034534, 39.628021],
#       [46.483499, 39.464155],
#       [46.50572, 38.770605],
#       [46.143623, 38.741201],
#       [45.735379, 39.319719],
#       [45.739978, 39.473999],
#       [45.298145, 39.471751],
#       [45.001987, 39.740004],
#       [44.79399, 39.713003],
#       [44.400009, 40.005],
#       [43.656436, 40.253564],
#       [43.752658, 40.740201],
#       [43.582746, 41.092143]]],
#     'type': 'Polygon'},
#    'id': 'ARM',
#    'properties': {'Cardiovascular_diseases': 7.7846153846153845,
#     'Congenital_anomalies': 0.6735042735042736,
#     'Country': 'Armenia',
#     'Diabetes_mellitus': 1.2478632478632479,
#     'Digestive_diseases': 1.2444444444444445,
#     'Endocrine_blood_immune_disorders': 0.16752136752136754,
#     'Genitourinary_diseases': 0.9777777777777777,
#     'Infectious_and_parasitic_diseases': 0.6256410256410256,
#     'Intentional_injuries': 0.441025641025641,
#     'Malignant_neoplasms': 7.114529914529914,
#     'Maternal_conditions': 0.020512820512820513,
#     'Mental_and_substance_use_disorders': 2.064957264957265,
#     'Musculoskeletal_diseases': 1.446153846153846,
#     'Neonatal_conditions': 0.8923076923076925,
#     'Neurological_conditions': 1.3982905982905982,
#     'Nutritional_deficiencies': 0.2803418803418803,
#     'Oral_conditions': 0.41709401709401706,
#     'Other_neoplasms': 0.07521367521367522,
#     'Population': '2,925',
#     'Respiratory_Infectious': 0.47863247863247865,
#     'Respiratory_diseases': 0.9162393162393163,
#     'Sense_organ_diseases': 1.7880341880341881,
#     'Skin_diseases': 0.24615384615384617,
#     'Sudden_infant_death_syndrome': 0.010256410256410256,
#     'Unintentional_injuries': 2.423931623931624,
#     'id': 'ARM',
#     'name': 'Armenia'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [[[[-59.572095, -80.040179],
#        [-59.865849, -80.549657],
#        [-60.159656, -81.000327],
#        [-62.255393, -80.863178],
#        [-64.488125, -80.921934],
#        [-65.741666, -80.588827],
#        [-65.741666, -80.549657],
#        [-66.290031, -80.255773],
#        [-64.037688, -80.294944],
#        [-61.883246, -80.39287],
#        [-61.138976, -79.981371],
#        [-60.610119, -79.628679],
#        [-59.572095, -80.040179]]],
#      [[[-159.208184, -79.497059],
#        [-161.127601, -79.634209],
#        [-162.439847, -79.281465],
#        [-163.027408, -78.928774],
#        [-163.066604, -78.869966],
#        [-163.712896, -78.595667],
#        [-163.712896, -78.595667],
#        [-163.105801, -78.223338],
#        [-161.245113, -78.380176],
#        [-160.246208, -78.693645],
#        [-159.482405, -79.046338],
#        [-159.208184, -79.497059]]],
#      [[[-45.154758, -78.04707],
#        [-43.920828, -78.478103],
#        [-43.48995, -79.08556],
#        [-43.372438, -79.516645],
#        [-43.333267, -80.026123],
#        [-44.880537, -80.339644],
#        [-46.506174, -80.594357],
#        [-48.386421, -80.829485],
#        [-50.482107, -81.025442],
#        [-52.851988, -80.966685],
#        [-54.164259, -80.633528],
#        [-53.987991, -80.222028],
#        [-51.853134, -79.94773],
#        [-50.991326, -79.614623],
#        [-50.364595, -79.183487],
#        [-49.914131, -78.811209],
#        [-49.306959, -78.458569],
#        [-48.660616, -78.047018],
#        [-48.660616, -78.047019],
#        [-48.151396, -78.04707],
#        [-46.662857, -77.831476],
#        [-45.154758, -78.04707]]],
#      [[[-121.211511, -73.50099],
#        [-119.918851, -73.657725],
#        [-118.724143, -73.481353],
#        [-119.292119, -73.834097],
#        [-120.232217, -74.08881],
#        [-121.62283, -74.010468],
#        [-122.621735, -73.657778],
#        [-122.621735, -73.657777],
#        [-122.406245, -73.324619],
#        [-121.211511, -73.50099]]],
#      [[[-125.559566, -73.481353],
#        [-124.031882, -73.873268],
#        [-124.619469, -73.834097],
#        [-125.912181, -73.736118],
#        [-127.28313, -73.461769],
#        [-127.28313, -73.461768],
#        [-126.558472, -73.246226],
#        [-125.559566, -73.481353]]],
#      [[[-98.98155, -71.933334],
#        [-97.884743, -72.070535],
#        [-96.787937, -71.952971],
#        [-96.20035, -72.521205],
#        [-96.983765, -72.442864],
#        [-98.198083, -72.482035],
#        [-99.432013, -72.442864],
#        [-100.783455, -72.50162],
#        [-101.801868, -72.305663],
#        [-102.330725, -71.894164],
#        [-102.330725, -71.894164],
#        [-101.703967, -71.717792],
#        [-100.430919, -71.854993],
#        [-98.98155, -71.933334]]],
#      [[[-68.451346, -70.955823],
#        [-68.333834, -71.406493],
#        [-68.510128, -71.798407],
#        [-68.784297, -72.170736],
#        [-69.959471, -72.307885],
#        [-71.075889, -72.503842],
#        [-72.388134, -72.484257],
#        [-71.8985, -72.092343],
#        [-73.073622, -72.229492],
#        [-74.19004, -72.366693],
#        [-74.953895, -72.072757],
#        [-75.012625, -71.661258],
#        [-73.915819, -71.269345],
#        [-73.915819, -71.269344],
#        [-73.230331, -71.15178],
#        [-72.074717, -71.190951],
#        [-71.780962, -70.681473],
#        [-71.72218, -70.309196],
#        [-71.741791, -69.505782],
#        [-71.173815, -69.035475],
#        [-70.253252, -68.87874],
#        [-69.724447, -69.251017],
#        [-69.489422, -69.623346],
#        [-69.058518, -70.074016],
#        [-68.725541, -70.505153],
#        [-68.451346, -70.955823]]],
#      [[[-58.614143, -64.152467],
#        [-59.045073, -64.36801],
#        [-59.789342, -64.211223],
#        [-60.611928, -64.309202],
#        [-61.297416, -64.54433],
#        [-62.0221, -64.799094],
#        [-62.51176, -65.09303],
#        [-62.648858, -65.484942],
#        [-62.590128, -65.857219],
#        [-62.120079, -66.190326],
#        [-62.805567, -66.425505],
#        [-63.74569, -66.503847],
#        [-64.294106, -66.837004],
#        [-64.881693, -67.150474],
#        [-65.508425, -67.58161],
#        [-65.665082, -67.953887],
#        [-65.312545, -68.365335],
#        [-64.783715, -68.678908],
#        [-63.961103, -68.913984],
#        [-63.1973, -69.227556],
#        [-62.785955, -69.619419],
#        [-62.570516, -69.991747],
#        [-62.276736, -70.383661],
#        [-61.806661, -70.716768],
#        [-61.512906, -71.089045],
#        [-61.375809, -72.010074],
#        [-61.081977, -72.382351],
#        [-61.003661, -72.774265],
#        [-60.690269, -73.166179],
#        [-60.827367, -73.695242],
#        [-61.375809, -74.106742],
#        [-61.96337, -74.439848],
#        [-63.295201, -74.576997],
#        [-63.74569, -74.92974],
#        [-64.352836, -75.262847],
#        [-65.860987, -75.635124],
#        [-67.192818, -75.79191],
#        [-68.446282, -76.007452],
#        [-69.797724, -76.222995],
#        [-70.600724, -76.634494],
#        [-72.206776, -76.673665],
#        [-73.969536, -76.634494],
#        [-75.555977, -76.712887],
#        [-77.24037, -76.712887],
#        [-76.926979, -77.104802],
#        [-75.399294, -77.28107],
#        [-74.282876, -77.55542],
#        [-73.656119, -77.908112],
#        [-74.772536, -78.221633],
#        [-76.4961, -78.123654],
#        [-77.925858, -78.378419],
#        [-77.984666, -78.789918],
#        [-78.023785, -79.181833],
#        [-76.848637, -79.514939],
#        [-76.633224, -79.887216],
#        [-75.360097, -80.259545],
#        [-73.244852, -80.416331],
#        [-71.442946, -80.69063],
#        [-70.013163, -81.004151],
#        [-68.191646, -81.317672],
#        [-65.704279, -81.474458],
#        [-63.25603, -81.748757],
#        [-61.552026, -82.042692],
#        [-59.691416, -82.37585],
#        [-58.712121, -82.846106],
#        [-58.222487, -83.218434],
#        [-57.008117, -82.865691],
#        [-55.362894, -82.571755],
#        [-53.619771, -82.258235],
#        [-51.543644, -82.003521],
#        [-49.76135, -81.729171],
#        [-47.273931, -81.709586],
#        [-44.825708, -81.846735],
#        [-42.808363, -82.081915],
#        [-42.16202, -81.65083],
#        [-40.771433, -81.356894],
#        [-38.244818, -81.337309],
#        [-36.26667, -81.121715],
#        [-34.386397, -80.906172],
#        [-32.310296, -80.769023],
#        [-30.097098, -80.592651],
#        [-28.549802, -80.337938],
#        [-29.254901, -79.985195],
#        [-29.685805, -79.632503],
#        [-29.685805, -79.260226],
#        [-31.624808, -79.299397],
#        [-33.681324, -79.456132],
#        [-35.639912, -79.456132],
#        [-35.914107, -79.083855],
#        [-35.77701, -78.339248],
#        [-35.326546, -78.123654],
#        [-33.896763, -77.888526],
#        [-32.212369, -77.65345],
#        [-30.998051, -77.359515],
#        [-29.783732, -77.065579],
#        [-28.882779, -76.673665],
#        [-27.511752, -76.497345],
#        [-26.160336, -76.360144],
#        [-25.474822, -76.281803],
#        [-23.927552, -76.24258],
#        [-22.458598, -76.105431],
#        [-21.224694, -75.909474],
#        [-20.010375, -75.674346],
#        [-18.913543, -75.439218],
#        [-17.522982, -75.125698],
#        [-16.641589, -74.79254],
#        [-15.701491, -74.498604],
#        [-15.40771, -74.106742],
#        [-16.46532, -73.871614],
#        [-16.112784, -73.460114],
#        [-15.446855, -73.146542],
#        [-14.408805, -72.950585],
#        [-13.311973, -72.715457],
#        [-12.293508, -72.401936],
#        [-11.510067, -72.010074],
#        [-11.020433, -71.539767],
#        [-10.295774, -71.265416],
#        [-9.101015, -71.324224],
#        [-8.611381, -71.65733],
#        [-7.416622, -71.696501],
#        [-7.377451, -71.324224],
#        [-6.868232, -70.93231],
#        [-5.790985, -71.030289],
#        [-5.536375, -71.402617],
#        [-4.341667, -71.461373],
#        [-3.048981, -71.285053],
#        [-1.795492, -71.167438],
#        [-0.659489, -71.226246],
#        [-0.228637, -71.637745],
#        [0.868195, -71.304639],
#        [1.886686, -71.128267],
#        [3.022638, -70.991118],
#        [4.139055, -70.853917],
#        [5.157546, -70.618789],
#        [6.273912, -70.462055],
#        [7.13572, -70.246512],
#        [7.742866, -69.893769],
#        [8.48711, -70.148534],
#        [9.525135, -70.011333],
#        [10.249845, -70.48164],
#        [10.817821, -70.834332],
#        [11.953824, -70.638375],
#        [12.404287, -70.246512],
#        [13.422778, -69.972162],
#        [14.734998, -70.030918],
#        [15.126757, -70.403247],
#        [15.949342, -70.030918],
#        [17.026589, -69.913354],
#        [18.201711, -69.874183],
#        [19.259373, -69.893769],
#        [20.375739, -70.011333],
#        [21.452985, -70.07014],
#        [21.923034, -70.403247],
#        [22.569403, -70.697182],
#        [23.666184, -70.520811],
#        [24.841357, -70.48164],
#        [25.977309, -70.48164],
#        [27.093726, -70.462055],
#        [28.09258, -70.324854],
#        [29.150242, -70.20729],
#        [30.031583, -69.93294],
#        [30.971733, -69.75662],
#        [31.990172, -69.658641],
#        [32.754053, -69.384291],
#        [33.302443, -68.835642],
#        [33.870419, -68.502588],
#        [34.908495, -68.659271],
#        [35.300202, -69.012014],
#        [36.16201, -69.247142],
#        [37.200035, -69.168748],
#        [37.905108, -69.52144],
#        [38.649404, -69.776205],
#        [39.667894, -69.541077],
#        [40.020431, -69.109941],
#        [40.921358, -68.933621],
#        [41.959434, -68.600514],
#        [42.938702, -68.463313],
#        [44.113876, -68.267408],
#        [44.897291, -68.051866],
#        [45.719928, -67.816738],
#        [46.503343, -67.601196],
#        [47.44344, -67.718759],
#        [48.344419, -67.366068],
#        [48.990736, -67.091718],
#        [49.930885, -67.111303],
#        [50.753471, -66.876175],
#        [50.949325, -66.523484],
#        [51.791547, -66.249133],
#        [52.614133, -66.053176],
#        [53.613038, -65.89639],
#        [54.53355, -65.818049],
#        [55.414943, -65.876805],
#        [56.355041, -65.974783],
#        [57.158093, -66.249133],
#        [57.255968, -66.680218],
#        [58.137361, -67.013324],
#        [58.744508, -67.287675],
#        [59.939318, -67.405239],
#        [60.605221, -67.679589],
#        [61.427806, -67.953887],
#        [62.387489, -68.012695],
#        [63.19049, -67.816738],
#        [64.052349, -67.405239],
#        [64.992447, -67.620729],
#        [65.971715, -67.738345],
#        [66.911864, -67.855909],
#        [67.891133, -67.934302],
#        [68.890038, -67.934302],
#        [69.712624, -68.972791],
#        [69.673453, -69.227556],
#        [69.555941, -69.678226],
#        [68.596258, -69.93294],
#        [67.81274, -70.305268],
#        [67.949889, -70.697182],
#        [69.066307, -70.677545],
#        [68.929157, -71.069459],
#        [68.419989, -71.441788],
#        [67.949889, -71.853287],
#        [68.71377, -72.166808],
#        [69.869307, -72.264787],
#        [71.024895, -72.088415],
#        [71.573285, -71.696501],
#        [71.906288, -71.324224],
#        [72.454627, -71.010703],
#        [73.08141, -70.716768],
#        [73.33602, -70.364024],
#        [73.864877, -69.874183],
#        [74.491557, -69.776205],
#        [75.62756, -69.737034],
#        [76.626465, -69.619419],
#        [77.644904, -69.462684],
#        [78.134539, -69.07077],
#        [78.428371, -68.698441],
#        [79.113859, -68.326216],
#        [80.093127, -68.071503],
#        [80.93535, -67.875546],
#        [81.483792, -67.542388],
#        [82.051767, -67.366068],
#        [82.776426, -67.209282],
#        [83.775331, -67.30726],
#        [84.676206, -67.209282],
#        [85.655527, -67.091718],
#        [86.752359, -67.150474],
#        [87.477017, -66.876175],
#        [87.986289, -66.209911],
#        [88.358411, -66.484261],
#        [88.828408, -66.954568],
#        [89.67063, -67.150474],
#        [90.630365, -67.228867],
#        [91.5901, -67.111303],
#        [92.608539, -67.189696],
#        [93.548637, -67.209282],
#        [94.17542, -67.111303],
#        [95.017591, -67.170111],
#        [95.781472, -67.385653],
#        [96.682399, -67.248504],
#        [97.759646, -67.248504],
#        [98.68021, -67.111303],
#        [99.718182, -67.248504],
#        [100.384188, -66.915346],
#        [100.893356, -66.58224],
#        [101.578896, -66.30789],
#        [102.832411, -65.563284],
#        [103.478676, -65.700485],
#        [104.242557, -65.974783],
#        [104.90846, -66.327527],
#        [106.181561, -66.934931],
#        [107.160881, -66.954568],
#        [108.081393, -66.954568],
#        [109.15864, -66.837004],
#        [110.235835, -66.699804],
#        [111.058472, -66.425505],
#        [111.74396, -66.13157],
#        [112.860378, -66.092347],
#        [113.604673, -65.876805],
#        [114.388088, -66.072762],
#        [114.897308, -66.386283],
#        [115.602381, -66.699804],
#        [116.699161, -66.660633],
#        [117.384701, -66.915346],
#        [118.57946, -67.170111],
#        [119.832924, -67.268089],
#        [120.871, -67.189696],
#        [121.654415, -66.876175],
#        [122.320369, -66.562654],
#        [123.221296, -66.484261],
#        [124.122274, -66.621462],
#        [125.160247, -66.719389],
#        [126.100396, -66.562654],
#        [127.001427, -66.562654],
#        [127.882768, -66.660633],
#        [128.80328, -66.758611],
#        [129.704259, -66.58224],
#        [130.781454, -66.425505],
#        [131.799945, -66.386283],
#        [132.935896, -66.386283],
#        [133.85646, -66.288304],
#        [134.757387, -66.209963],
#        [135.031582, -65.72007],
#        [135.070753, -65.308571],
#        [135.697485, -65.582869],
#        [135.873805, -66.033591],
#        [136.206705, -66.44509],
#        [136.618049, -66.778197],
#        [137.460271, -66.954568],
#        [138.596223, -66.895761],
#        [139.908442, -66.876175],
#        [140.809421, -66.817367],
#        [142.121692, -66.817367],
#        [143.061842, -66.797782],
#        [144.374061, -66.837004],
#        [145.490427, -66.915346],
#        [146.195552, -67.228867],
#        [145.999699, -67.601196],
#        [146.646067, -67.895131],
#        [147.723263, -68.130259],
#        [148.839629, -68.385024],
#        [150.132314, -68.561292],
#        [151.483705, -68.71813],
#        [152.502247, -68.874813],
#        [153.638199, -68.894502],
#        [154.284567, -68.561292],
#        [155.165857, -68.835642],
#        [155.92979, -69.149215],
#        [156.811132, -69.384291],
#        [158.025528, -69.482269],
#        [159.181013, -69.599833],
#        [159.670699, -69.991747],
#        [160.80665, -70.226875],
#        [161.570479, -70.579618],
#        [162.686897, -70.736353],
#        [163.842434, -70.716768],
#        [164.919681, -70.775524],
#        [166.11444, -70.755938],
#        [167.309095, -70.834332],
#        [168.425616, -70.971481],
#        [169.463589, -71.20666],
#        [170.501665, -71.402617],
#        [171.20679, -71.696501],
#        [171.089227, -72.088415],
#        [170.560422, -72.441159],
#        [170.109958, -72.891829],
#        [169.75737, -73.24452],
#        [169.287321, -73.65602],
#        [167.975101, -73.812806],
#        [167.387489, -74.165498],
#        [166.094803, -74.38104],
#        [165.644391, -74.772954],
#        [164.958851, -75.145283],
#        [164.234193, -75.458804],
#        [163.822797, -75.870303],
#        [163.568239, -76.24258],
#        [163.47026, -76.693302],
#        [163.489897, -77.065579],
#        [164.057873, -77.457442],
#        [164.273363, -77.82977],
#        [164.743464, -78.182514],
#        [166.604126, -78.319611],
#        [166.995781, -78.750748],
#        [165.193876, -78.907483],
#        [163.666217, -79.123025],
#        [161.766385, -79.162248],
#        [160.924162, -79.730482],
#        [160.747894, -80.200737],
#        [160.316964, -80.573066],
#        [159.788211, -80.945395],
#        [161.120016, -81.278501],
#        [161.629287, -81.690001],
#        [162.490992, -82.062278],
#        [163.705336, -82.395435],
#        [165.095949, -82.708956],
#        [166.604126, -83.022477],
#        [168.895665, -83.335998],
#        [169.404782, -83.825891],
#        [172.283934, -84.041433],
#        [172.477049, -84.117914],
#        [173.224083, -84.41371],
#        [175.985672, -84.158997],
#        [178.277212, -84.472518],
#        [180, -84.71338],
#        [-179.942499, -84.721443],
#        [-179.058677, -84.139412],
#        [-177.256772, -84.452933],
#        [-177.140807, -84.417941],
#        [-176.084673, -84.099259],
#        [-175.947235, -84.110449],
#        [-175.829882, -84.117914],
#        [-174.382503, -84.534323],
#        [-173.116559, -84.117914],
#        [-172.889106, -84.061019],
#        [-169.951223, -83.884647],
#        [-168.999989, -84.117914],
#        [-168.530199, -84.23739],
#        [-167.022099, -84.570497],
#        [-164.182144, -84.82521],
#        [-161.929775, -85.138731],
#        [-158.07138, -85.37391],
#        [-155.192253, -85.09956],
#        [-150.942099, -85.295517],
#        [-148.533073, -85.609038],
#        [-145.888918, -85.315102],
#        [-143.107718, -85.040752],
#        [-142.892279, -84.570497],
#        [-146.829068, -84.531274],
#        [-150.060732, -84.296146],
#        [-150.902928, -83.904232],
#        [-153.586201, -83.68869],
#        [-153.409907, -83.23802],
#        [-153.037759, -82.82652],
#        [-152.665637, -82.454192],
#        [-152.861517, -82.042692],
#        [-154.526299, -81.768394],
#        [-155.29018, -81.41565],
#        [-156.83745, -81.102129],
#        [-154.408787, -81.160937],
#        [-152.097662, -81.004151],
#        [-150.648293, -81.337309],
#        [-148.865998, -81.043373],
#        [-147.22075, -80.671045],
#        [-146.417749, -80.337938],
#        [-146.770286, -79.926439],
#        [-148.062947, -79.652089],
#        [-149.531901, -79.358205],
#        [-151.588416, -79.299397],
#        [-153.390322, -79.162248],
#        [-155.329376, -79.064269],
#        [-155.975668, -78.69194],
#        [-157.268302, -78.378419],
#        [-158.051768, -78.025676],
#        [-158.365134, -76.889207],
#        [-157.875474, -76.987238],
#        [-156.974573, -77.300759],
#        [-155.329376, -77.202728],
#        [-153.742832, -77.065579],
#        [-152.920247, -77.496664],
#        [-151.33378, -77.398737],
#        [-150.00195, -77.183143],
#        [-148.748486, -76.908845],
#        [-147.612483, -76.575738],
#        [-146.104409, -76.47776],
#        [-146.143528, -76.105431],
#        [-146.496091, -75.733154],
#        [-146.20231, -75.380411],
#        [-144.909624, -75.204039],
#        [-144.322037, -75.537197],
#        [-142.794353, -75.34124],
#        [-141.638764, -75.086475],
#        [-140.209007, -75.06689],
#        [-138.85759, -74.968911],
#        [-137.5062, -74.733783],
#        [-136.428901, -74.518241],
#        [-135.214583, -74.302699],
#        [-134.431194, -74.361455],
#        [-133.745654, -74.439848],
#        [-132.257168, -74.302699],
#        [-130.925311, -74.479019],
#        [-129.554284, -74.459433],
#        [-128.242038, -74.322284],
#        [-126.890622, -74.420263],
#        [-125.402082, -74.518241],
#        [-124.011496, -74.479019],
#        [-122.562152, -74.498604],
#        [-121.073613, -74.518241],
#        [-119.70256, -74.479019],
#        [-118.684145, -74.185083],
#        [-117.469801, -74.028348],
#        [-116.216312, -74.243891],
#        [-115.021552, -74.067519],
#        [-113.944331, -73.714828],
#        [-113.297988, -74.028348],
#        [-112.945452, -74.38104],
#        [-112.299083, -74.714198],
#        [-111.261059, -74.420263],
#        [-110.066325, -74.79254],
#        [-108.714909, -74.910103],
#        [-107.559346, -75.184454],
#        [-106.149148, -75.125698],
#        [-104.876074, -74.949326],
#        [-103.367949, -74.988497],
#        [-102.016507, -75.125698],
#        [-100.645531, -75.302018],
#        [-100.1167, -74.870933],
#        [-100.763043, -74.537826],
#        [-101.252703, -74.185083],
#        [-102.545337, -74.106742],
#        [-103.113313, -73.734413],
#        [-103.328752, -73.362084],
#        [-103.681289, -72.61753],
#        [-102.917485, -72.754679],
#        [-101.60524, -72.813436],
#        [-100.312528, -72.754679],
#        [-99.13738, -72.911414],
#        [-98.118889, -73.20535],
#        [-97.688037, -73.558041],
#        [-96.336595, -73.616849],
#        [-95.043961, -73.4797],
#        [-93.672907, -73.283743],
#        [-92.439003, -73.166179],
#        [-91.420564, -73.401307],
#        [-90.088733, -73.322914],
#        [-89.226951, -72.558722],
#        [-88.423951, -73.009393],
#        [-87.268337, -73.185764],
#        [-86.014822, -73.087786],
#        [-85.192236, -73.4797],
#        [-83.879991, -73.518871],
#        [-82.665646, -73.636434],
#        [-81.470913, -73.851977],
#        [-80.687447, -73.4797],
#        [-80.295791, -73.126956],
#        [-79.296886, -73.518871],
#        [-77.925858, -73.420892],
#        [-76.907367, -73.636434],
#        [-76.221879, -73.969541],
#        [-74.890049, -73.871614],
#        [-73.852024, -73.65602],
#        [-72.833533, -73.401307],
#        [-71.619215, -73.264157],
#        [-70.209042, -73.146542],
#        [-68.935916, -73.009393],
#        [-67.956622, -72.79385],
#        [-67.369061, -72.480329],
#        [-67.134036, -72.049244],
#        [-67.251548, -71.637745],
#        [-67.56494, -71.245831],
#        [-67.917477, -70.853917],
#        [-68.230843, -70.462055],
#        [-68.485452, -70.109311],
#        [-68.544209, -69.717397],
#        [-68.446282, -69.325535],
#        [-67.976233, -68.953206],
#        [-67.5845, -68.541707],
#        [-67.427843, -68.149844],
#        [-67.62367, -67.718759],
#        [-67.741183, -67.326845],
#        [-67.251548, -66.876175],
#        [-66.703184, -66.58224],
#        [-66.056815, -66.209963],
#        [-65.371327, -65.89639],
#        [-64.568276, -65.602506],
#        [-64.176542, -65.171423],
#        [-63.628152, -64.897073],
#        [-63.001394, -64.642308],
#        [-62.041686, -64.583552],
#        [-61.414928, -64.270031],
#        [-60.709855, -64.074074],
#        [-59.887269, -63.95651],
#        [-59.162585, -63.701745],
#        [-58.594557, -63.388224],
#        [-57.811143, -63.27066],
#        [-57.223582, -63.525425],
#        [-57.59573, -63.858532],
#        [-58.614143, -64.152467]]]],
#     'type': 'MultiPolygon'},
#    'id': 'ATA',
#    'properties': {'Cardiovascular_diseases': 0,
#     'Congenital_anomalies': 0,
#     'Country': 0,
#     'Diabetes_mellitus': 0,
#     'Digestive_diseases': 0,
#     'Endocrine_blood_immune_disorders': 0,
#     'Genitourinary_diseases': 0,
#     'Infectious_and_parasitic_diseases': 0,
#     'Intentional_injuries': 0,
#     'Malignant_neoplasms': 0,
#     'Maternal_conditions': 0,
#     'Mental_and_substance_use_disorders': 0,
#     'Musculoskeletal_diseases': 0,
#     'Neonatal_conditions': 0,
#     'Neurological_conditions': 0,
#     'Nutritional_deficiencies': 0,
#     'Oral_conditions': 0,
#     'Other_neoplasms': 0,
#     'Population': 0,
#     'Respiratory_Infectious': 0,
#     'Respiratory_diseases': 0,
#     'Sense_organ_diseases': 0,
#     'Skin_diseases': 0,
#     'Sudden_infant_death_syndrome': 0,
#     'Unintentional_injuries': 0,
#     'id': 0,
#     'name': 'Antarctica'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [[[68.935, -48.625],
#       [69.58, -48.94],
#       [70.525, -49.065],
#       [70.56, -49.255],
#       [70.28, -49.71],
#       [68.745, -49.775],
#       [68.72, -49.2425],
#       [68.8675, -48.83],
#       [68.935, -48.625]]],
#     'type': 'Polygon'},
#    'id': 'ATF',
#    'properties': {'Cardiovascular_diseases': 0,
#     'Congenital_anomalies': 0,
#     'Country': 0,
#     'Diabetes_mellitus': 0,
#     'Digestive_diseases': 0,
#     'Endocrine_blood_immune_disorders': 0,
#     'Genitourinary_diseases': 0,
#     'Infectious_and_parasitic_diseases': 0,
#     'Intentional_injuries': 0,
#     'Malignant_neoplasms': 0,
#     'Maternal_conditions': 0,
#     'Mental_and_substance_use_disorders': 0,
#     'Musculoskeletal_diseases': 0,
#     'Neonatal_conditions': 0,
#     'Neurological_conditions': 0,
#     'Nutritional_deficiencies': 0,
#     'Oral_conditions': 0,
#     'Other_neoplasms': 0,
#     'Population': 0,
#     'Respiratory_Infectious': 0,
#     'Respiratory_diseases': 0,
#     'Sense_organ_diseases': 0,
#     'Skin_diseases': 0,
#     'Sudden_infant_death_syndrome': 0,
#     'Unintentional_injuries': 0,
#     'id': 0,
#     'name': 'French Southern and Antarctic Lands'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [[[[145.397978, -40.792549],
#        [146.364121, -41.137695],
#        [146.908584, -41.000546],
#        [147.689259, -40.808258],
#        [148.289068, -40.875438],
#        [148.359865, -42.062445],
#        [148.017301, -42.407024],
#        [147.914052, -43.211522],
#        [147.564564, -42.937689],
#        [146.870343, -43.634597],
#        [146.663327, -43.580854],
#        [146.048378, -43.549745],
#        [145.43193, -42.693776],
#        [145.29509, -42.03361],
#        [144.718071, -41.162552],
#        [144.743755, -40.703975],
#        [145.397978, -40.792549]]],
#      [[[143.561811, -13.763656],
#        [143.922099, -14.548311],
#        [144.563714, -14.171176],
#        [144.894908, -14.594458],
#        [145.374724, -14.984976],
#        [145.271991, -15.428205],
#        [145.48526, -16.285672],
#        [145.637033, -16.784918],
#        [145.888904, -16.906926],
#        [146.160309, -17.761655],
#        [146.063674, -18.280073],
#        [146.387478, -18.958274],
#        [147.471082, -19.480723],
#        [148.177602, -19.955939],
#        [148.848414, -20.39121],
#        [148.717465, -20.633469],
#        [149.28942, -21.260511],
#        [149.678337, -22.342512],
#        [150.077382, -22.122784],
#        [150.482939, -22.556142],
#        [150.727265, -22.402405],
#        [150.899554, -23.462237],
#        [151.609175, -24.076256],
#        [152.07354, -24.457887],
#        [152.855197, -25.267501],
#        [153.136162, -26.071173],
#        [153.161949, -26.641319],
#        [153.092909, -27.2603],
#        [153.569469, -28.110067],
#        [153.512108, -28.995077],
#        [153.339095, -29.458202],
#        [153.069241, -30.35024],
#        [153.089602, -30.923642],
#        [152.891578, -31.640446],
#        [152.450002, -32.550003],
#        [151.709117, -33.041342],
#        [151.343972, -33.816023],
#        [151.010555, -34.31036],
#        [150.714139, -35.17346],
#        [150.32822, -35.671879],
#        [150.075212, -36.420206],
#        [149.946124, -37.109052],
#        [149.997284, -37.425261],
#        [149.423882, -37.772681],
#        [148.304622, -37.809061],
#        [147.381733, -38.219217],
#        [146.922123, -38.606532],
#        [146.317922, -39.035757],
#        [145.489652, -38.593768],
#        [144.876976, -38.417448],
#        [145.032212, -37.896188],
#        [144.485682, -38.085324],
#        [143.609974, -38.809465],
#        [142.745427, -38.538268],
#        [142.17833, -38.380034],
#        [141.606582, -38.308514],
#        [140.638579, -38.019333],
#        [139.992158, -37.402936],
#        [139.806588, -36.643603],
#        [139.574148, -36.138362],
#        [139.082808, -35.732754],
#        [138.120748, -35.612296],
#        [138.449462, -35.127261],
#        [138.207564, -34.384723],
#        [137.71917, -35.076825],
#        [136.829406, -35.260535],
#        [137.352371, -34.707339],
#        [137.503886, -34.130268],
#        [137.890116, -33.640479],
#        [137.810328, -32.900007],
#        [136.996837, -33.752771],
#        [136.372069, -34.094766],
#        [135.989043, -34.890118],
#        [135.208213, -34.47867],
#        [135.239218, -33.947953],
#        [134.613417, -33.222778],
#        [134.085904, -32.848072],
#        [134.273903, -32.617234],
#        [132.990777, -32.011224],
#        [132.288081, -31.982647],
#        [131.326331, -31.495803],
#        [129.535794, -31.590423],
#        [128.240938, -31.948489],
#        [127.102867, -32.282267],
#        [126.148714, -32.215966],
#        [125.088623, -32.728751],
#        [124.221648, -32.959487],
#        [124.028947, -33.483847],
#        [123.659667, -33.890179],
#        [122.811036, -33.914467],
#        [122.183064, -34.003402],
#        [121.299191, -33.821036],
#        [120.580268, -33.930177],
#        [119.893695, -33.976065],
#        [119.298899, -34.509366],
#        [119.007341, -34.464149],
#        [118.505718, -34.746819],
#        [118.024972, -35.064733],
#        [117.295507, -35.025459],
#        [116.625109, -35.025097],
#        [115.564347, -34.386428],
#        [115.026809, -34.196517],
#        [115.048616, -33.623425],
#        [115.545123, -33.487258],
#        [115.714674, -33.259572],
#        [115.679379, -32.900369],
#        [115.801645, -32.205062],
#        [115.689611, -31.612437],
#        [115.160909, -30.601594],
#        [114.997043, -30.030725],
#        [115.040038, -29.461095],
#        [114.641974, -28.810231],
#        [114.616498, -28.516399],
#        [114.173579, -28.118077],
#        [114.048884, -27.334765],
#        [113.477498, -26.543134],
#        [113.338953, -26.116545],
#        [113.778358, -26.549025],
#        [113.440962, -25.621278],
#        [113.936901, -25.911235],
#        [114.232852, -26.298446],
#        [114.216161, -25.786281],
#        [113.721255, -24.998939],
#        [113.625344, -24.683971],
#        [113.393523, -24.384764],
#        [113.502044, -23.80635],
#        [113.706993, -23.560215],
#        [113.843418, -23.059987],
#        [113.736552, -22.475475],
#        [114.149756, -21.755881],
#        [114.225307, -22.517488],
#        [114.647762, -21.82952],
#        [115.460167, -21.495173],
#        [115.947373, -21.068688],
#        [116.711615, -20.701682],
#        [117.166316, -20.623599],
#        [117.441545, -20.746899],
#        [118.229559, -20.374208],
#        [118.836085, -20.263311],
#        [118.987807, -20.044203],
#        [119.252494, -19.952942],
#        [119.805225, -19.976506],
#        [120.85622, -19.683708],
#        [121.399856, -19.239756],
#        [121.655138, -18.705318],
#        [122.241665, -18.197649],
#        [122.286624, -17.798603],
#        [122.312772, -17.254967],
#        [123.012574, -16.4052],
#        [123.433789, -17.268558],
#        [123.859345, -17.069035],
#        [123.503242, -16.596506],
#        [123.817073, -16.111316],
#        [124.258287, -16.327944],
#        [124.379726, -15.56706],
#        [124.926153, -15.0751],
#        [125.167275, -14.680396],
#        [125.670087, -14.51007],
#        [125.685796, -14.230656],
#        [126.125149, -14.347341],
#        [126.142823, -14.095987],
#        [126.582589, -13.952791],
#        [127.065867, -13.817968],
# ...
#     'Other_neoplasms': 0.039547843373621376,
#     'Population': '94,569',
#     'Respiratory_Infectious': 0.7971956983789614,
#     'Respiratory_diseases': 1.110511901363026,
#     'Sense_organ_diseases': 1.4605208895092472,
#     'Skin_diseases': 0.3429242140659201,
#     'Sudden_infant_death_syndrome': 0.028021867631041884,
#     'Unintentional_injuries': 2.8808594782645476,
#     'id': 'VNM',
#     'name': 'Vietnam'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [[[[167.844877, -16.466333],
#        [167.515181, -16.59785],
#        [167.180008, -16.159995],
#        [167.216801, -15.891846],
#        [167.844877, -16.466333]]],
#      [[[167.107712, -14.93392],
#        [167.270028, -15.740021],
#        [167.001207, -15.614602],
#        [166.793158, -15.668811],
#        [166.649859, -15.392704],
#        [166.629137, -14.626497],
#        [167.107712, -14.93392]]]],
#     'type': 'MultiPolygon'},
#    'id': 'VUT',
#    'properties': {'Cardiovascular_diseases': 4.518518518518518,
#     'Congenital_anomalies': 1.2962962962962963,
#     'Country': 'Vanuatu',
#     'Diabetes_mellitus': 1.3333333333333335,
#     'Digestive_diseases': 0.5555555555555556,
#     'Endocrine_blood_immune_disorders': 0.1851851851851852,
#     'Genitourinary_diseases': 0.8148148148148149,
#     'Infectious_and_parasitic_diseases': 2.9629629629629632,
#     'Intentional_injuries': 0.4444444444444444,
#     'Malignant_neoplasms': 2.7037037037037037,
#     'Maternal_conditions': 0.1111111111111111,
#     'Mental_and_substance_use_disorders': 1.6296296296296298,
#     'Musculoskeletal_diseases': 1.037037037037037,
#     'Neonatal_conditions': 2.2962962962962963,
#     'Neurological_conditions': 0.7037037037037037,
#     'Nutritional_deficiencies': 1.1481481481481481,
#     'Oral_conditions': 0.1111111111111111,
#     'Other_neoplasms': 0.03703703703703704,
#     'Population': '270',
#     'Respiratory_Infectious': 1.5185185185185184,
#     'Respiratory_diseases': 1.3703703703703705,
#     'Sense_organ_diseases': 1.1851851851851853,
#     'Skin_diseases': 0.3703703703703704,
#     'Sudden_infant_death_syndrome': 0.03703703703703704,
#     'Unintentional_injuries': 2.0,
#     'id': 'VUT',
#     'name': 'Vanuatu'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [[[35.545665, 32.393992],
#       [35.545252, 31.782505],
#       [35.397561, 31.489086],
#       [34.927408, 31.353435],
#       [34.970507, 31.616778],
#       [35.225892, 31.754341],
#       [34.974641, 31.866582],
#       [35.18393, 32.532511],
#       [35.545665, 32.393992]]],
#     'type': 'Polygon'},
#    'id': 'PSE',
#    'properties': {'Cardiovascular_diseases': 0,
#     'Congenital_anomalies': 0,
#     'Country': 0,
#     'Diabetes_mellitus': 0,
#     'Digestive_diseases': 0,
#     'Endocrine_blood_immune_disorders': 0,
#     'Genitourinary_diseases': 0,
#     'Infectious_and_parasitic_diseases': 0,
#     'Intentional_injuries': 0,
#     'Malignant_neoplasms': 0,
#     'Maternal_conditions': 0,
#     'Mental_and_substance_use_disorders': 0,
#     'Musculoskeletal_diseases': 0,
#     'Neonatal_conditions': 0,
#     'Neurological_conditions': 0,
#     'Nutritional_deficiencies': 0,
#     'Oral_conditions': 0,
#     'Other_neoplasms': 0,
#     'Population': 0,
#     'Respiratory_Infectious': 0,
#     'Respiratory_diseases': 0,
#     'Sense_organ_diseases': 0,
#     'Skin_diseases': 0,
#     'Sudden_infant_death_syndrome': 0,
#     'Unintentional_injuries': 0,
#     'id': 0,
#     'name': 'West Bank'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [[[53.108573, 16.651051],
#       [52.385206, 16.382411],
#       [52.191729, 15.938433],
#       [52.168165, 15.59742],
#       [51.172515, 15.17525],
#       [49.574576, 14.708767],
#       [48.679231, 14.003202],
#       [48.238947, 13.94809],
#       [47.938914, 14.007233],
#       [47.354454, 13.59222],
#       [46.717076, 13.399699],
#       [45.877593, 13.347764],
#       [45.62505, 13.290946],
#       [45.406459, 13.026905],
#       [45.144356, 12.953938],
#       [44.989533, 12.699587],
#       [44.494576, 12.721653],
#       [44.175113, 12.58595],
#       [43.482959, 12.6368],
#       [43.222871, 13.22095],
#       [43.251448, 13.767584],
#       [43.087944, 14.06263],
#       [42.892245, 14.802249],
#       [42.604873, 15.213335],
#       [42.805015, 15.261963],
#       [42.702438, 15.718886],
#       [42.823671, 15.911742],
#       [42.779332, 16.347891],
#       [43.218375, 16.66689],
#       [43.115798, 17.08844],
#       [43.380794, 17.579987],
#       [43.791519, 17.319977],
#       [44.062613, 17.410359],
#       [45.216651, 17.433329],
#       [45.399999, 17.333335],
#       [46.366659, 17.233315],
#       [46.749994, 17.283338],
#       [47.000005, 16.949999],
#       [47.466695, 17.116682],
#       [48.183344, 18.166669],
#       [49.116672, 18.616668],
#       [52.00001, 19.000003],
#       [52.782184, 17.349742],
#       [53.108573, 16.651051]]],
#     'type': 'Polygon'},
#    'id': 'YEM',
#    'properties': {'Cardiovascular_diseases': 6.531685034802784,
#     'Congenital_anomalies': 1.7372389791183294,
#     'Country': 'Yemen',
#     'Diabetes_mellitus': 0.6518271461716938,
#     'Digestive_diseases': 0.7623984918793504,
#     'Endocrine_blood_immune_disorders': 0.5637325986078886,
#     'Genitourinary_diseases': 0.9411252900232019,
#     'Infectious_and_parasitic_diseases': 4.655234918793503,
#     'Intentional_injuries': 2.2059889791183296,
#     'Malignant_neoplasms': 1.6527697215777262,
#     'Maternal_conditions': 0.7399216937354988,
#     'Mental_and_substance_use_disorders': 2.202726218097448,
#     'Musculoskeletal_diseases': 1.023419373549884,
#     'Neonatal_conditions': 6.7067865429234335,
#     'Neurological_conditions': 1.1361658932714616,
#     'Nutritional_deficiencies': 2.257830626450116,
#     'Oral_conditions': 0.17147621809744779,
#     'Other_neoplasms': 0.10223317865429235,
#     'Population': '27,584',
#     'Respiratory_Infectious': 3.3581061484918795,
#     'Respiratory_diseases': 1.0306699535962878,
#     'Sense_organ_diseases': 1.5092082366589328,
#     'Skin_diseases': 0.2885730858468677,
#     'Sudden_infant_death_syndrome': 0.2033787703016241,
#     'Unintentional_injuries': 4.429016821345708,
#     'id': 'YEM',
#     'name': 'Yemen'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [[[31.521001, -29.257387],
#       [31.325561, -29.401978],
#       [30.901763, -29.909957],
#       [30.622813, -30.423776],
#       [30.055716, -31.140269],
#       [28.925553, -32.172041],
#       [28.219756, -32.771953],
#       [27.464608, -33.226964],
#       [26.419452, -33.61495],
#       [25.909664, -33.66704],
#       [25.780628, -33.944646],
#       [25.172862, -33.796851],
#       [24.677853, -33.987176],
#       [23.594043, -33.794474],
#       [22.988189, -33.916431],
#       [22.574157, -33.864083],
#       [21.542799, -34.258839],
#       [20.689053, -34.417175],
#       [20.071261, -34.795137],
#       [19.616405, -34.819166],
#       [19.193278, -34.462599],
#       [18.855315, -34.444306],
#       [18.424643, -33.997873],
#       [18.377411, -34.136521],
#       [18.244499, -33.867752],
#       [18.25008, -33.281431],
#       [17.92519, -32.611291],
#       [18.24791, -32.429131],
#       [18.221762, -31.661633],
#       [17.566918, -30.725721],
#       [17.064416, -29.878641],
#       [17.062918, -29.875954],
#       [16.344977, -28.576705],
#       [16.824017, -28.082162],
#       [17.218929, -28.355943],
#       [17.387497, -28.783514],
#       [17.836152, -28.856378],
#       [18.464899, -29.045462],
#       [19.002127, -28.972443],
#       [19.894734, -28.461105],
#       [19.895768, -24.76779],
#       [20.165726, -24.917962],
#       [20.758609, -25.868136],
#       [20.66647, -26.477453],
#       [20.889609, -26.828543],
#       [21.605896, -26.726534],
#       [22.105969, -26.280256],
#       [22.579532, -25.979448],
#       [22.824271, -25.500459],
#       [23.312097, -25.26869],
#       [23.73357, -25.390129],
#       [24.211267, -25.670216],
#       [25.025171, -25.71967],
#       [25.664666, -25.486816],
#       [25.765849, -25.174845],
#       [25.941652, -24.696373],
#       [26.485753, -24.616327],
#       [26.786407, -24.240691],
#       [27.11941, -23.574323],
#       [28.017236, -22.827754],
#       [29.432188, -22.091313],
#       [29.839037, -22.102216],
#       [30.322883, -22.271612],
#       [30.659865, -22.151567],
#       [31.191409, -22.25151],
#       [31.670398, -23.658969],
#       [31.930589, -24.369417],
#       [31.752408, -25.484284],
#       [31.837778, -25.843332],
#       [31.333158, -25.660191],
#       [31.04408, -25.731452],
#       [30.949667, -26.022649],
#       [30.676609, -26.398078],
#       [30.685962, -26.743845],
#       [31.282773, -27.285879],
#       [31.86806, -27.177927],
#       [32.071665, -26.73382],
#       [32.83012, -26.742192],
#       [32.580265, -27.470158],
#       [32.462133, -28.301011],
#       [32.203389, -28.752405],
#       [31.521001, -29.257387]],
#      [[28.978263, -28.955597],
#       [28.5417, -28.647502],
#       [28.074338, -28.851469],
#       [27.532511, -29.242711],
#       [26.999262, -29.875954],
#       [27.749397, -30.645106],
#       [28.107205, -30.545732],
#       [28.291069, -30.226217],
#       [28.8484, -30.070051],
#       [29.018415, -29.743766],
#       [29.325166, -29.257387],
#       [28.978263, -28.955597]]],
#     'type': 'Polygon'},
#    'id': 'ZAF',
#    'properties': {'Cardiovascular_diseases': 4.431670088369187,
#     'Congenital_anomalies': 0.9977684548781576,
#     'Country': 'South Africa',
#     'Diabetes_mellitus': 2.1860216013567793,
#     'Digestive_diseases': 0.884584486298313,
#     'Endocrine_blood_immune_disorders': 0.646433990895296,
#     'Genitourinary_diseases': 1.010265107560475,
#     'Infectious_and_parasitic_diseases': 16.153708827992503,
#     'Intentional_injuries': 2.533607069534946,
#     'Malignant_neoplasms': 2.914576452735874,
#     'Maternal_conditions': 0.18352227082031597,
#     'Mental_and_substance_use_disorders': 2.17638132643042,
#     'Musculoskeletal_diseases': 1.03043827546193,
#     'Neonatal_conditions': 2.518789609925913,
#     'Neurological_conditions': 1.3589217173971258,
#     'Nutritional_deficiencies': 0.982772471659377,
#     'Oral_conditions': 0.23208069267160583,
#     'Other_neoplasms': 0.09408194233687406,
#     'Population': '56,015',
#     'Respiratory_Infectious': 3.003302686780327,
#     'Respiratory_diseases': 1.492100330268678,
#     'Sense_organ_diseases': 1.2651968222797465,
#     'Skin_diseases': 0.353298223690083,
#     'Sudden_infant_death_syndrome': 0.08140676604480943,
#     'Unintentional_injuries': 2.708560207087387,
#     'id': 'ZAF',
#     'name': 'South Africa'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [[[32.759375, -9.230599],
#       [33.231388, -9.676722],
#       [33.485688, -10.525559],
#       [33.31531, -10.79655],
#       [33.114289, -11.607198],
#       [33.306422, -12.435778],
#       [32.991764, -12.783871],
#       [32.688165, -13.712858],
#       [33.214025, -13.97186],
#       [30.179481, -14.796099],
#       [30.274256, -15.507787],
#       [29.516834, -15.644678],
#       [28.947463, -16.043051],
#       [28.825869, -16.389749],
#       [28.467906, -16.4684],
#       [27.598243, -17.290831],
#       [27.044427, -17.938026],
#       [26.706773, -17.961229],
#       [26.381935, -17.846042],
#       [25.264226, -17.73654],
#       [25.084443, -17.661816],
#       [25.07695, -17.578823],
#       [24.682349, -17.353411],
#       [24.033862, -17.295843],
#       [23.215048, -17.523116],
#       [22.562478, -16.898451],
#       [21.887843, -16.08031],
#       [21.933886, -12.898437],
#       [24.016137, -12.911046],
#       [23.930922, -12.565848],
#       [24.079905, -12.191297],
#       [23.904154, -11.722282],
#       [24.017894, -11.237298],
#       [23.912215, -10.926826],
#       [24.257155, -10.951993],
#       [24.314516, -11.262826],
#       [24.78317, -11.238694],
#       [25.418118, -11.330936],
#       [25.75231, -11.784965],
#       [26.553088, -11.92444],
#       [27.16442, -11.608748],
#       [27.388799, -12.132747],
#       [28.155109, -12.272481],
#       [28.523562, -12.698604],
#       [28.934286, -13.248958],
#       [29.699614, -13.257227],
#       [29.616001, -12.178895],
#       [29.341548, -12.360744],
#       [28.642417, -11.971569],
#       [28.372253, -11.793647],
#       [28.49607, -10.789884],
#       [28.673682, -9.605925],
#       [28.449871, -9.164918],
#       [28.734867, -8.526559],
#       [29.002912, -8.407032],
#       [30.346086, -8.238257],
#       [30.740015, -8.340007],
#       [31.157751, -8.594579],
#       [31.556348, -8.762049],
#       [32.191865, -8.930359],
#       [32.759375, -9.230599]]],
#     'type': 'Polygon'},
#    'id': 'ZMB',
#    'properties': {'Cardiovascular_diseases': 2.3042613465131696,
#     'Congenital_anomalies': 1.6967030317642093,
#     'Country': 'Zambia',
#     'Diabetes_mellitus': 0.4375866433608583,
#     'Digestive_diseases': 1.313965402929299,
#     'Endocrine_blood_immune_disorders': 0.44662768971128924,
#     'Genitourinary_diseases': 0.5249834247483576,
#     'Infectious_and_parasitic_diseases': 19.356277499849316,
#     'Intentional_injuries': 1.040925803146284,
#     'Malignant_neoplasms': 1.7834970767283465,
#     'Maternal_conditions': 0.6280513531432705,
#     'Mental_and_substance_use_disorders': 1.7762642396480017,
#     'Musculoskeletal_diseases': 0.623832198179736,
#     'Neonatal_conditions': 7.312398288228558,
#     'Neurological_conditions': 0.869145922488096,
#     'Nutritional_deficiencies': 2.4778494364414443,
#     'Oral_conditions': 0.1313965402929299,
#     'Other_neoplasms': 0.08920499065758544,
#     'Population': '16,591',
#     'Respiratory_Infectious': 4.407208727623411,
#     'Respiratory_diseases': 0.6449279729974082,
#     'Sense_organ_diseases': 0.7919956602977517,
#     'Skin_diseases': 0.4858055572298234,
#     'Sudden_infant_death_syndrome': 0.09945150985474051,
#     'Unintentional_injuries': 4.30172985353505,
#     'id': 'ZMB',
#     'name': 'Zambia'},
#    'type': 'Feature'},
#   {'geometry': {'coordinates': [[[31.191409, -22.25151],
#       [30.659865, -22.151567],
#       [30.322883, -22.271612],
#       [29.839037, -22.102216],
#       [29.432188, -22.091313],
#       [28.794656, -21.639454],
#       [28.02137, -21.485975],
#       [27.727228, -20.851802],
#       [27.724747, -20.499059],
#       [27.296505, -20.39152],
#       [26.164791, -19.293086],
#       [25.850391, -18.714413],
#       [25.649163, -18.536026],
#       [25.264226, -17.73654],
#       [26.381935, -17.846042],
#       [26.706773, -17.961229],
#       [27.044427, -17.938026],
#       [27.598243, -17.290831],
#       [28.467906, -16.4684],
#       [28.825869, -16.389749],
#       [28.947463, -16.043051],
#       [29.516834, -15.644678],
#       [30.274256, -15.507787],
#       [30.338955, -15.880839],
#       [31.173064, -15.860944],
#       [31.636498, -16.07199],
#       [31.852041, -16.319417],
#       [32.328239, -16.392074],
#       [32.847639, -16.713398],
#       [32.849861, -17.979057],
#       [32.654886, -18.67209],
#       [32.611994, -19.419383],
#       [32.772708, -19.715592],
#       [32.659743, -20.30429],
#       [32.508693, -20.395292],
#       [32.244988, -21.116489],
#       [31.191409, -22.25151]]],
#     'type': 'Polygon'},
#    'id': 'ZWE',
#    'properties': {'Cardiovascular_diseases': 2.890402476780186,
#     'Congenital_anomalies': 1.847678018575851,
#     'Country': 'Zimbabwe',
#     'Diabetes_mellitus': 0.8321981424148608,
#     'Digestive_diseases': 0.9758513931888545,
#     'Endocrine_blood_immune_disorders': 0.30712074303405573,
#     'Genitourinary_diseases': 0.691640866873065,
#     'Infectious_and_parasitic_diseases': 16.367182662538703,
#     'Intentional_injuries': 1.5479876160990713,
#     'Malignant_neoplasms': 2.086687306501548,
#     'Maternal_conditions': 1.0972136222910216,
#     'Mental_and_substance_use_disorders': 1.920123839009288,
#     'Musculoskeletal_diseases': 0.6978328173374613,
#     'Neonatal_conditions': 6.391331269349846,
#     'Neurological_conditions': 0.9145510835913312,
#     'Nutritional_deficiencies': 2.5306501547987614,
#     'Oral_conditions': 0.15046439628482974,
#     'Other_neoplasms': 0.02724458204334365,
#     'Population': '16,150',
#     'Respiratory_Infectious': 4.128792569659442,
#     'Respiratory_diseases': 0.8637770897832818,
#     'Sense_organ_diseases': 0.8272445820433436,
#     'Skin_diseases': 0.3640866873065015,
#     'Sudden_infant_death_syndrome': 0.02414860681114551,
#     'Unintentional_injuries': 4.759133126934985,
#     'id': 'ZWE',
#     'name': 'Zimbabwe'},
#    'type': 'Feature'}],
#  'type': 'FeatureCollection'}
